# %% [markdown]
# # CIS 519 Homework 2: Linear Classifiers
#
# - Handed Out: October 5, 2020
# - Due: October 19, 2020 at 11:59pm.
#
# ## Name: Ian MacDonald
#
# Although the solutions are my own, I consulted with the following people
# while working on this homework:
# - TODO (if applicable): ...
#
# ## Preface
#
# - Feel free to talk to other members of the class in doing the homework. I am more concerned that you learn how to solve the problem than that you demonstrate that you solved it entirely on your own. You should, however, **write down your solution yourself**. Please include here the list of people you consulted with in the course of working on the homework:
#
# - While we encourage discussion within and outside the class, cheating and copying code is strictly not allowed. Copied code will result in the entire assignment being discarded at the very least.
#
# - Please use Piazza if you have questions about the homework. Also, please come to the TAs recitations and to the office hours.
#
# - The homework is due at 11:59 PM on the due date. We will be using Gradescope for collecting the homework assignments. You should have been automatically added to Gradescope. If not, please ask a TA for assistance. Post on Piazza and contact the TAs if you are having technical difficulties in submitting the assignment.
#
# - Here are some resources you will need for this assignment (https://www.seas.upenn.edu/~cis519/fall2020/assets/HW/HW2/hw2-materials.zip)

# %% [markdown]
# # Overview
#
# ### About Jupyter Notebooks
#
# In this homework assignment, we will use a Jupyter notebook to implement, analyze, and discuss ML classifiers.
# Knowing and being comfortable with Jupyter notebooks is a must in every data scientist, ML engineer, researcher, etc. They are widely used in industry and are a standard form of communication in ML by intertwining text and code to "tell a story". There are many resources that can introduce you to Jupyter notebooks (they are pretty easy to understand!), and if you still need help any of the TAs are more than willing to help.
#
# We will be using a local instance of Jupyter instead of Colab. You are of course free to use Colab, but you will need to understand how to hook your Colab instance with Google Drive to upload the datasets and to save images.
#
#
#
# ### About the Homework
#
# You will experiment with several different linear classifiers and analyze
# their performances in both real and synthetic datasets. The goal is to understand the differences and
# similarities between the algorithms and the impact that the dataset characteristics have on the
# algorithms' learning behaviors and performances.
#
# In total, there are seven different learning algorithms which you will implement.
# Six are variants of the Perceptron algorithm and the seventh is a support vector machine (SVM).
# The details of these models is described in Section 1.
#
#
# In order to evaluate the performances of these models, you will use several different datasets.
# The first two datasets are synthetic datasets that have features and labels that were programatically
# generated. They were generated using the same script but use different input parameters that produced
# sparse and dense variants. The second two datasets are for the task of named-entity recognition (NER),
# identifying the names of people, locations, and organizations within text.
# One comes from news text and the other from a corpus of emails.
# For these two datasets, you need to implement the feature extraction yourself.
# All of the datasets and feature extraction information are described in Section 2.
#
# Finally, you will run two sets of experiments, one on the synthetic data and one on the NER data.
# The first set will analyze how the amount of training data impacts model performance.
# The second will look at the consequences of having training and testing data that come from different domains.
# The details of the experiments are described in Section 3.
#
# ### Distribution of Points
#
# The homework has 4 sections for a total of 100 points + 10 extra credit points:
# - Section 0: Warmup (5 points)
# - Section 1: Linear Classifiers (30 points)
# - Section 2: Datasets (0 points, just text)
# - Section 3: Experiments (65 points)
#     - Synthetic Experiment:
#         - Parameter Tuning (10 points)
#         - Learning Curves(10 points)
#         - Final Test Accuracies (5 points)
#         - Discussion Questions (5 points)
#         - Noise Experiment (10 points **extra credit**)
#     - NER Experiment:
#         - Feature Extraction (25 points)
#         - Final Test Accuracies (5 points)
#         - $F_1$ Discussion Questions (5 points)

# %% [markdown]
# # Section 0: Warmup

# %% [markdown]
# ###### Only For Colab
#
# If you want to complete this homework in Colab, you are more than welcome to.
# You will need a little bit more maneuvering since you will need to upload
# the files of hw2 to your Google Drive and run the following two cells:

# %%
# Uncomment if you want to use Colab for this homework.
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# %%
# Uncomment if you want to use Colab for this homework.
# %cd /content/drive/My Drive/Colab Notebooks/YOUR_PATH_TO_HW_FOLDER

# %% [markdown]
# ###### Python Version
#
# Python 3.6 or above is required for this homework. Make sure you have it installed.

# %%
# Let's check.
import sys
if sys.version_info[:2] < (3, 6):
    raise Exception("You have Python version " + str(sys.version_info))

# %% [markdown]
# ## Imports and Helper Functions (5 points total)

# %% [markdown]
# Let's import useful modules we will need throughout the homework
# as well as implement helper functions for our experiment. **Read and remember** what each function is doing, as you will probably need some of them down the line.

# %%
# Install necessary libraries for this homework.
# %pip install sklearn
# %pip install matplotlib
# %pip install numpy

# %%
import json
import os

import numpy as np
import matplotlib.pylab as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import accuracy_score
from sklearn.svm import LinearSVC
from sklearn.feature_extraction import DictVectorizer

DATASETS_PATH = "datasets/"
NER_PATH = os.path.join(DATASETS_PATH, 'ner')
SYNTHETIC_PATH = os.path.join(DATASETS_PATH, 'synthetic')

# %%
"""
Helper function that loads a synthetic dataset from the dataset root (e.g. "synthetic/sparse").

You should not need to edit this method.
"""
def load_synthetic_data(dataset_type):

    def load_jsonl(file_path):
        data = []
        with open(file_path, 'r') as f:
            for line in f:
                data.append(json.loads(line))
        return data

    def load_txt(file_path):
        data = []
        with open(file_path, 'r') as f:
            for line in f:
                data.append(int(line.strip()))
        return data

    def convert_to_sparse(X):
        sparse = []
        for x in X:
            data = {}
            for i, value in enumerate(x):
                if value != 0:
                    data[str(i)] = value
            sparse.append(data)
        return sparse

    path = os.path.join(SYNTHETIC_PATH, dataset_type)
    
    X_train = load_jsonl(os.path.join(path, 'train.X'))
    X_dev = load_jsonl(os.path.join(path, 'dev.X'))
    X_test = load_jsonl(os.path.join(path, 'test.X'))

    num_features = len(X_train[0])
    features = [str(i) for i in range(num_features)]

    X_train = convert_to_sparse(X_train)
    X_dev = convert_to_sparse(X_dev)
    X_test = convert_to_sparse(X_test)

    y_train = load_txt(os.path.join(path, 'train.y'))
    y_dev = load_txt(os.path.join(path, 'dev.y'))
    y_test = load_txt(os.path.join(path, 'test.y'))

    return X_train, y_train, X_dev, y_dev, X_test, y_test, features

# %%
"""
Helper function that loads the NER data from a path (e.g. "ner/conll/train"). 

You should not need to edit this method.
"""
def load_ner_data(dataset=None, dataset_type=None):
    # List of tuples for each sentence
    data = []
    path = os.path.join(os.path.join(NER_PATH, dataset), dataset_type)
    for filename in os.listdir(path):
        with open(os.path.join(path, filename), 'r') as file:
            sentence = []
            for line in file:
                if line == '\n':
                    data.append(sentence)
                    sentence = []
                else:
                    sentence.append(tuple(line.split()))
    return data

# %%
"""
A helper function that plots the relationship between number of examples
and accuracies for all the models.

You should not need to edit this method.
"""
def plot_learning_curves(
    perceptron_accs,
    winnow_accs,
    adagrad_accs,
    avg_perceptron_accs,
    avg_winnow_accs,
    avg_adagrad_accs,
    svm_accs
):
    """
    This function will plot the learning curve for the 7 different models.
    Pass the accuracies as lists of length 11 where each item corresponds
    to a point on the learning curve.
    """
    
    accuracies = [
        ('perceptron', perceptron_accs),
        ('winnow', winnow_accs),
        ('adagrad', adagrad_accs),
        ('avg-perceptron', avg_perceptron_accs),
        ('avg-winnow', avg_winnow_accs),
        ('avg-adagrad', avg_adagrad_accs),
        ('svm', svm_accs)
    ]
    
    x = [500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 10000]
    plt.figure()
    f, (ax, ax2) = plt.subplots(1, 2, sharey=True, facecolor='w')
    
    for label, acc_list in accuracies:
        assert len(acc_list) == 11
        ax.plot(x, acc_list, label=label)
        ax2.plot(x, acc_list, label=label)
        
    ax.set_xlim(0, 5500)
    ax2.set_xlim(9500, 10000)
    ax2.set_xticks([10000])
    # hide the spines between ax and ax2
    ax.spines['right'].set_visible(False)
    ax2.spines['left'].set_visible(False)
    ax.yaxis.tick_left()
    ax.tick_params(labelright='off')
    ax2.yaxis.tick_right()
    ax2.legend()
    plt.show()

# %% [markdown]
# ### F1 Score (5 points)
#
# For some part of the homework, you will use the F1 score instead of accuracy to evaluate how well a model does. The F1 score is computed as the harmonic mean of the precision and recall of the classifier. Precision measures the number of correctly identified positive results by the total number of positive results. Recall, on the other hand, measures the number of correctly identified positive results divided by the number of all samples that should have been identified as positive. More formally, we have that
#
# $$
# \begin{align}
# \text{Precision} &= \frac{TP}{TP + FP} \\
# \text{Recall} &= \frac{TP}{TP + FN}
# \end{align}
# $$
#
# where $TP$ is the number of true positives, $FP$ false positives and $FN$ false negatives. Combining these two we define F1 as
#
# $$
# \text{F1} = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
# $$
#
# You now need to implement the calculation of F1 yourself using the provided function header. It will be unit tested on Gradescope.

# %%
def calculate_f1(y_gold, y_model):
    
    tp_count = 0
    fp_count = 0
    fn_count = 0 
    
    for i in range (0, len(y_gold)):
        
        if(y_model[i] == 1):
            
            if(y_gold[i] == 1):
                
                tp_count+=1
            
            if(y_gold[i] != 1):
                
                fp_count+=1
        
        else:
            
            if(y_gold[i] == 1):
                
                fn_count+=1
                
    precision = tp_count/(tp_count+fp_count)
        
    recall = tp_count/(tp_count+fn_count)
        
    f1 = 2*(precision*recall)/(precision+recall)
        
    return f1

# %% [markdown]
# Looking at the formula for the F1 score, what is the highest and lowest possible value?

# %%
def highest_and_lowest_f1_score():
    return 1, 0

# %% [markdown]
# # Section 1. Linear Classifiers (30 points total)

# %% [markdown]
# This section details the seven different algorithms that you will use in the experiments. For each of the algorithms, we describe the initialization you should use to start training and the different parameter settings that you should use for the experiment on the synthetic datasets. Each of the update functions for the Perceptron, Winnow, and Perceptron with AdaGrad will be unittested on Gradescope, so please do not edit the function definitions.

# %% [markdown]
# ### 1.1 Base Classifier

# %%
class Classifier(object):
    """
    DO NOT MODIFY

    The Classifier class is the base class for all of the Perceptron-based
    algorithms. Your class should override the "process_example" and
    "predict_single" functions. Further, the averaged models should
    override the "finalize" method, where the final parameter values
    should be calculated. 
    
    You should not need to edit this class any further.
    """
    
    ITERATIONS = 10
    
    def train(self, X, y):
        for iteration in range(self.ITERATIONS):
            for x_i, y_i in zip(X, y):
                self.process_example(x_i, y_i)
        self.finalize()

    def process_example(self, x, y):
        """
        Makes a prediction using the current parameter values for
        the features x and potentially updates the parameters based
        on the gradient. Note "x" is a dictionary which maps from the feature
        name to the feature value and y is either 1 or -1.
        """
        raise NotImplementedError

    def finalize(self):
        """Calculates the final parameter values for the averaged models."""
        pass

    def predict(self, X):
        """
        Predicts labels for all of the input examples. You should not need
        to override this method.
        """
        return [self.predict_single(x) for x in X]

    def predict_single(self, x):
        """
        Predicts a label, 1 or -1, for the input example. "x" is a dictionary
        which maps from the feature name to the feature value.
        """
        raise NotImplementedError

# %% [markdown]
# ### 1.2 Basic Perceptron (2 points)

# %% [markdown]
# We do this classifier for you, so enjoy the two free points and pay attention to the techniques and code written.
#
# #### 1.2.1 Description
#
# This is the basic version of the Perceptron Algorithm.
#     In this version, an update will be performed on the example $(\textbf{x}, y)$ if $y(\mathbf{w}^\intercal \mathbf{x} + \theta) \leq 0$. The Perceptron needs to learn both the bias term $\theta$ and the weight vector $\mathbf{w}$ parameters.
# When the Perceptron makes a mistake on the example $(\textbf{x}, y)$, both $\mathbf{w}$ and $\theta$ need to be updated using the following update equations:
# $$
# \begin{align*}
#     \mathbf{w}^\textrm{new} &\gets \mathbf{w} + \eta \cdot y \cdot \mathbf{x} \\
#     \theta^\textrm{new} &\gets \theta + \eta \cdot y
# \end{align*}
# $$
# where $\eta$ is the learning rate.
#
# #### 1.2.2 Hyperparameters
#
# We set $\eta$ to 1, so there are no hyperparameters to tune.
#
# Note: If we assume that the order of the examples presented to the algorithm is fixed, we initialize $\mathbf{w} = \mathbf{0}$ and $\theta = 0$, and train both together, then the learning rate $\eta$ does not have any effect.
#         In fact you can show that, if $\mathbf{w}_1$ and $\theta_1$ are the outputs of the Perceptron algorithm with learning rate $\eta_1$, then $\mathbf{w}_1/\eta_1$ and $\theta_1/\eta_1$ will be the result of the Perceptron with learning rate 1 (note that these two hyperplanes give identical predictions).
#
# #### 1.2.3 Initialization
#
# $\mathbf{w} = [0, 0, \dots, 0]$ and $\theta = 0$.

# %%
class Perceptron(Classifier):
    """
    DO NOT MODIFY THIS CELL

    The Perceptron model. Note how we are subclassing `Classifier`.
    """
    
    def __init__(self, features):
        """
        Initializes the parameters for the Perceptron model. "features"
        is a list of all of the features of the model where each is
        represented by a string.
        """
        
        # NOTE: Do not change the names of these 3 data members because
        # they are used in the unit tests
        self.eta = 1
        self.theta = 0
        self.w = {feature: 0.0 for feature in features}

    def process_example(self, x, y):
        y_pred = self.predict_single(x)
        if y != y_pred:
            for feature, value in x.items():
                self.w[feature] += self.eta * y * value
            self.theta += self.eta * y

    def predict_single(self, x):
        score = 0
        for feature, value in x.items():
            score += self.w[feature] * value
        score += self.theta
        if score <= 0:
            return -1
        return 1

# %% [markdown]
# For the rest of the Perceptron-based algorithms, you will have to implement the corresponding class like we have done for `Perceptron`.
# Use the `Perceptron` class as a guide for how to implement the functions.

# %% [markdown]
# ### 1.3 Winnow (5 points)

# %% [markdown]
# #### 1.3.1 Description
# The Winnow algorithm is a variant of the Perceptron algorithm with multiplicative updates. Since the algorithm requires that the target function is monotonic, you will only use it on the synthetic datasets.
#
# The Winnow algorithm only learns parameters $\mathbf{w}$.
# We will fix $\theta = -n$, where $n$ is the number of features.
# When the Winnow algorithm makes a mistake on the example $(\textbf{x}, y)$, the parameters are updated with the following equation:
# $$
# \begin{equation}
#     w^\textrm{new}_i \gets w_i \cdot \alpha^{y \cdot x_i}
# \end{equation}
# $$
# where $w_i$ and $x_i$ are the $i$th components of the corresponding vectors.
# Here, $\alpha$ is a promotion/demotion hyperparameter.
#
# #### 1.3.2 Hyperparameters
#
# For the experiment, choose $\alpha \in \{1.1, 1.01, 1.005, 1.0005, 1.0001\}$.
#
# #### 1.3.3 Initialization
#
# $\mathbf{w} = [1, 1, \dots, 1]$ and $\theta = -n$ (constant).

# %%
class Winnow(Classifier):
    def __init__(self, alpha, features):
        # DO NOT change the names of these 3 data members because
        # they are used in the unit tests
        self.alpha = alpha
        self.w = {feature: 1.0 for feature in features}
        self.theta = -len(features)
        
    def process_example(self, x, y):
        y_pred = self.predict_single(x)
        if (y_pred != y):
            for feature, value in x.items():
                self.w[feature] = self.w[feature] * self.alpha**(y*value)

    def predict_single(self, x):
        score = 0
        for feature, value in x.items():
            score += self.w[feature] * value
        score += self.theta
        if (score <= 0):
            return -1 
        else:
            return 1

# %% [markdown]
# ### 1.4 AdaGrad (10 points)

# %% [markdown]
# #### 1.4.1 Description
# AdaGrad is a variant of the Perceptron algorithm that adapts the learning rate for each parameter based on historical information.
#     The idea is that frequently changing features get smaller learning rates and stable features higher ones.
#
# To derive the update equations for this model, we first need to start with the loss function.
# Instead of using the hinge loss with the elbow at 0 (like the basic Perceptron does), we will instead use the standard hinge loss with the elbow at 1:
#
# $$
# \begin{equation}
#     \mathcal{L}(\mathbf{x}, y, \mathbf{w}, \theta) = \max\left\{0, 1 - y(\mathbf{w}^\intercal \mathbf{x} + \theta)\right\}
# \end{equation}
# $$
#
# Then, by taking the partial derivative of $\mathcal{L}$ with respect to $\mathbf{w}$ and $\theta$, we can derive the respective graidents (make sure you understand how you could derive these gradients on your own):
#
# $$
# \begin{align}
#     \frac{\partial\mathcal{L}}{\partial\mathbf{w}} &=
#         \begin{cases}
#         \mathbf{0} & \text{if $y(\mathbf{w}^\intercal \mathbf{x} + \theta) > 1$} \\
#         -y\cdot \mathbf{x} & \textrm{otherwise}
#         \end{cases} \\
#     \frac{\partial\mathcal{L}}{\partial\theta} &=
#         \begin{cases}
#             0 & \text{if $y(\mathbf{w}^\intercal \mathbf{x} + \theta) > 1$} \\
#             -y & \textrm{otherwise}
#         \end{cases}
# \end{align}
# $$
#
# Then for each parameter, we will keep track of the sum of the parameters' squared gradients.
# In the following equations, the $k$ superscript refers to the $k$th non-zero gradient (i.e., the $k$th weight vector/misclassified example) and $t$ is the number of mistakes seen thus far.
#
# $$
# \begin{align}
#     G^t_j &= \sum_{k=1}^t \left(\frac{\partial \mathcal{L}}{\partial w^k_j}\right)^2 \\
#     H^t &= \sum_{k=1}^t \left(\frac{\partial \mathcal{L}}{\partial \theta^k}\right)^2
# \end{align}
# $$
#
# For example, on the 3rd mistake ($t = 3$), $G^3_j$ is the sum of the squares of the first three non-zero gradients ($\left(\frac{\partial \mathcal{L}}{\partial w^1_j}\right)^2$, $\left(\frac{\partial \mathcal{L}}{\partial w^2_j}\right)^2$, and $\left(\frac{\partial \mathcal{L}}{\partial w^3_j}\right)^2$).
# Then $\mathbf{G}^3$ is used to calculate the 4th value of the weight vector as follows.
# On example $(\mathbf{x}, y)$, if $y(\mathbf{w}^\intercal \mathbf{x} + \theta) \leq 1$, then the parameters are updated with the following equations:
#
# $$
# \begin{align}
#     \mathbf{w}^{t+1} &\gets \mathbf{w}^t + \eta \cdot \frac{y \cdot \mathbf{x}}{\sqrt{\mathbf{G}^t}} \\
#     \theta^{t+1} &\gets \theta^t + \eta \frac{y}{\sqrt{H^t}}
# \end{align}
# $$
#
# Note that, although we use the hinge loss with the elbow at 1 for training, you still make the prediction based on whether or not $y(\mathbf{w}^\intercal \mathbf{x} + \theta) \leq 0$ during testing.
#
# #### 1.4.2 Hyperparameters
#
# For the experiment, choose $\eta \in \{1.5, 0.25, 0.03, 0.005, 0.001\}$
#
# #### 1.4.3 Initialization
#
# $\mathbf{w} = [0, 0, \dots, 0]$ and $\theta = 0$.

# %%
class AdaGrad(Classifier):
    def __init__(self, eta, features):
        # DO NOT change the names of these 3 data members because
        # they are used in the unit tests
        self.eta = eta
        self.w = {feature: 0.0 for feature in features}
        self.theta = 0
        self.G = {feature: 1e-5 for feature in features}  # 1e-5 prevents divide by 0 problems
        self.H = 0
        
    def process_example(self, x, y):
        y_pred = self.predict_single(x)
        if (y_pred != y):
            for feature, value in x.items():
                dw = y*value
                self.G[feature]+=(dw**2)
                self.w[feature] = self.w[feature] + (self.eta*y*value)/(np.sqrt(self.G[feature]))
                
            dt = -y
            self.H += dt**2
            self.theta = self.theta + (self.eta*y)/(np.sqrt(self.H))
                

    def predict_single(self, x):
        score = 0
        for feature, value in x.items():
            score += self.w[feature] * value
        score += self.theta
        if (score <= 0):
            return -1 
        else:
            return 1

# %% [markdown]
# ### 1.5 Averaged Models (15 points)

# %% [markdown]
# You will also implement the averaged version of the previous three algorithms.
#
# During the course of training, each of the above algorithms will have $K + 1$ different parameter settings for the $K$ different updates it will make during training.
# The regular implementation of these algorithms uses the parameter values after the $K$th update as the final ones.
# Instead, the averaged version use the weighted average of the $K + 1$ parameter values as the final parameter values.
# Let $m_k$ denote the number of correctly classified examples by the $k$th parameter values and $M$ the total number of correctly classified examples.
# The final parameter values are
#
# $$
# \begin{align}
#     M &= \sum_{k=1}^{K+1} m_k \\
#     \mathbf{w} &\gets \frac{1}{M} \sum_{k=1}^{K+1} m_k \cdot \mathbf{w}^k \\
#     \theta &\gets \frac{1}{M} \sum_{k=1}^{K+1} m_k \cdot \theta^k \\
# \end{align}
# $$
#
# For each of the averaged versions of Perceptron, Winnow, and AdaGrad, use the same hyperparameters and initialization as before.
#
# #### 1.5.1 Implementation Note
# Implementing the averaged variants of these algorithms can be tricky.
#     While the final parameter values are based on the sum of $K$ different vectors, there is no need to maintain *all* of these parameters.
#     Instead, you should implement these algorithms by keeping only two vectors, one which maintains the cumulative sum and the current one.
#
# Additionally, there are two ways of keeping track of these two vectors.
# One is more straightforward but prohibitively slow.
# The second requires some algebra to derive but is significantly faster to run.
# Try to analyze how the final weight vector is a function of the intermediate updates and their corresponding weights.
# It should take less than a minute or two for ten iterations for any of the averaged algorithms.
# **You need to think about how to efficiently implement the averaged algorithms yourself.**
#
# Further, the implementation for Winnow is slightly more complicated than the other two, so if you consistently have low accuracy for the averaged Winnow, take a closer look at the derivation.

# %%
class AveragedPerceptron(Classifier):
    def __init__(self, features):
        self.eta = 1
        self.w = {feature: 0.0 for feature in features}
        self.theta = 0
        self.cumul_w = {feature: 0.0 for feature in features}
        self.cumul_theta = 0
        self.classified = 0
        self.final_m = 0
        
    def process_example(self, x, y):
        self.final_m+=1
        y_pred = self.predict_single(x)
        
        if (y_pred == y):
            self.classified+=1
        
        else:
            for feature in self.w:
                self.cumul_w[feature] += self.w[feature] * self.classified
                if feature in x:
                    self.w[feature] += self.eta * y * x[feature]
            self.cumul_theta += self.theta * self.classified
            self.theta += self.eta * y
            self.classified=1
            
#         y_pred = self.predict_single(x)
#         self.classified+=1
#         if y != y_pred:
#             for feature in self.w:
#                 if feature in x:
#                     self.w[feature] += self.eta * y * x[feature]
            
#                 self.cumul_w[feature] += self.w[feature]
            
#             self.theta += self.eta * y
#             self.cumul_theta += self.theta
        
#         else:
#             for feature in self.w:
#                 self.cumul_w[feature] += self.w[feature]
            
#             self.cumul_theta += self.theta

    def predict_single(self, x):
        score = 0
        for feature, value in x.items():
            score += self.w[feature] * value
        score += self.theta
        if score <= 0:
            return -1
        return 1
        
    def finalize(self):
        for feature in self.w:
            self.cumul_w[feature] += self.w[feature] * self.classified
        self.cumul_theta += self.theta * self.classified
        
        final_w = {feature: (value/self.final_m) for feature, value in self.cumul_w.items()}
        final_theta = self.cumul_theta/self.final_m
        
        self.w = final_w
        self.theta = final_theta

# %%
class AveragedWinnow(Classifier):
    def __init__(self, alpha, features):
        self.alpha = alpha
        self.w = {feature: 1.0 for feature in features}
        self.theta = -len(features)
        self.cumul_w = {feature: 1.0 for feature in features}
        self.classified = 0
        
    def process_example(self, x, y):
        y_pred = self.predict_single(x)
        self.classified+=1
        if y != y_pred:
            for feature in self.w:
                if feature in x:
                    self.w[feature] = self.w[feature] * self.alpha**(y*x[feature])
            
                self.cumul_w[feature] += self.w[feature]
        
        else:
            for feature in self.w:
                self.cumul_w[feature] += self.w[feature]

    def predict_single(self, x):
        score = 0
        for feature, value in x.items():
            score += self.w[feature] * value
        score += self.theta
        if (score <= 0):
            return -1 
        else:
            return 1
        
    def finalize(self):
        final_m = self.classified
        final_w = {feature: (value/final_m) for feature, value in self.cumul_w.items()}
        
        self.w = final_w

# %%
class AveragedAdaGrad(Classifier):
    def __init__(self, eta, features):
        self.eta = eta
        self.w = {feature: 0.0 for feature in features}
        self.theta = 0
        self.G = {feature: 1e-5 for feature in features}
        self.H = 0
        self.cumul_w = {feature: 0.0 for feature in features}
        self.cumul_theta = 0
        self.classified = 0 
        self.final_m = 0 
        
    def process_example(self, x, y):
        y_pred = self.predict_single(x)
        self.final_m+=1
        
        if (y_pred == y):
            self.classified+=1
            
        else:
            for feature in self.w:
                self.cumul_w[feature] += self.w[feature] * self.classified
                if feature in x:
                    dw=y*x[feature]
                    self.G[feature]+=(dw**2)
                    self.w[feature]=self.w[feature] + (self.eta*y*x[feature])/(np.sqrt(self.G[feature]))

            dt = -y
            self.H += dt**2
            self.cumul_theta += self.theta * self.classified
            self.theta = self.theta + (self.eta*y)/(np.sqrt(self.H))

    def predict_single(self, x):
        score = 0
        for feature, value in x.items():
            score += self.w[feature] * value
        score += self.theta
        if (score <= 0):
            return -1 
        else:
            return 1
        
    def finalize(self):
        for feature in self.w:
            self.cumul_w[feature] += self.w[feature] * self.classified
        self.cumul_theta += self.theta * self.classified
        
        final_w = {feature: (value/self.final_m) for feature, value in self.cumul_w.items()}
        final_theta = self.cumul_theta/self.final_m
        
        self.w = final_w
        self.theta = final_theta

# %% [markdown]
# ### 1.6 Support Vector Machines
#
# Although we have not yet covered SVMs in class, you can still train them using the `sklearn` library.
# We will use a soft margin SVM for non-linearly separable data.
# You should use the `sklearn` implementation as follows:
# ```
# from sklearn.svm import LinearSVC
# classifier = LinearSVC(loss='hinge')
# classifier.fit(X, y)
# ```
#
# `sklearn` requires a different feature representation than what we use for the Perceptron models.
# The provided Python template code demonstrates how to convert to the require representation.
#
#
# Given training samples $S = \{(\mathbf{x}^1, y^1), (\mathbf{x}^2, y^2), \dots, (\mathbf{x}^m, y^m)\}$, the objective for the SVM is the following:
#
# $$
# \begin{equation}
#     \min_{\mathbf{w}, b, \boldsymbol{\xi}} \frac{1}{2} \vert\vert \mathbf{w}\vert\vert^2_2 + C \sum_{i=1}^m \xi_i
# \end{equation}
# $$
#
# subject to the following constraints:
#
# $$
# \begin{align}
#     y^i(\mathbf{w}^\intercal \mathbf{x}^i + b) \geq 1 - \xi_i \;\;&\textrm{for } i = 1, 2, \dots, m \\
#     \xi_i \geq 0 \;\;& \textrm{for } i = 1, 2, \dots, m
# \end{align}
# $$

# %% [markdown]
# # Section 2. Datasets
#
# In this section, we describe the synthetic and NER datasets that you will use for your experiments.
# For the NER datasets, there is also an explanation for the features which you need to extract from the data.
#
# ### 2.1 Synthetic Data
#
# #### 2.1.1 Introduction
#
# The synthetic datasets have features and labels which are automatically generated from a python script.
# Each instance will have $n$ binary features and are labeled according to a $l$-of-$m$-of-$n$ Boolean function.
# Specifically, there is a set of $m$ features such that an example if positive if and only if at least $l$ of these $m$ features are active.
# The set of $m$ features is the same for the dataset (i.e., it is not a separate set of $m$ features for each individual instance).
#
# We provide two versions of the synthetic dataset called sparse and dense.
# For both datasets, we set $l = 10$ and $m=20$.
# We set $n = 200$ for the sparse data and $n = 40$ for the dense data.
# Additionally, we add noise to the data as follows:
# With probability $0.05$ the label assigned by the function is changed and with probability $0.001$ each feature value is changed.
# Consequently, the data is not linearly separable.
#
# We have provided you with three data splits for both sparse and dense with 10,000 training, 2,000 development, and 2,000 testing examples.
# Section 3 describes the experiments that you need to run on these datasets.
#
# #### 2.1.2 Feature Representation
#
# The features of the synthetic data provided are vectors of 0s and 1s.
# Storing these large matrices requires lots of memory so we use a sparse representation that stores them as dictionaries instead.
# For example, the vector $[0,1,0,0,0,1]$ can be stored as `{"x2": 1,"x6": 1}` (using 1-based indexing).
# We have provided you with the code for parsing and converting the data to this format.
# You can use these for the all algorithms you develop except the SVM.
# Since you will be using the implementation of SVM from sklearn, you will need to provide a vector to it. You can use `sklearn.feature_extraction.DictVectorizer` for converting feature-value dictionaries to vectors.
#
# ### 2.2 NER Data
#
# In addition to the synthetic data, we have provided you two datasets for the task of named-entity recognition (NER).
# The goal is to identify whether strings in text represent names of people, organizations, or locations.
# An example instance looks like the following:
#
# ```
#     [PER Wolff] , currently a journalist in [LOC Argentina] , played with
#     [PER del Bosque] in the final years of the seventies in
#     [ORG Real Madrid] .
# ```
#
# In this problem, we will simplify the task to identifying whether a string is named entity or not (that is, you don't have to say which type of entity it is).
# For each token in the input, we will use the tag $\texttt{I}$ to denote that token is an entity and $\texttt{O}$ otherwise.
# For example, the full tagging for the above instace is as follows:
#
# ```
#     [I Wolff] [O ,] [O currently] [a] [O journalist] [O in] [I Argentina]
#     [O ,] [O played] [O with] [I del] [I Bosque] [O in] [O the] [O final]
#     [O years] [O of] [O the] [O seventies] [O in] [I Real] [I Madrid] .
# ```
#
# Given a sentence $S = w_1, w_2, \dots, w_n$, you need to predict the `I`, `O` tag for each word in the sentence.
# That is, you will produce the sequence $Y = y_1, y_2, \dots, y_n$ where $y_i \in$ {`I`, `O`}.
#
# #### 2.2.1 Datasets: CoNLL and Enron
#
# We have provided two datasets, the CoNLL dataset which is text from news articles, and Enron, a corpus of emails.
# The files contain one word and one tag per line.
# For CoNLL, there are training, development, and testing files, whereas Enron only has a test dataset.
# There are 14,987 training sentences (204,567 words), 336 development sentences (3,779 words), and 303 testing sentences (3,880 words) in CoNLL.
# For Enron there are 368 sentences (11,852 words).
#
# **Please note that the CoNLL dataset is available only for the purposes of this assignment.
# It is copyrighted, and you are granted access because you are a Penn student, but please delete it when you are done with the homework.**
#
# #### 2.2.2 Feature Extraction
#
# The NER data is provided as raw text, and you are required to extract features for the classifier.
# In this assignment, we will only consider binary features based on the context of the word that is supposed to be tagged.
#
# Assume that there are $V$ unique words in the dataset and each word has been assigned a unique ID which is a number $\{1, 2, \dots, V\}$.
# Further, $w_{-k}$ and $w_{+k}$ indicate the $k$th word before and after the target word.
# The feature templates that you should use to generate features are as follows:
#
# | Template             | Number of Features |
# |----------------------|--------------------|
# | $w_{-3}$             | $V$                |
# | $w_{-2}$             | $V$                |
# | $w_{-1}$             | $V$                |
# | $w_{+1}$             | $V$                |
# | $w_{+2}$             | $V$                |
# | $w_{+3}$             | $V$                |
# | $w_{-1}$ & $w_{-2}$  | $V \times V$       |
# | $w_{+1}$ \& $w_{+2}$ | $V \times V$       |
# | $w_{-1}$ \& $w_{+1}$ | $V \times V$       |
#
# Each feature template corresponds to a set of features that you will compute (similar to the features you generated in problem 2 from the first homework assignment).
# The $w_{-3}$ feature template corresponds to $V$ features where the $i$th feature is 1 if the third word to the left of the target word has ID $i$.
# The $w_{-1} \& w_{+1}$ feature template corresponds to $V \times V$ features where there is one feature for every unique pair words.
# For example, feature $(i - 1) \times V + j$ is a binary feature that is 1 if the word 1 to the left of the target has ID $i$ and the first word to the right of the target has ID $j$.
# In practice, you will not need to keep track of the feature IDs.
# Instead, each feature will be given a name such as "$w_{-1}=\textrm{the} \& w_{+1}=\textrm{cat}$".
#
# In total, all of the above feature templates correspond to a very large number of features.
# However, for each word, there will be exactly 9 features which are active (non-zero), so the feature vector is quite sparse.
# You will represent this as a dictionary which maps from the feature name to the value.
# In the provided Python template, we have implemented a couple of the features for you to demonstrate how to compute them and what the naming scheme should look like.
#
# In order to deal with the first two words and the last two words in a sentence, we will add special symbol "SSS" and "EEE" to the vocabulary to represent the words before the first word and the words after the last word.
# Notice that in the test data you may encounter a word that was not observed in training, and therefore is not in your dictionary.
# In this case, you cannot generate a feature for it, resulting in less than 7 active features in some of the test examples.

# %% [markdown]
# # Section 3. Experiments (65 points total)

# %% [markdown]
# You will run two sets of experiments, one using the synthetic data and one using the NER data.
#
# ### 3.1 Synthetic Experiment (30 + 10 extra credit points)
#
# This experiment will explore the impact that the amount of training data has on model performance.
# First, you will do hyperparameter tuning for Winnow and Perceptron with AdaGrad (both standard and averaged versions).
# Then you will generate learning curves that will plot the size of the training data against the performance.
# Finally, for each of the models trained on all of the training data, you will find the test score.
# You should use accuracy to compute the performance of the model.
#
# In summary, the experiment consists of three parts
# 1. Parameter Tuning
# 2. Learning Curves
# 3. Final Evaluation
#
# #### 3.1.1 Parameter Tuning (10 points)
#
# For both the Winnow and Perceptron with AdaGrad (standard and averaged), there are hyperparameters that you need to choose.
# (The same is true for SVM, but you should only use the default settings.)
# Similarly to cross-validation from Homework 1, we will estimate how well each model will do on the true test data using the development dataset (we will not run cross-validation), and choose the hyperparameter settings based on these results.
#
# For each hyperparameter value in Section 1, train a model using that value on the training data and compute the accuracy on the development dataset. Each model should be trained for 10 iterations (i.e., 10 passes over the entire dataset).
#
# TODO: Fill in the table with the best hyperparameter values and the corresponding validation accuracies.
# Repeat this for both the sparse and dense data.

# %%
# Load in data sets 

sparse_data = load_synthetic_data('sparse')
dense_data = load_synthetic_data('dense')

sparse_x_train = sparse_data[0]
sparse_y_train = sparse_data[1]
sparse_x_dev = sparse_data[2]
sparse_y_dev = sparse_data[3]
sparse_x_test = sparse_data[4]
sparse_y_test = sparse_data[5]
sparse_features = sparse_data[6]

# %%
perceptron = Perceptron(sparse_features)
perceptron.train(sparse_x_train, sparse_y_train)

# %%
perceptron_model_dev_predictions = perceptron.predict(sparse_x_dev)
calculate_f1(sparse_y_dev, perceptron_model_dev_predictions)
# Out:
# 0.7737809752198241

# %%
# %%time
avg_perceptron = AveragedPerceptron(sparse_features)
avg_perceptron.train(sparse_x_train, sparse_y_train)
# Out:
# CPU times: user 2.24 s, sys: 318 µs, total: 2.24 s
# Wall time: 2.24 s

# %%
avg_perceptron_model_dev_predictions = avg_perceptron.predict(sparse_x_dev)
calculate_f1(sparse_y_dev, avg_perceptron_model_dev_predictions)
# Out:
# 0.9062034739454093

# %%
winnow = Winnow(1.1, sparse_features)
winnow.train(sparse_x_train, sparse_y_train)

# %%
winnow_model_dev_predictions = winnow.predict(sparse_x_dev)
calculate_f1(sparse_y_dev, winnow_model_dev_predictions)
# Out:
# 0.8945022288261516

# %%
# %%time
avg_winnow = AveragedWinnow(1.1, sparse_features)
avg_winnow.train(sparse_x_train, sparse_y_train)
# Out:
# CPU times: user 3.06 s, sys: 3.99 ms, total: 3.06 s
# Wall time: 3.06 s

# %%
avg_winnow_model_dev_predictions = avg_winnow.predict(sparse_x_dev)
calculate_f1(sparse_y_dev, avg_winnow_model_dev_predictions)
# Out:
# 0.9390609390609391

# %%
ada = AdaGrad(1.5, sparse_features)
ada.train(sparse_x_train, sparse_y_train)

# %%
ada_model_dev_predictions = ada.predict(sparse_x_dev)
calculate_f1(sparse_y_dev, ada_model_dev_predictions)
# Out:
# 0.8651262761955937

# %%
# %%time 
avg_ada = AveragedAdaGrad(1.1, sparse_features)
avg_ada.train(sparse_x_train, sparse_y_train)
# Out:
# CPU times: user 10.3 s, sys: 2 µs, total: 10.3 s
# Wall time: 10.3 s

# %%
avg_ada_model_dev_predictions = avg_ada.predict(sparse_x_test)
accuracy_score(sparse_y_test, avg_ada_model_dev_predictions)
# Out:
# 0.9265

# %%
dv = DictVectorizer(sparse=False, dtype=int)
svc_x_train=dv.fit_transform(sparse_x_train)
svc.fit(svc_x_train, sparse_y_train)
# Out:
# LinearSVC(loss='hinge')

# %%
svc_pred = svc.predict(dv.fit_transform(sparse_x_dev))
accuracy_score(svc_pred, sparse_y_dev)
# Out:
# 0.939

# %% [markdown]
# ##### Winnow Sweep
#
# | $\alpha$ | Sparse | Dense |
# |----------|--------|-------|
# | 1.1      |        |       |
# | 1.01     |        |       |
# | 1.005    |        |       |
# | 1.0005   |        |       |
# | 1.0001   |        |       |
#
# ##### Averaged Winnow Sweep
#
# | $\alpha$ | Sparse | Dense |
# |----------|--------|-------|
# | 1.1      |        |       |
# | 1.01     |        |       |
# | 1.005    |        |       |
# | 1.0005   |        |       |
# | 1.0001   |        |       |
#
# ##### AdaGrad Sweep
#
# | $\eta$   | Sparse | Dense |
# |----------|--------|-------|
# | 1.5      |        |       |
# | 0.25     |        |       |
# | 0.03     |        |       |
# | 0.005    |        |       |
# | 0.001    |        |       |
#
# ##### Averaged AdaGrad Sweep
#
# | $\eta$   | Sparse | Dense |
# |----------|--------|-------|
# | 1.5      |        |       |
# | 0.25     |        |       |
# | 0.03     |        |       |
# | 0.005    |        |       |
# | 0.001    |        |       |

# %% [markdown]
# #### 3.1.2 Learning Curves (10 points)
#
# Next, you will train all 7 models with different amounts of training data.
# For Winnow and Perceptron with AdaGrad (standard and averaged), use the best hyperparameters from the parameter tuning experiment.
#
# Each of the datasets contains 10,000 training examples.
# You will train each model 11 times on varying amounts of training data.
# The first 10 will increase by 500 examples: 500, 1k, 1.5k, 2k, ..., 5k.
# The 11th model should use all 10k examples.
# Each Perceptron-based model should be trained for 10 iterations (e.g., 10 passes over the total number of training examples available to that model).
# The SVM can be run until convergence with the default parameters.
#
# For each model, compute the accuracy on the development dataset and plot the results using the provided code.
# There should be a separate plot for the sparse and dense data.
#
# **Note** how we have included an image in markdown. You should do the same for both plots and include them in the output below by running your experiment, saving your plots to the images folder, and linking it to this cell.
#
# ##### Sparse Plot
#
# ![Sample](images/sample.png)
#
# ##### Dense Plot
#
# ![Sample](images/sample.png)

# %% [markdown]
# #### 3.1.3 Final Evaluation (5 points)
#
# Finally, for each of the 7 models, train the models on all of the training data and compute the test accuracy.
# For Winnow and Perceptron with AdaGrad, use the best hyperparameter settings you found.
# Report these accuracies in a table.
#
# We will run our models with [500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 10000] examples.

# %%
sample_sizes = [500 * i for i in range(1, 11)] + [10_000]

# %%
def run_synthetic_experiment(dataset_type):

    # Load in data sets
    
    X_train, y_train, X_dev, y_dev, X_test, y_test, features = load_synthetic_data(dataset_type)
    
    # Select model hyperparameters
    
    winnow_hp_choices = [1.1, 1.01, 1.005, 1.0005, 1.0001]
    ada_hp_choices = [1.5, .25, .03, .005, .001]
    
    winnow_hp_accs = []
    ada_hp_accs = []
    winnow_avg_hp_accs = []
    ada_avg_hp_accs = []
    
    for hp in winnow_hp_choices:
        w = Winnow(hp, features)
        w.train(X_train, y_train)
        w_pred = w.predict(X_dev)
        w_acc = accuracy_score(y_dev, w_pred)
        winnow_hp_accs.append(w_acc)
        print('Winnow Accuracy for Hyperparameter: ' + str(hp) + ' = ' + str(w_acc))
        
        w_avg = AveragedWinnow(hp, features)
        w_avg.train(X_train, y_train)
        w_avg_pred = w_avg.predict(X_dev)
        w_avg_acc = accuracy_score(y_dev, w_avg_pred)
        winnow_avg_hp_accs.append(w_avg_acc)
        print('AveragedWinnow Accuracy for Hyperparameter: ' + str(hp) + ' = ' + str(w_avg_acc))
        
        print()
    
    for hp in ada_hp_choices:
        a = AdaGrad(hp, features)
        a.train(X_train, y_train)
        a_pred = a.predict(X_dev)
        a_acc = accuracy_score(y_dev, a_pred)
        ada_hp_accs.append(a_acc)
        print('AdaGrad Accuracy for Hyperparameter: ' + str(hp) + ' = ' + str(a_acc))
        
        a_avg = AveragedAdaGrad(hp, features)
        a_avg.train(X_train, y_train)
        a_avg_pred = a_avg.predict(X_dev)
        a_avg_acc = accuracy_score(y_dev, a_avg_pred)
        ada_avg_hp_accs.append(a_avg_acc)
        print('AveragedAdaGrad Accuracy for Hyperparameter: ' + str(hp) + ' = ' + str(a_avg_acc))
        
        print()
    
    
    winnow_hp_selection = winnow_hp_choices[winnow_hp_accs.index(max(winnow_hp_accs))]
    ada_hp_selection = ada_hp_choices[ada_hp_accs.index(max(ada_hp_accs))]
    winnow_avgd_hp_selection = winnow_hp_choices[winnow_avg_hp_accs.index(max(winnow_avg_hp_accs))]
    ada_avgd_hp_selection = ada_hp_choices[ada_avg_hp_accs.index(max(ada_avg_hp_accs))]
    
    print('Ideal Winnow Hyperparameter: ' + str(winnow_hp_selection) + ', Accuracy: ' + str(max(winnow_hp_accs)))
    print('Ideal AdaGrad Hyperparameter: ' + str(ada_hp_selection) + ', Accuracy: ' + str(max(ada_hp_accs)))
    print('Ideal AveragedWinnow Hyperparameter: ' + str(winnow_avgd_hp_selection) + ', Accuracy: ' + str(max(winnow_avg_hp_accs)))
    print('Ideal AveragedAdaGrad Hyperparameter: ' + str(ada_avgd_hp_selection) + ', Accuracy: ' + str(max(ada_avg_hp_accs)))
    print()
    
#     winnow_hp_selection = winnow_hp_choices[0]
#     ada_hp_selection = ada_hp_choices[0]
#     winnow_avgd_hp_selection = winnow_hp_choices[0]
#     ada_avgd_hp_selection = ada_hp_choices[0]

    # Train models, compute test accuracy
    
    per_accs = []
    avg_per_accs = []
    winnow_accs = []
    avg_winnow_accs = []
    ada_accs = []
    avg_ada_accs = []
    svc_accs = []
    
    models = {0: Perceptron, 1: AveragedPerceptron,
             2: Winnow, 3: AveragedWinnow,
             4: AdaGrad, 5: AveragedAdaGrad}
    
    model_names = ['Perceptron', 'AveragedPerceptron', 'Winnow', 'AveragedWinnow', 
                  'AdaGrad', 'AveragedAdaGrad']
    
    accs = [per_accs, avg_per_accs, winnow_accs, avg_winnow_accs, ada_accs, avg_ada_accs, svc_accs]
    
    dv = DictVectorizer(sparse=False, dtype=int)
    
    for size in sample_sizes:
        x_train_slice = X_train[0:size]
        y_train_slice = y_train[0:size]
        
        for i in range(0, len(models)):
            if (i==2):
                classifier=models[i](winnow_hp_selection, features)
            elif (i==3):
                classifier=models[i](winnow_avgd_hp_selection, features)
            elif (i==4):
                classifier=models[i](ada_hp_selection, features)
            elif (i==5):
                classifier=models[i](ada_avgd_hp_selection, features)
            else:
                classifier=models[i](features)
            
            classifier.train(x_train_slice, y_train_slice)
            y_pred = classifier.predict(X_test)
            acc = accuracy_score(y_test, y_pred)
            accs[i].append(acc)
            print(model_names[i] + ' accuracy with sample size ' + str(size) + ' is ' + str(acc))
        
        svc_x_train_slice = dv.fit_transform(x_train_slice)
        svc_x_test = dv.fit_transform(X_test)
        
        svc = LinearSVC(loss='hinge')
        svc.fit(svc_x_train_slice, y_train_slice)
        svc_pred = svc.predict(svc_x_test)
        svc_acc = accuracy_score(y_test, svc_pred)
        accs[6].append(svc_acc)
        print('SVC accuracy with sample size ' + str(size) + ' is ' + str(svc_acc))
            
        print()
        
    # Plot Accuracies
    
    plot_learning_curves(per_accs, winnow_accs, ada_accs, avg_per_accs, avg_winnow_accs, avg_ada_accs, svc_accs)
    save_destination = 'images/' + dataset_type + '.png'
    plt.savefig(save_destination)

# %%
# classifier = AveragedAdaGrad(1.5, sparse_features)
# classifier.train(sparse_x_train, sparse_y_train)
# y_pred = classifier.predict(sparse_x_test)
# acc = accuracy_score(sparse_y_test, y_pred)
# print(' accuracy is ' + str(acc))

# %%
# %%time 
"""
Run the synthetic experiment on the sparse dataset. For reference,
"synthetic/sparse" is the path to where the data is located.
Note: This experiment takes substantial time (around 15 minutes),
so don't worry if it's taking a long time to finish.
"""
run_synthetic_experiment('sparse')
# Out:
# Winnow Accuracy for Hyperparameter: 1.1 = 0.8935
# AveragedWinnow Accuracy for Hyperparameter: 1.1 = 0.939
#
# Winnow Accuracy for Hyperparameter: 1.01 = 0.927
# AveragedWinnow Accuracy for Hyperparameter: 1.01 = 0.8875
#
# Winnow Accuracy for Hyperparameter: 1.005 = 0.9195
# AveragedWinnow Accuracy for Hyperparameter: 1.005 = 0.8145
#
# Winnow Accuracy for Hyperparameter: 1.0005 = 0.563
# AveragedWinnow Accuracy for Hyperparameter: 1.0005 = 0.5275
#
# Winnow Accuracy for Hyperparameter: 1.0001 = 0.5205
# AveragedWinnow Accuracy for Hyperparameter: 1.0001 = 0.5055
#
# AdaGrad Accuracy for Hyperparameter: 1.5 = 0.8745
# AveragedAdaGrad Accuracy for Hyperparameter: 1.5 = 0.9265
#
# AdaGrad Accuracy for Hyperparameter: 0.25 = 0.8745
# AveragedAdaGrad Accuracy for Hyperparameter: 0.25 = 0.9265
#
# AdaGrad Accuracy for Hyperparameter: 0.03 = 0.8745
# AveragedAdaGrad Accuracy for Hyperparameter: 0.03 = 0.9265
#
# AdaGrad Accuracy for Hyperparameter: 0.005 = 0.8745
# AveragedAdaGrad Accuracy for Hyperparameter: 0.005 = 0.9265
#
# AdaGrad Accuracy for Hyperparameter: 0.001 = 0.8745
# AveragedAdaGrad Accuracy for Hyperparameter: 0.001 = 0.9265
#
# Ideal Winnow Hyperparameter: 1.01, Accuracy: 0.927
# Ideal AdaGrad Hyperparameter: 1.5, Accuracy: 0.8745
# Ideal AveragedWinnow Hyperparameter: 1.1, Accuracy: 0.939
# Ideal AveragedAdaGrad Hyperparameter: 1.5, Accuracy: 0.9265
#
# Perceptron accuracy with sample size 500 is 0.544
# AveragedPerceptron accuracy with sample size 500 is 0.5415
# Winnow accuracy with sample size 500 is 0.5575
# AveragedWinnow accuracy with sample size 500 is 0.673
# AdaGrad accuracy with sample size 500 is 0.5365
# AveragedAdaGrad accuracy with sample size 500 is 0.5285
# SVC accuracy with sample size 500 is 0.6165
# /home/ian/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Perceptron accuracy with sample size 1000 is 0.605
# AveragedPerceptron accuracy with sample size 1000 is 0.606
# Winnow accuracy with sample size 1000 is 0.626
# AveragedWinnow accuracy with sample size 1000 is 0.8555
# AdaGrad accuracy with sample size 1000 is 0.582
# AveragedAdaGrad accuracy with sample size 1000 is 0.6145
# SVC accuracy with sample size 1000 is 0.93
# /home/ian/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Perceptron accuracy with sample size 1500 is 0.664
# AveragedPerceptron accuracy with sample size 1500 is 0.6525
# Winnow accuracy with sample size 1500 is 0.758
# AveragedWinnow accuracy with sample size 1500 is 0.9175
# AdaGrad accuracy with sample size 1500 is 0.6745
# AveragedAdaGrad accuracy with sample size 1500 is 0.6705
# SVC accuracy with sample size 1500 is 0.936
#
# Perceptron accuracy with sample size 2000 is 0.6295
# AveragedPerceptron accuracy with sample size 2000 is 0.6885
# Winnow accuracy with sample size 2000 is 0.8465
# AveragedWinnow accuracy with sample size 2000 is 0.932
# AdaGrad accuracy with sample size 2000 is 0.7045
# AveragedAdaGrad accuracy with sample size 2000 is 0.709
# SVC accuracy with sample size 2000 is 0.936
#
# Perceptron accuracy with sample size 2500 is 0.647
# AveragedPerceptron accuracy with sample size 2500 is 0.7115
# Winnow accuracy with sample size 2500 is 0.8515
# AveragedWinnow accuracy with sample size 2500 is 0.9355
# AdaGrad accuracy with sample size 2500 is 0.641
# AveragedAdaGrad accuracy with sample size 2500 is 0.7345
# SVC accuracy with sample size 2500 is 0.936
#
# Perceptron accuracy with sample size 3000 is 0.6565
# AveragedPerceptron accuracy with sample size 3000 is 0.7355
# Winnow accuracy with sample size 3000 is 0.8965
# AveragedWinnow accuracy with sample size 3000 is 0.9355
# AdaGrad accuracy with sample size 3000 is 0.716
# AveragedAdaGrad accuracy with sample size 3000 is 0.7485
# SVC accuracy with sample size 3000 is 0.936
#
# Perceptron accuracy with sample size 3500 is 0.7275
# AveragedPerceptron accuracy with sample size 3500 is 0.7595
# Winnow accuracy with sample size 3500 is 0.841
# AveragedWinnow accuracy with sample size 3500 is 0.9355
# AdaGrad accuracy with sample size 3500 is 0.745
# AveragedAdaGrad accuracy with sample size 3500 is 0.776
# SVC accuracy with sample size 3500 is 0.936
#
# Perceptron accuracy with sample size 4000 is 0.69
# AveragedPerceptron accuracy with sample size 4000 is 0.784
# Winnow accuracy with sample size 4000 is 0.8555
# AveragedWinnow accuracy with sample size 4000 is 0.9355
# AdaGrad accuracy with sample size 4000 is 0.756
# AveragedAdaGrad accuracy with sample size 4000 is 0.796
# SVC accuracy with sample size 4000 is 0.936
#
# Perceptron accuracy with sample size 4500 is 0.675
# AveragedPerceptron accuracy with sample size 4500 is 0.8015
# Winnow accuracy with sample size 4500 is 0.9085
# AveragedWinnow accuracy with sample size 4500 is 0.936
# AdaGrad accuracy with sample size 4500 is 0.8295
# AveragedAdaGrad accuracy with sample size 4500 is 0.818
# SVC accuracy with sample size 4500 is 0.936
#
# Perceptron accuracy with sample size 5000 is 0.766
# AveragedPerceptron accuracy with sample size 5000 is 0.81
# Winnow accuracy with sample size 5000 is 0.9115
# AveragedWinnow accuracy with sample size 5000 is 0.936
# AdaGrad accuracy with sample size 5000 is 0.8435
# AveragedAdaGrad accuracy with sample size 5000 is 0.8375
# SVC accuracy with sample size 5000 is 0.936
#
# Perceptron accuracy with sample size 10000 is 0.717
# AveragedPerceptron accuracy with sample size 10000 is 0.909
# Winnow accuracy with sample size 10000 is 0.926
# AveragedWinnow accuracy with sample size 10000 is 0.936
# AdaGrad accuracy with sample size 10000 is 0.878
# AveragedAdaGrad accuracy with sample size 10000 is 0.9265
# SVC accuracy with sample size 10000 is 0.936
# CPU times: user 3min 57s, sys: 348 ms, total: 3min 58s
# Wall time: 3min 58s

# %%
# %%time 

"""
Run the synthetic experiment on the dense dataset. For reference,
"synthetic/dense" is the path to where the data is located.
Note: this experiment should take much less time.
"""
run_synthetic_experiment('dense')
# Out:
# Winnow Accuracy for Hyperparameter: 1.1 = 0.8995
# AveragedWinnow Accuracy for Hyperparameter: 1.1 = 0.9445
#
# Winnow Accuracy for Hyperparameter: 1.01 = 0.9215
# AveragedWinnow Accuracy for Hyperparameter: 1.01 = 0.9315
#
# Winnow Accuracy for Hyperparameter: 1.005 = 0.908
# AveragedWinnow Accuracy for Hyperparameter: 1.005 = 0.913
#
# Winnow Accuracy for Hyperparameter: 1.0005 = 0.8615
# AveragedWinnow Accuracy for Hyperparameter: 1.0005 = 0.682
#
# Winnow Accuracy for Hyperparameter: 1.0001 = 0.614
# AveragedWinnow Accuracy for Hyperparameter: 1.0001 = 0.5465
#
# AdaGrad Accuracy for Hyperparameter: 1.5 = 0.9325
# AveragedAdaGrad Accuracy for Hyperparameter: 1.5 = 0.9445
#
# AdaGrad Accuracy for Hyperparameter: 0.25 = 0.9325
# AveragedAdaGrad Accuracy for Hyperparameter: 0.25 = 0.9445
#
# AdaGrad Accuracy for Hyperparameter: 0.03 = 0.9325
# AveragedAdaGrad Accuracy for Hyperparameter: 0.03 = 0.9445
#
# AdaGrad Accuracy for Hyperparameter: 0.005 = 0.9325
# AveragedAdaGrad Accuracy for Hyperparameter: 0.005 = 0.9445
#
# AdaGrad Accuracy for Hyperparameter: 0.001 = 0.9325
# AveragedAdaGrad Accuracy for Hyperparameter: 0.001 = 0.9445
#
# Ideal Winnow Hyperparameter: 1.01, Accuracy: 0.9215
# Ideal AdaGrad Hyperparameter: 1.5, Accuracy: 0.9325
# Ideal AveragedWinnow Hyperparameter: 1.1, Accuracy: 0.9445
# Ideal AveragedAdaGrad Hyperparameter: 1.5, Accuracy: 0.9445
#
# Perceptron accuracy with sample size 500 is 0.5335
# AveragedPerceptron accuracy with sample size 500 is 0.667
# Winnow accuracy with sample size 500 is 0.799
# AveragedWinnow accuracy with sample size 500 is 0.9225
# AdaGrad accuracy with sample size 500 is 0.6205
# AveragedAdaGrad accuracy with sample size 500 is 0.7375
# SVC accuracy with sample size 500 is 0.9385
# /home/ian/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Perceptron accuracy with sample size 1000 is 0.676
# AveragedPerceptron accuracy with sample size 1000 is 0.8665
# Winnow accuracy with sample size 1000 is 0.907
# AveragedWinnow accuracy with sample size 1000 is 0.9405
# AdaGrad accuracy with sample size 1000 is 0.86
# AveragedAdaGrad accuracy with sample size 1000 is 0.9305
# SVC accuracy with sample size 1000 is 0.9405
#
# Perceptron accuracy with sample size 1500 is 0.8255
# AveragedPerceptron accuracy with sample size 1500 is 0.934
# Winnow accuracy with sample size 1500 is 0.8895
# AveragedWinnow accuracy with sample size 1500 is 0.9405
# AdaGrad accuracy with sample size 1500 is 0.926
# AveragedAdaGrad accuracy with sample size 1500 is 0.9405
# SVC accuracy with sample size 1500 is 0.9405
#
# Perceptron accuracy with sample size 2000 is 0.815
# AveragedPerceptron accuracy with sample size 2000 is 0.9405
# Winnow accuracy with sample size 2000 is 0.9205
# AveragedWinnow accuracy with sample size 2000 is 0.9405
# AdaGrad accuracy with sample size 2000 is 0.9
# AveragedAdaGrad accuracy with sample size 2000 is 0.9405
# SVC accuracy with sample size 2000 is 0.9405
#
# Perceptron accuracy with sample size 2500 is 0.8715
# AveragedPerceptron accuracy with sample size 2500 is 0.9405
# Winnow accuracy with sample size 2500 is 0.9255
# AveragedWinnow accuracy with sample size 2500 is 0.9405
# AdaGrad accuracy with sample size 2500 is 0.9075
# AveragedAdaGrad accuracy with sample size 2500 is 0.9405
# SVC accuracy with sample size 2500 is 0.9405
#
# Perceptron accuracy with sample size 3000 is 0.7985
# AveragedPerceptron accuracy with sample size 3000 is 0.9405
# Winnow accuracy with sample size 3000 is 0.93
# AveragedWinnow accuracy with sample size 3000 is 0.9405
# AdaGrad accuracy with sample size 3000 is 0.8135
# AveragedAdaGrad accuracy with sample size 3000 is 0.9405
# SVC accuracy with sample size 3000 is 0.9405
#
# Perceptron accuracy with sample size 3500 is 0.924
# AveragedPerceptron accuracy with sample size 3500 is 0.9405
# Winnow accuracy with sample size 3500 is 0.9245
# AveragedWinnow accuracy with sample size 3500 is 0.9405
# AdaGrad accuracy with sample size 3500 is 0.9075
# AveragedAdaGrad accuracy with sample size 3500 is 0.9405
# SVC accuracy with sample size 3500 is 0.9405
#
# Perceptron accuracy with sample size 4000 is 0.8195
# AveragedPerceptron accuracy with sample size 4000 is 0.9405
# Winnow accuracy with sample size 4000 is 0.9335
# AveragedWinnow accuracy with sample size 4000 is 0.9405
# AdaGrad accuracy with sample size 4000 is 0.93
# AveragedAdaGrad accuracy with sample size 4000 is 0.9405
# SVC accuracy with sample size 4000 is 0.9405
#
# Perceptron accuracy with sample size 4500 is 0.8915
# AveragedPerceptron accuracy with sample size 4500 is 0.9405
# Winnow accuracy with sample size 4500 is 0.9325
# AveragedWinnow accuracy with sample size 4500 is 0.9405
# AdaGrad accuracy with sample size 4500 is 0.9205
# AveragedAdaGrad accuracy with sample size 4500 is 0.9405
# SVC accuracy with sample size 4500 is 0.9405
#
# Perceptron accuracy with sample size 5000 is 0.896
# AveragedPerceptron accuracy with sample size 5000 is 0.9405
# Winnow accuracy with sample size 5000 is 0.932
# AveragedWinnow accuracy with sample size 5000 is 0.9405
# AdaGrad accuracy with sample size 5000 is 0.9235
# AveragedAdaGrad accuracy with sample size 5000 is 0.9405
# SVC accuracy with sample size 5000 is 0.9405
#
# Perceptron accuracy with sample size 10000 is 0.9205
# AveragedPerceptron accuracy with sample size 10000 is 0.9405
# Winnow accuracy with sample size 10000 is 0.9255
# AveragedWinnow accuracy with sample size 10000 is 0.9405
# AdaGrad accuracy with sample size 10000 is 0.9325
# AveragedAdaGrad accuracy with sample size 10000 is 0.9405
# SVC accuracy with sample size 10000 is 0.9405
# CPU times: user 41.5 s, sys: 28 ms, total: 41.5 s
# Wall time: 41.6 s

# %% [markdown]
# ##### Questions (5 points)
#
# Answer the following questions:
#
# 1. Discuss the trends that you see when comparing the standard version of an algorithm to the averaged version (e.g., Winnow versus Averaged Winnow). Is there an observable trend?
#
#     *TODO: My answer to question 1 here*
#
#
# 2. We provided you with 10,000 training examples.
#    Were all 10,000 necessary to achieve the best performance for each classifier?
#    If not, how many were necessary? (Rough estimates, no exact numbers required)
#
#    *TODO: My answer to question 2 here*
#
#
# 3. Report your Final Test Accuracies
#
#   *TODO: Fill in the table*
#
# | Model               | Sparse | Dense |
# |---------------------|--------|-------|
# | Perceptron          |        |       |
# | Winnow              |        |       |
# | AdaGrad             |        |       |
# | Averaged Perceptron |        |       |
# | Averaged Winnow     |        |       |
# | Averaged AdaGrad    |        |       |
# | SVM                 |        |       |

# %% [markdown]
# #### 3.1.5 Extra Credit (10 points)
#
# Included in the resources for this homework assignment is the code that we used to generate the synthetic data.
# We used a small amount of noise to create the dataset which you ran the experiments on.
# For extra credit, vary the amount of noise in either/both of the label and features.
# Then, plot the models' performances as a function of the amount of noise.
# Discuss your observations.

# %% [markdown]
# TODO: Extra Credit observations

# %% [markdown]
# ### 3.2 NER Experiment: Welcome to the Real World (35 points)
#
# The experiment with the NER data will analyze how changing the domain of the training and testing data can impact the performance of a model.
#
# Instead of accuracy, you will use your $F_1$ score implementation in Section 0 to evaluate how well a model does.
# Recall measures how many of the actual entities the model successfully tagged as an entity.
#
# $$
# \begin{align}
#     \textrm{Precision} &= \frac{\#\textrm{(Actually Entity & Model Predicted Entity)}}{\#\textrm{(Model Predicted Entity)}} \\
#     \textrm{Recall} &= \frac{\#\textrm{(Actually Entity & Model Predicted Entity)}}{\#\textrm{(Actually Entity)}} \\
#     \textrm{F}_1 &= 2 \cdot \frac{\textrm{Precision} \times \textrm{Recall}}{\textrm{Precision} + \textrm{Recall}}
# \end{align}
# $$
#
# For this experiment, you will only use the averaged basic Perceptron and SVM.
# Hence, no parameter tuning is necessary.
# Train both models on the CoNLL training data then compute the F$_1$ on the development and testing data of both CoNLL and Enron.
# Note that the model which is used to predict labels for Enron is trained on CoNLL data, not Enron data.
# Report the F$_1$ scores in a table.
#
# #### 3.2.1 Extracting NER Features  (25 points)
#
# Reread Section 2.2.2 to understand how to extract the features required to train the models
# and translate it to the code below.

# %%
def extract_ner_features_train(train):
    """
    Extracts feature dictionaries and labels from the data in "train"
    Additionally creates a list of all of the features which were created.
    We have implemented the w-1 and w+1 features for you to show you how
    to create them.
    
    TODO: You should add your additional featurization code here.
    (which might require adding and/or changing existing code)
    """
    y = []
    X = []
    features = set()
    for sentence in train:
        padded = [('SSS', None)] * 3 + sentence[:] + [('EEE', None)] * 3
        for i in range(3, len(padded) - 3):
            y.append(1 if padded[i][1] == 'I' else -1)
            feat1 = 'w-3=' + str(padded[i - 3][0])
            feat2 = 'w-2=' + str(padded[i - 2][0])
            feat3 = 'w-1=' + str(padded[i - 1][0])
            feat4 = 'w+1=' + str(padded[i + 1][0])
            feat5 = 'w+2=' + str(padded[i + 2][0])
            feat6 = 'w+3=' + str(padded[i + 3][0])
            feat7 = 'w-1=' + str(padded[i - 1][0]) + '&w-2=' + str(padded[i - 2][0])
            feat8 = 'w+1=' + str(padded[i + 1][0]) + '&w+2=' + str(padded[i + 2][0])
            feat9 = 'w-1=' + str(padded[i - 1][0]) + '&w+1=' + str(padded[i + 1][0])
            feats = [feat1, feat2, feat3, feat4, feat5, feat6, feat7, feat8, feat9]
            features.update(feats)
            feats = {feature: 1 for feature in feats}
            X.append(feats)
    return features, X, y

# %%
ner_data_train = load_ner_data(dataset='conll', dataset_type='train')
ner_data_train
# Out:
# [[('-DOCSTART-', 'O')],
#  [('Iraq', 'I'),
#   ('says', 'O'),
#   ('hijackers', 'O'),
#   ('were', 'O'),
#   ('not', 'O'),
#   ('diplomats', 'O'),
#   ('.', 'O')],
#  [('BAGHDAD', 'I'), ('1996-08-28', 'O')],
#  [('Iraq', 'I'),
#   ('on', 'O'),
#   ('Wednesday', 'O'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('hijackers', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('Sudanese', 'I'),
#   ('airliner', 'O'),
#   ('were', 'O'),
#   ('not', 'O'),
#   ('Iraqi', 'I'),
#   ('diplomats', 'O'),
#   ('and', 'O'),
#   ('added', 'O'),
#   ('that', 'O'),
#   ('"', 'O'),
#   ('noble', 'O'),
#   ('Iraqis', 'I'),
#   ('"', 'O'),
#   ('would', 'O'),
#   ('never', 'O'),
#   ('contemplate', 'O'),
#   ('such', 'O'),
#   ('an', 'O'),
#   ('action', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('official', 'O'),
#   ('Iraqi', 'I'),
#   ('News', 'I'),
#   ('Agency', 'I'),
#   ('(', 'O'),
#   ('INA', 'I'),
#   (')', 'O'),
#   ('quoted', 'O'),
#   ('Iraq', 'I'),
#   ("'s", 'O'),
#   ('ambassador', 'O'),
#   ('in', 'O'),
#   ('Khartoum', 'I'),
#   ('as', 'O'),
#   ('saying', 'O'),
#   ('that', 'O'),
#   ('Iraq', 'I'),
#   ("'s", 'O'),
#   ('embassy', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('Sudanese', 'I'),
#   ('capital', 'O'),
#   ('had', 'O'),
#   ('nothing', 'O'),
#   ('to', 'O'),
#   ('do', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('Monday', 'O'),
#   ('night', 'O'),
#   ('hijacking', 'O'),
#   ('.', 'O')],
#  [('Iraq', 'I'),
#   ("'s", 'O'),
#   ('ambassador', 'O'),
#   ('in', 'O'),
#   ('Khartoum', 'I'),
#   ('denounced', 'O'),
#   ('the', 'O'),
#   ('hijacking', 'O'),
#   ('and', 'O'),
#   ('described', 'O'),
#   ('it', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('terrorist', 'O'),
#   ('act', 'O'),
#   ('which', 'O'),
#   ('had', 'O'),
#   ('nothing', 'O'),
#   ('to', 'O'),
#   ('do', 'O'),
#   ('"', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('morals', 'O'),
#   ('and', 'O'),
#   ('values', 'O'),
#   ('of', 'O'),
#   ('noble', 'O'),
#   ('Iraqis', 'I'),
#   (',', 'O'),
#   ('"', 'O'),
#   ('INA', 'I'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('Ambassador', 'O'),
#   ('Abdulsamad', 'I'),
#   ('Hameed', 'I'),
#   ('Ali', 'I'),
#   ('told', 'O'),
#   ('INA', 'I'),
#   ('there', 'O'),
#   ('was', 'O'),
#   ('only', 'O'),
#   ('one', 'O'),
#   ('diplomat', 'O'),
#   ('among', 'O'),
#   ('the', 'O'),
#   ('199', 'O'),
#   ('passengers', 'O'),
#   ('and', 'O'),
#   ('crew', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('Sudan', 'I'),
#   ('Airways', 'I'),
#   ('Airbus', 'I'),
#   ('.', 'O')],
#  [('"', 'O'),
#   ('He', 'O'),
#   ('was', 'O'),
#   ('not', 'O'),
#   ('involved', 'O'),
#   ('...', 'O')],
#  [('on', 'O'),
#   ('the', 'O'),
#   ('contrary', 'O'),
#   ('he', 'O'),
#   ('was', 'O'),
#   ('harassed', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('elements', 'O'),
#   ('which', 'O'),
#   ('carried', 'O'),
#   ('out', 'O'),
#   ('the', 'O'),
#   ('hijacking', 'O'),
#   (',', 'O'),
#   ('"', 'O'),
#   ('he', 'O'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('INA', 'I'),
#   ('did', 'O'),
#   ('not', 'O'),
#   ('say', 'O'),
#   ('the', 'O'),
#   ('hijackers', 'O'),
#   ('were', 'O'),
#   ('Iraqis', 'I'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('hijack', 'O'),
#   ('started', 'O'),
#   ('when', 'O'),
#   ('the', 'O'),
#   ('flight', 'O'),
#   ('left', 'O'),
#   ('Khartoum', 'I'),
#   ('for', 'O'),
#   ('Amman', 'I'),
#   ('on', 'O'),
#   ('Monday', 'O'),
#   ('night', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('hijackers', 'O'),
#   ('told', 'O'),
#   ('the', 'O'),
#   ('crew', 'O'),
#   ('they', 'O'),
#   ('had', 'O'),
#   ('grenades', 'O'),
#   ('and', 'O'),
#   ('other', 'O'),
#   ('explosives', 'O'),
#   ('and', 'O'),
#   ('threatened', 'O'),
#   ('to', 'O'),
#   ('blow', 'O'),
#   ('up', 'O'),
#   ('the', 'O'),
#   ('plane', 'O'),
#   ('if', 'O'),
#   ('they', 'O'),
#   ('were', 'O'),
#   ('not', 'O'),
#   ('taken', 'O'),
#   ('to', 'O'),
#   ('London', 'I'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('airliner', 'O'),
#   ('refuelled', 'O'),
#   ('at', 'O'),
#   ('Larnaca', 'I'),
#   (',', 'O'),
#   ('Cyprus', 'I'),
#   ('and', 'O'),
#   ('landed', 'O'),
#   ('at', 'O'),
#   ('London', 'I'),
#   ("'s", 'O'),
#   ('Stansted', 'I'),
#   ('airport', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('early', 'O'),
#   ('hours', 'O'),
#   ('of', 'O'),
#   ('Tuesday', 'O'),
#   ('.', 'O')],
#  [('Seven', 'O'),
#   ('Iraqi', 'I'),
#   ('suspected', 'O'),
#   ('hijackers', 'O'),
#   ('surrendered', 'O'),
#   ('and', 'O'),
#   ('British', 'I'),
#   ('police', 'O'),
#   ('said', 'O'),
#   ('they', 'O'),
#   ('had', 'O'),
#   ('apparently', 'O'),
#   ('asked', 'O'),
#   ('for', 'O'),
#   ('political', 'O'),
#   ('asylum', 'O'),
#   ('.', 'O')],
#  [('Several', 'O'),
#   ('had', 'O'),
#   ('brought', 'O'),
#   ('their', 'O'),
#   ('families', 'O'),
#   ('along', 'O'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('children', 'O'),
#   ('.', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('CRICKET', 'O'),
#   ('-', 'O'),
#   ('ENGLISH', 'I'),
#   ('COUNTY', 'I'),
#   ('CHAMPIONSHIP', 'I'),
#   ('SCORES', 'O'),
#   ('.', 'O')],
#  [('LONDON', 'I'), ('1996-08-22', 'O')],
#  [('Close', 'O'),
#   ('of', 'O'),
#   ('play', 'O'),
#   ('scores', 'O'),
#   ('in', 'O'),
#   ('four-day', 'O')],
#  [('English', 'I'),
#   ('County', 'I'),
#   ('Championship', 'I'),
#   ('cricket', 'O'),
#   ('matches', 'O'),
#   ('on', 'O'),
#   ('Thursday', 'O'),
#   (':', 'O')],
#  [('Second', 'O'), ('day', 'O')],
#  [('At', 'O'),
#   ('Weston-super-Mare', 'I'),
#   (':', 'O'),
#   ('Durham', 'I'),
#   ('326', 'O'),
#   ('(', 'O'),
#   ('D.', 'I'),
#   ('Cox', 'I'),
#   ('95', 'O'),
#   ('not', 'O'),
#   ('out', 'O'),
#   (',', 'O')],
#  [('S.', 'I'),
#   ('Campbell', 'I'),
#   ('69', 'O'),
#   (';', 'O'),
#   ('G.', 'I'),
#   ('Rose', 'I'),
#   ('7-73', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('Somerset', 'I'),
#   ('236-4', 'O'),
#   ('(', 'O'),
#   ('M.', 'I'),
#   ('Lathwell', 'I'),
#   ('85', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('Firsy', 'O'), ('day', 'O')],
#  [('At', 'O'),
#   ('Colchester', 'I'),
#   (':', 'O'),
#   ('Gloucestershire', 'I'),
#   ('280', 'O'),
#   ('(', 'O'),
#   ('J.', 'I'),
#   ('Russell', 'I'),
#   ('63', 'O'),
#   (',', 'O'),
#   ('A.', 'I'),
#   ('Symonds', 'I')],
#  [('52', 'O'),
#   (';', 'O'),
#   ('A.', 'I'),
#   ('Cowan', 'I'),
#   ('5-68', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('Essex', 'I'), ('72-0', 'O'), ('.', 'O')],
#  [('At', 'O'),
#   ('Cardiff', 'I'),
#   (':', 'O'),
#   ('Kent', 'I'),
#   ('128-1', 'O'),
#   ('(', 'O'),
#   ('M.', 'I'),
#   ('Walker', 'I'),
#   ('59', 'O'),
#   (',', 'O'),
#   ('D.', 'I'),
#   ('Fulton', 'I'),
#   ('53', 'O'),
#   ('not', 'O'),
#   ('out', 'O'),
#   (')', 'O'),
#   ('v', 'O')],
#  [('Glamorgan', 'I'), ('.', 'O')],
#  [('At', 'O'),
#   ('Leicester', 'I'),
#   (':', 'O'),
#   ('Leicestershire', 'I'),
#   ('343-8', 'O'),
#   ('(', 'O'),
#   ('P.', 'I'),
#   ('Simmons', 'I'),
#   ('108', 'O'),
#   (',', 'O'),
#   ('P.', 'I'),
#   ('Nixon', 'I')],
#  [('67', 'O'),
#   ('not', 'O'),
#   ('out', 'O'),
#   (')', 'O'),
#   ('v', 'O'),
#   ('Hampshire', 'I'),
#   ('.', 'O')],
#  [('At', 'O'),
#   ('Northampton', 'I'),
#   (':', 'O'),
#   ('Sussex', 'I'),
#   ('368-7', 'O'),
#   ('(', 'O'),
#   ('N.', 'I'),
#   ('Lenham', 'I'),
#   ('145', 'O'),
#   (',', 'O'),
#   ('V.', 'I'),
#   ('Drakes', 'I'),
#   ('59', 'O'),
#   ('not', 'O')],
#  [('out', 'O'),
#   (',', 'O'),
#   ('A.', 'I'),
#   ('Wells', 'I'),
#   ('51', 'O'),
#   (')', 'O'),
#   ('v', 'O'),
#   ('Northamptonshire', 'I'),
#   ('.', 'O')],
#  [('At', 'O'),
#   ('Trent', 'I'),
#   ('Bridge', 'I'),
#   (':', 'O'),
#   ('Nottinghamshire', 'I'),
#   ('392-6', 'O'),
#   ('(', 'O'),
#   ('G.', 'I'),
#   ('Archer', 'I'),
#   ('143', 'O'),
#   ('not', 'O')],
#  [('out', 'O'),
#   (',', 'O'),
#   ('M.', 'I'),
#   ('Dowman', 'I'),
#   ('107', 'O'),
#   (')', 'O'),
#   ('v', 'O'),
#   ('Surrey', 'I'),
#   ('.', 'O')],
#  [('At', 'O'),
#   ('Worcester', 'I'),
#   (':', 'O'),
#   ('Warwickshire', 'I'),
#   ('255-9', 'O'),
#   ('(', 'O'),
#   ('A.', 'I'),
#   ('Giles', 'I'),
#   ('57', 'O'),
#   ('not', 'O'),
#   ('out', 'O'),
#   (',', 'O'),
#   ('W.', 'I'),
#   ('Khan', 'I')],
#  [('52', 'O'), (')', 'O'), ('v', 'O'), ('Worcestershire', 'I'), ('.', 'O')],
#  [('At', 'O'),
#   ('Headingley', 'I'),
#   (':', 'O'),
#   ('Yorkshire', 'I'),
#   ('305-5', 'O'),
#   ('(', 'O'),
#   ('C.', 'I'),
#   ('White', 'I'),
#   ('66', 'O'),
#   ('not', 'O'),
#   ('out', 'O'),
#   (',', 'O'),
#   ('M.', 'I'),
#   ('Moxon', 'I')],
#  [('66', 'O'),
#   (',', 'O'),
#   ('M.', 'I'),
#   ('Vaughan', 'I'),
#   ('57', 'O'),
#   (')', 'O'),
#   ('v', 'O'),
#   ('Lancashire', 'I'),
#   ('.', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('Moroccan', 'I'),
#   ('King', 'O'),
#   ('meets', 'O'),
#   ('former', 'O'),
#   ('Israel', 'I'),
#   ('PM', 'O'),
#   ('Peres', 'I'),
#   ('.', 'O')],
#  [('SKHIRAT', 'I'), (',', 'O'), ('Morocco', 'I'), ('1996-08-29', 'O')],
#  [('King', 'I'),
#   ('Hassan', 'I'),
#   ('of', 'O'),
#   ('Morocco', 'I'),
#   ('met', 'O'),
#   ('former', 'O'),
#   ('Israeli', 'I'),
#   ('prime', 'O'),
#   ('minister', 'O'),
#   ('Shimon', 'I'),
#   ('Peres', 'I'),
#   ('on', 'O'),
#   ('Thursday', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('coastal', 'O'),
#   ('resort', 'O'),
#   ('of', 'O'),
#   ('Skhirat', 'I'),
#   (',', 'O'),
#   ('20', 'O'),
#   ('km', 'O'),
#   ('(', 'O'),
#   ('12', 'O'),
#   ('miles', 'O'),
#   (')', 'O'),
#   ('south', 'O'),
#   ('of', 'O'),
#   ('Rabat', 'I'),
#   (',', 'O'),
#   ('an', 'O'),
#   ('official', 'O'),
#   ('source', 'O'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('"', 'O'),
#   ('Mr', 'O'),
#   ('Shimon', 'I'),
#   ('Peres', 'I'),
#   (',', 'O'),
#   ('who', 'O'),
#   ('is', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('purely', 'O'),
#   ('private', 'O'),
#   ('and', 'O'),
#   ('family', 'O'),
#   ('visit', 'O'),
#   ('to', 'O'),
#   ('Morocco', 'I'),
#   (',', 'O'),
#   ('was', 'O'),
#   ('received', 'O'),
#   ('on', 'O'),
#   ('Thursday', 'O'),
#   ('by', 'O'),
#   ('his', 'O'),
#   ('Majesty', 'O'),
#   ('King', 'I'),
#   ('Hassan', 'I'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('royal', 'O'),
#   ('palace', 'O'),
#   ('of', 'O'),
#   ('Skhirat', 'I'),
#   (',', 'O'),
#   ('"', 'O'),
#   ('the', 'O'),
#   ('source', 'O'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('Accompanied', 'O'),
#   ('by', 'O'),
#   ('his', 'O'),
#   ('wife', 'O'),
#   ('and', 'O'),
#   ('grandson', 'O'),
#   (',', 'O'),
#   ('Peres', 'I'),
#   ('arrived', 'O'),
#   ('in', 'O'),
#   ('Morocco', 'I'),
#   ('on', 'O'),
#   ('August', 'O'),
#   ('25', 'O'),
#   ('.', 'O')],
#  [('Peres', 'I'),
#   ('is', 'O'),
#   ('expected', 'O'),
#   ('to', 'O'),
#   ('fly', 'O'),
#   ('home', 'O'),
#   ('on', 'O'),
#   ('Friday', 'O'),
#   (',', 'O'),
#   ('officials', 'O'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('HK', 'I'),
#   ('civil', 'O'),
#   ('servants', 'O'),
#   ('contest', 'O'),
#   ('ban', 'O'),
#   ('on', 'O'),
#   ('China', 'I'),
#   ('panel', 'O'),
#   ('.', 'O')],
#  [('HONG', 'I'), ('KONG', 'I'), ('1996-08-29', 'O')],
#  [('Senior', 'O'),
#   ('Hong', 'I'),
#   ('Kong', 'I'),
#   ('civil', 'O'),
#   ('servants', 'O'),
#   ('were', 'O'),
#   ('given', 'O'),
#   ('the', 'O'),
#   ('go-ahead', 'O'),
#   ('on', 'O'),
#   ('Thursday', 'O'),
#   ('to', 'O'),
#   ('challenge', 'O'),
#   ('a', 'O'),
#   ('government', 'O'),
#   ('ban', 'O'),
#   ('on', 'O'),
#   ('them', 'O'),
#   ('standing', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('Beijing-backed', 'I'),
#   ('panel', 'O'),
#   ('to', 'O'),
#   ('choose', 'O'),
#   ('the', 'O'),
#   ('territory', 'O'),
#   ("'s", 'O'),
#   ('first', 'O'),
#   ('post-handover', 'O'),
#   ('leader', 'O'),
#   ('and', 'O'),
#   ('lawmakers', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('Supreme', 'I'),
#   ('Court', 'I'),
#   ('ruled', 'O'),
#   ('that', 'O'),
#   ('a', 'O'),
#   ('judicial', 'O'),
#   ('hearing', 'O'),
#   ('contesting', 'O'),
#   ('the', 'O'),
#   ('ban', 'O'),
#   ('would', 'O'),
#   ('be', 'O'),
#   ('heard', 'O'),
#   ('on', 'O'),
#   ('September', 'O'),
#   ('11', 'O'),
#   (',', 'O'),
#   ('three', 'O'),
#   ('days', 'O'),
#   ('before', 'O'),
#   ('the', 'O'),
#   ('nomination', 'O'),
#   ('period', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('Selection', 'I'),
#   ('Committee', 'I'),
#   ('closes', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('government', 'O'),
#   ('maintains', 'O'),
#   ('the', 'O'),
#   ('ban', 'O'),
#   (',', 'O'),
#   ('announced', 'O'),
#   ('earlier', 'O'),
#   ('this', 'O'),
#   ('month', 'O'),
#   (',', 'O'),
#   ('is', 'O'),
#   ('necessary', 'O'),
#   ('to', 'O'),
#   ('avoid', 'O'),
#   ('a', 'O'),
#   ('possible', 'O'),
#   ('conflict', 'O'),
#   ('of', 'O'),
#   ('interest', 'O'),
#   ('because', 'O'),
#   ('civil', 'O'),
#   ('servants', 'O'),
#   ('are', 'O'),
#   ('involved', 'O'),
#   ('in', 'O'),
#   ('determining', 'O'),
#   ('government', 'O'),
#   ('policy', 'O'),
#   ('.', 'O')],
#  [('Civil', 'O'),
#   ('servants', 'O'),
#   ('argue', 'O'),
#   ('the', 'O'),
#   ('ban', 'O'),
#   ('stymies', 'O'),
#   ('their', 'O'),
#   ('political', 'O'),
#   ('rights', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('400-strong', 'O'),
#   ('Selection', 'I'),
#   ('Committee', 'I'),
#   ('will', 'O'),
#   ('select', 'O'),
#   ('Hong', 'I'),
#   ('Kong', 'I'),
#   ("'s", 'O'),
#   ('future', 'O'),
#   ('chief', 'O'),
#   ('executive', 'O'),
#   ('to', 'O'),
#   ('replace', 'O'),
#   ('the', 'O'),
#   ('British', 'I'),
#   ('governor', 'O'),
#   ('and', 'O'),
#   ('a', 'O'),
#   ('provisional', 'O'),
#   ('legislature', 'O'),
#   ('to', 'O'),
#   ('take', 'O'),
#   ('over', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('elected', 'O'),
#   ('chamber', 'O'),
#   ('which', 'O'),
#   ('Beijing', 'I'),
#   ('plans', 'O'),
#   ('to', 'O'),
#   ('dissolve', 'O'),
#   ('.', 'O')],
#  [('Hong', 'I'),
#   ('Kong', 'I'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('British', 'I'),
#   ('colony', 'O'),
#   ('for', 'O'),
#   ('more', 'O'),
#   ('than', 'O'),
#   ('150', 'O'),
#   ('years', 'O'),
#   (',', 'O'),
#   ('will', 'O'),
#   ('be', 'O'),
#   ('handed', 'O'),
#   ('back', 'O'),
#   ('to', 'O'),
#   ('China', 'I'),
#   ('at', 'O'),
#   ('midnight', 'O'),
#   ('on', 'O'),
#   ('June', 'O'),
#   ('30', 'O'),
#   ('next', 'O'),
#   ('year', 'O'),
#   ('.', 'O')],
#  [('China', 'I'),
#   ('intends', 'O'),
#   ('to', 'O'),
#   ('dismantle', 'O'),
#   ('the', 'O'),
#   ('territory', 'O'),
#   ("'s", 'O'),
#   ('first', 'O'),
#   ('fully-elected', 'O'),
#   ('legislature', 'O'),
#   ('because', 'O'),
#   ('it', 'O'),
#   ('opposes', 'O'),
#   ('Britain', 'I'),
#   ("'s", 'O'),
#   ('recent', 'O'),
#   ('electoral', 'O'),
#   ('reforms', 'O'),
#   ('and', 'O'),
#   ('install', 'O'),
#   ('an', 'O'),
#   ('interim', 'O'),
#   ('appointed', 'O'),
#   ('chamber', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('decision', 'O'),
#   ('that', 'O'),
#   ('has', 'O'),
#   ('generated', 'O'),
#   ('considerable', 'O'),
#   ('controversy', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('judicial', 'O'),
#   ('review', 'O'),
#   ('sought', 'O'),
#   ('by', 'O'),
#   ('directorate-grade', 'O'),
#   ('bureaucrats', 'O'),
#   ('will', 'O'),
#   ('apply', 'O'),
#   ('to', 'O'),
#   ('only', 'O'),
#   ('about', 'O'),
#   ('1,000', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('approximately', 'O'),
#   ('33,000', 'O'),
#   ('civil', 'O'),
#   ('servants', 'O'),
#   ('affected', 'O'),
#   ('.', 'O')],
#  [('Police', 'O'),
#   ('unions', 'O'),
#   ('are', 'O'),
#   ('not', 'O'),
#   ('contesting', 'O'),
#   ('the', 'O'),
#   ('ban', 'O'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('affects', 'O'),
#   ('all', 'O'),
#   ('27,000', 'O'),
#   ('officers', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('nor', 'O'),
#   ('are', 'O'),
#   ('the', 'O'),
#   ('very', 'O'),
#   ('top', 'O'),
#   ('tier', 'O'),
#   ('of', 'O'),
#   ('Hong', 'I'),
#   ('Kong', 'I'),
#   ("'s", 'O'),
#   ('mandarin', 'O'),
#   ('class', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('policy', 'O'),
#   ('secretaries', 'O'),
#   ('.', 'O')],
#  [('More', 'O'),
#   ('than', 'O'),
#   ('16,000', 'O'),
#   ('application', 'O'),
#   ('forms', 'O'),
#   ('for', 'O'),
#   ('places', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('Selection', 'I'),
#   ('Committee', 'I'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('handed', 'O'),
#   ('out', 'O'),
#   ('since', 'O'),
#   ('the', 'O'),
#   ('nomination', 'O'),
#   ('period', 'O'),
#   ('opened', 'O'),
#   ('.', 'O')],
#  [('It', 'O'),
#   ('closes', 'O'),
#   ('on', 'O'),
#   ('September', 'O'),
#   ('14', 'O'),
#   ('.', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('MOTOCROSS', 'O'),
#   ('-', 'O'),
#   ('SWEDISH', 'I'),
#   ('500CC', 'O'),
#   ('GRAND', 'I'),
#   ('PRIX', 'I'),
#   ('RESULTS', 'O'),
#   ('.', 'O')],
#  [('LANDSKRONA', 'I'), (',', 'O'), ('Sweden', 'I'), ('1996-08-25', 'O')],
#  [('Leading', 'O'), ('results', 'O'), ('in', 'O'), ('the', 'O')],
#  [('Swedish', 'I'),
#   ('500cc', 'O'),
#   ('motocross', 'O'),
#   ('Grand', 'I'),
#   ('Prix', 'I'),
#   ('on', 'O'),
#   ('Sunday', 'O'),
#   (':', 'O')],
#  [('First', 'O'), ('race', 'O')],
#  [('1.', 'O'),
#   ('Joel', 'I'),
#   ('Smets', 'I'),
#   ('(', 'O'),
#   ('Belgium', 'I'),
#   (')', 'O'),
#   ('Husaberg', 'I')],
#  [('2.', 'O'),
#   ('Peter', 'I'),
#   ('Johansson', 'I'),
#   ('(', 'O'),
#   ('Sweden', 'I'),
#   (')', 'O'),
#   ('Husqvarna', 'I')],
#  [('3.', 'O'),
#   ('Gert', 'I'),
#   ('Jan', 'I'),
#   ('Van', 'I'),
#   ('Doorn', 'I'),
#   ('(', 'O'),
#   ('Netherlands', 'I'),
#   (')', 'O'),
#   ('Honda', 'I')],
#  [('4.', 'O'),
#   ('Jacky', 'I'),
#   ('Martens', 'I'),
#   ('(', 'O'),
#   ('Belgium', 'I'),
#   (')', 'O'),
#   ('Husqvarna', 'I')],
#  [('5.', 'O'),
#   ('Peter', 'I'),
#   ('Dirkx', 'I'),
#   ('(', 'O'),
#   ('Belgium', 'I'),
#   (')', 'O'),
#   ('KTM', 'I')],
#  [('6.', 'O'),
#   ('Danny', 'I'),
#   ('Theybers', 'I'),
#   ('(', 'O'),
#   ('Belgium', 'I'),
#   (')', 'O'),
#   ('Honda', 'I')],
#  [('Second', 'O'), ('race', 'O')],
#  [('1.', 'O'),
#   ('Shayne', 'I'),
#   ('King', 'I'),
#   ('(', 'O'),
#   ('New', 'I'),
#   ('Zealand', 'I'),
#   (')', 'O'),
#   ('KTM', 'I')],
#  [('2.', 'O'), ('Martens', 'I')],
#  [('3.', 'O'), ('Theybers', 'I')],
#  [('4.', 'O'),
#   ('Johan', 'I'),
#   ('Boonen', 'I'),
#   ('(', 'O'),
#   ('Belgium', 'I'),
#   (')', 'O'),
#   ('Husqvarna', 'I')],
#  [('5.', 'O'),
#   ('Dietmar', 'I'),
#   ('Lalcher', 'I'),
#   ('(', 'O'),
#   ('Germany', 'I'),
#   (')', 'O'),
#   ('Honda', 'I')],
#  [('6.', 'O'),
#   ('Claus', 'I'),
#   ('Manne', 'I'),
#   ('Nielsen', 'I'),
#   ('(', 'O'),
#   ('Denmark', 'I'),
#   (')', 'O'),
#   ('KTM', 'I')],
#  [('Overall', 'O'), ('on', 'O'), ('day', 'O'), (':', 'O')],
#  [('1.', 'O'), ('Martens', 'I'), ('30', 'O'), ('points', 'O')],
#  [('2.', 'O'), ('Shayne', 'I'), ('King', 'I'), ('28', 'O')],
#  [('3.', 'O'), ('Smets', 'I'), ('27', 'O')],
#  [('4.', 'O'), ('Theybers', 'I'), ('25', 'O')],
#  [('5.', 'O'), ('Van', 'I'), ('Doorn', 'I'), ('24', 'O')],
#  [('6.', 'O'), ('Johansson', 'I'), ('17', 'O')],
#  [('World', 'O'),
#   ('championship', 'O'),
#   ('standings', 'O'),
#   ('(', 'O'),
#   ('after', 'O'),
#   ('11', 'O'),
#   ('of', 'O'),
#   ('12', 'O'),
#   ('rounds', 'O'),
#   (')', 'O'),
#   (':', 'O')],
#  [('1.', 'O'), ('Shayne', 'I'), ('King', 'I'), ('323', 'O'), ('points', 'O')],
#  [('2.', 'O'), ('Smets', 'I'), ('290', 'O')],
#  [('3.', 'O'), ('Johansson', 'I'), ('236', 'O')],
#  [('4.', 'O'), ('Lacher', 'I'), ('219', 'O')],
#  [('5.', 'O'),
#   ('Darryll', 'I'),
#   ('King', 'I'),
#   ('(', 'O'),
#   ('New', 'I'),
#   ('Zealand', 'I'),
#   (')', 'O'),
#   ('Honda', 'I'),
#   ('178', 'O')],
#  [('6.', 'O'), ('Van', 'I'), ('Doorn', 'I'), ('176', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('Belgian', 'I'),
#   ('police', 'O'),
#   ('arrest', 'O'),
#   ('detective', 'O'),
#   ('in', 'O'),
#   ('Dutroux', 'I'),
#   ('affair', 'O'),
#   ('.', 'O')],
#  [('Geert', 'I'), ('de', 'I'), ('Clercq', 'I')],
#  [('NEUFCHATEAU', 'I'), (',', 'O'), ('Belgium', 'I'), ('1996-08-25', 'O')],
#  [('Investigators', 'O'),
#   ('arrested', 'O'),
#   ('a', 'O'),
#   ('senior', 'O'),
#   ('police', 'O'),
#   ('detective', 'O'),
#   ('on', 'O'),
#   ('Sunday', 'O'),
#   ('in', 'O'),
#   ('connection', 'O'),
#   ('with', 'O'),
#   ('their', 'O'),
#   ('inquiries', 'O'),
#   ('into', 'O'),
#   ('Belgium', 'I'),
#   ("'s", 'O'),
#   ('child', 'O'),
#   ('sex', 'O'),
#   ('scandal', 'O'),
#   (',', 'O'),
#   ('Public', 'O'),
#   ('Prosecutor', 'O'),
#   ('Michel', 'I'),
#   ('Bourlet', 'I'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('"', 'O'),
#   ('Georges', 'I'),
#   ('Zicot', 'I'),
#   ('was', 'O'),
#   ('arrested', 'O'),
#   ('and', 'O'),
#   ('will', 'O'),
#   ('be', 'O'),
#   ('charged', 'O'),
#   ('with', 'O'),
#   ('truck', 'O'),
#   ('theft', 'O'),
#   (',', 'O'),
#   ('insurance', 'O'),
#   ('fraud', 'O'),
#   ('and', 'O'),
#   ('document', 'O'),
#   ('forgery', 'O'),
#   (',', 'O'),
#   ('"', 'O'),
#   ('Bourlet', 'I'),
#   ('told', 'O'),
#   ('a', 'O'),
#   ('news', 'O'),
#   ('conference', 'O'),
#   ('.', 'O')],
#  [('He', 'O'),
#   ('said', 'O'),
#   ('there', 'O'),
#   ('had', 'O'),
#   ('been', 'O'),
#   ('searches', 'O'),
#   ('at', 'O'),
#   ('three', 'O'),
#   ('sites', 'O'),
#   ('on', 'O'),
#   ('Sunday', 'O'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('one', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('Charleroi', 'I'),
#   ('judicial', 'O'),
#   ('police', 'O'),
#   ('headquarters', 'O'),
#   ('where', 'O'),
#   ('Zicot', 'I'),
#   ('worked', 'O'),
#   ('.', 'O')],
#  [('Zicot', 'I'),
#   (',', 'O'),
#   ('45', 'O'),
#   (',', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('specialist', 'O'),
#   ('in', 'O'),
#   ('tackling', 'O'),
#   ('vehicle', 'O'),
#   ('theft', 'O'),
#   ('.', 'O')],
#  [('Belgian', 'I'),
#   ('media', 'O'),
#   ('reported', 'O'),
#   ('that', 'O'),
#   ('he', 'O'),
#   ('had', 'O'),
#   ('been', 'O'),
#   ('questioned', 'O'),
#   ('twice', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('past', 'O'),
#   ('two', 'O'),
#   ('years', 'O'),
#   ('about', 'O'),
#   ('thefts', 'O'),
#   ('but', 'O'),
#   ('released', 'O'),
#   ('both', 'O'),
#   ('times', 'O'),
#   ('.', 'O')],
#  [('He', 'O'),
#   ('was', 'O'),
#   ('promoted', 'O'),
#   ('to', 'O'),
#   ('chief', 'O'),
#   ('detective', 'O'),
#   ('earlier', 'O'),
#   ('this', 'O'),
#   ('year', 'O'),
#   ('.', 'O')],
#  [('Bourlet', 'I'),
#   ('said', 'O'),
#   ('two', 'O'),
#   ('other', 'O'),
#   ('people', 'O'),
#   ('had', 'O'),
#   ('also', 'O'),
#   ('been', 'O'),
#   ('arrested', 'O'),
#   ('.', 'O')],
#  [('One', 'O'),
#   ('was', 'O'),
#   ('Gerard', 'I'),
#   ('Pignon', 'I'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('owner', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('warehouse', 'O'),
#   ('where', 'O'),
#   ('stolen', 'O'),
#   ('vehicles', 'O'),
#   ('were', 'O'),
#   ('allegedly', 'O'),
#   ('stored', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('other', 'O'),
#   ('was', 'O'),
#   ('insurer', 'O'),
#   ('Thierry', 'I'),
#   ('Dehaan', 'I'),
#   ('.', 'O')],
#  [('Bourlet', 'I'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('investigation', 'O'),
#   ('into', 'O'),
#   ('the', 'O'),
#   ('vehicle', 'O'),
#   ('theft', 'O'),
#   ('ring', 'O'),
#   ('would', 'O'),
#   ('be', 'O'),
#   ('added', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('inquiry', 'O'),
#   ('into', 'O'),
#   ('the', 'O'),
#   ('paedophile', 'O'),
#   ('sex', 'O'),
#   ('scandal', 'O'),
#   ('in', 'O'),
#   ('which', 'O'),
#   ('five', 'O'),
#   ('other', 'O'),
#   ('people', 'O'),
#   ('have', 'O'),
#   ('already', 'O'),
#   ('been', 'O'),
#   ('arrested', 'O'),
#   ('.', 'O')],
#  [('He', 'O'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('connection', 'O'),
#   ('was', 'O'),
#   ('through', 'O'),
#   ('Bernard', 'I'),
#   ('Weinstein', 'I'),
#   (',', 'O'),
#   ('an', 'O'),
#   ('accomplice', 'O'),
#   ('of', 'O'),
#   ('convicted', 'O'),
#   ('child', 'O'),
#   ('rapist', 'O'),
#   ('Marc', 'I'),
#   ('Dutroux', 'I'),
#   ('--', 'O'),
#   ('the', 'O'),
#   ('central', 'O'),
#   ('figure', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('paedophile', 'O'),
#   ('scandal', 'O'),
#   ('that', 'O'),
#   ('has', 'O'),
#   ('sent', 'O'),
#   ('shockwaves', 'O'),
#   ('across', 'O'),
#   ('Europe', 'I'),
#   ('.', 'O')],
#  [('Weinstein', 'I'),
#   ('was', 'O'),
#   ('found', 'O'),
#   ('dead', 'O'),
#   ('last', 'O'),
#   ('weekend', 'O'),
#   ('alongside', 'O'),
#   ('the', 'O'),
#   ('bodies', 'O'),
#   ('of', 'O'),
#   ('eight-year-olds', 'O'),
#   ('Julie', 'I'),
#   ('Lejeune', 'I'),
#   ('and', 'O'),
#   ('Melissa', 'I'),
#   ('Russo', 'I'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('house', 'O'),
#   ('belonging', 'O'),
#   ('to', 'O'),
#   ('Detroux', 'I'),
#   (',', 'O'),
#   ('who', 'O'),
#   ('said', 'O'),
#   ('they', 'O'),
#   ('starved', 'O'),
#   ('to', 'O'),
#   ('death', 'O'),
#   ('earlier', 'O'),
#   ('this', 'O'),
#   ('year', 'O'),
#   (',', 'O'),
#   ('nine', 'O'),
#   ('months', 'O'),
#   ('after', 'O'),
#   ('being', 'O'),
#   ('abducted', 'O'),
#   ('in', 'O'),
#   ('June', 'O'),
#   ('1995', 'O'),
#   ('.', 'O')],
#  [('Two', 'O'),
#   ('other', 'O'),
#   ('girls', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('rescued', 'O'),
#   ('and', 'O'),
#   ('police', 'O'),
#   ('are', 'O'),
#   ('hunting', 'O'),
#   ('for', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('two', 'O'),
#   ('more', 'O'),
#   ('who', 'O'),
#   ('Dutroux', 'I'),
#   ('has', 'O'),
#   ('admitted', 'O'),
#   ('kidnapping', 'O'),
#   ('a', 'O'),
#   ('year', 'O'),
#   ('ago', 'O'),
#   ('.', 'O')],
#  [('"', 'O'),
#   ('Dutroux', 'I'),
#   ('has', 'O'),
#   ('admitted', 'O'),
#   ('killing', 'O'),
#   ('Weinstein', 'I'),
#   ('after', 'O'),
#   ('a', 'O'),
#   ('disagreement', 'O'),
#   ('between', 'O'),
#   ('the', 'O'),
#   ('accomplices', 'O'),
#   ('in', 'O'),
#   ('an', 'O'),
#   ('affair', 'O'),
#   ('of', 'O'),
#   ('truck', 'O'),
#   ('theft', 'O'),
#   (',', 'O'),
#   ('"', 'O'),
#   ('Bourlet', 'I'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('Another', 'O'),
#   ('four', 'O'),
#   ('people', 'O'),
#   ('were', 'O'),
#   ('also', 'O'),
#   ('questioned', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('weekend', 'O'),
#   ('but', 'O'),
#   ('had', 'O'),
#   ('not', 'O'),
#   ('been', 'O'),
#   ('detained', 'O'),
#   (',', 'O'),
#   ('Bourlet', 'I'),
#   ('added', 'O'),
#   ('.', 'O')],
#  [('Anne', 'I'),
#   ('Thily', 'I'),
#   (',', 'O'),
#   ('public', 'O'),
#   ('prosecutor', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('eastern', 'O'),
#   ('city', 'O'),
#   ('of', 'O'),
#   ('Liege', 'I'),
#   ('where', 'O'),
#   ('Julie', 'I'),
#   ('and', 'O'),
#   ('Melissa', 'I'),
#   ('lived', 'O'),
#   (',', 'O'),
#   ('said', 'O'),
#   ('this', 'O'),
#   ('was', 'O'),
#   ('a', 'O'),
#   ('major', 'O'),
#   ('case', 'O'),
#   ('involving', 'O'),
#   ('some', 'O'),
#   ('50', 'O'),
#   ('investigators', 'O'),
#   ('--', 'O'),
#   ('including', 'O'),
#   ('two', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('U.S.', 'I'),
#   ('Federal', 'I'),
#   ('Bureau', 'I'),
#   ('of', 'I'),
#   ('Investigation', 'I'),
#   ('.', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('Dhaka', 'I'),
#   ('stocks', 'O'),
#   ('end', 'O'),
#   ('up', 'O'),
#   ('on', 'O'),
#   ('gains', 'O'),
#   ('by', 'O'),
#   ('engineering', 'O'),
#   (',', 'O'),
#   ('banks', 'O'),
#   ('.', 'O')],
#  [('DHAKA', 'I'), ('1996-08-22', 'O')],
#  [('Dhaka', 'I'),
#   ('stocks', 'O'),
#   ('edged', 'O'),
#   ('up', 'O'),
#   ('on', 'O'),
#   ('sharply', 'O'),
#   ('higher', 'O'),
#   ('volume', 'O'),
#   ('as', 'O'),
#   ('engineering', 'O'),
#   ('and', 'O'),
#   ('cash', 'O'),
#   ('shares', 'O'),
#   ('gained', 'O'),
#   ('amid', 'O'),
#   ('buying', 'O'),
#   ('by', 'O'),
#   ('both', 'O'),
#   ('small', 'O'),
#   ('and', 'O'),
#   ('institutional', 'O'),
#   ('investors', 'O'),
#   (',', 'O'),
#   ('brokers', 'O'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('Dhaka', 'I'),
#   ('Stock', 'I'),
#   ('Exchange', 'I'),
#   ('(', 'O'),
#   ('DSE', 'I'),
#   (')', 'O'),
#   ('all-share', 'O'),
#   ('price', 'O'),
#   ('index', 'O'),
#   ('rose', 'O'),
#   ('8.05', 'O'),
#   ('points', 'O'),
#   ('or', 'O'),
#   ('0.7', 'O'),
#   ('percent', 'O'),
#   ('to', 'O'),
#   ('1,156.79', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('turnover', 'O'),
#   ('of', 'O'),
#   ('146.2', 'O'),
#   ('million', 'O'),
#   ('taka', 'O'),
#   ('.', 'O')],
#  [('Of', 'O'),
#   ('the', 'O'),
#   ('total', 'O'),
#   ('119', 'O'),
#   ('issues', 'O'),
#   ('traded', 'O'),
#   ('71', 'O'),
#   ('closed', 'O'),
#   ('higher', 'O'),
#   (',', 'O'),
#   ('44', 'O'),
#   ('ended', 'O'),
#   ('lower', 'O'),
#   ('and', 'O'),
#   ('four', 'O'),
#   ('remained', 'O'),
#   ('unchanged', 'O'),
#   ('.', 'O')],
#  [('.', 'O')],
#  [('National', 'I'),
#   ('Bank', 'I'),
#   ('rose', 'O'),
#   ('12.71', 'O'),
#   ('taka', 'O'),
#   ('to', 'O'),
#   ('228.7', 'O'),
#   (',', 'O'),
#   ('Eastern', 'I'),
#   ('Cables', 'I'),
#   ('gained', 'O'),
#   ('20.37', 'O'),
#   ('to', 'O'),
#   ('677.98', 'O'),
#   ('and', 'O'),
#   ('Apex', 'I'),
#   ('Tannery', 'I'),
#   ('lost', 'O'),
#   ('22.72', 'O'),
#   ('to', 'O'),
#   ('597', 'O'),
#   ('.', 'O')],
#  [('Brokers', 'O'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('stocks', 'O'),
#   ('recovered', 'O'),
#   ('early', 'O'),
#   ('losses', 'O'),
#   ('to', 'O'),
#   ('edge', 'O'),
#   ('up', 'O'),
#   ('at', 'O'),
#   ('close', 'O'),
#   ('because', 'O'),
#   ('of', 'O'),
#   ('institutional', 'O'),
#   ('support', 'O'),
#   ('and', 'O'),
#   ('short-covering', 'O'),
#   ('ahead', 'O'),
#   ('of', 'O'),
#   ('Friday', 'O'),
#   ('weekend', 'O'),
#   ('.', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('Key', 'O'),
#   ('stock', 'O'),
#   ('and', 'O'),
#   ('currency', 'O'),
#   ('market', 'O'),
#   ('movements', 'O'),
#   ('at', 'O'),
#   ('1600', 'O'),
#   ('GMT', 'I'),
#   ('.', 'O')],
#  [('LONDON', 'I'), ('1996-08-23', 'O')],
#  [('The', 'O'),
#   ('following', 'O'),
#   ('table', 'O'),
#   ('shows', 'O'),
#   ('the', 'O'),
#   ('latest', 'O'),
#   ('close', 'O'),
#   ('of', 'O'),
#   ('key', 'O'),
#   ('indices*', 'O'),
#   ('on', 'O'),
#   ('major', 'O'),
#   ('world', 'O'),
#   ('stock', 'O'),
#   ('exchanges', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('day', 'O'),
#   ("'s", 'O'),
#   ('change', 'O'),
#   ('in', 'O'),
#   ('points', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('indices', 'O'),
#   ("'", 'O'),
#   ('1996', 'O'),
#   ('closing', 'O'),
#   ('highs', 'O'),
#   ('and', 'O'),
#   ('lows', 'O'),
#   ('(', 'O'),
#   ('with', 'O'),
#   ('dates', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('Also', 'O'),
#   ('shown', 'O'),
#   ('are', 'O'),
#   ('the', 'O'),
#   ('London', 'I'),
#   ('closing', 'O'),
#   ('values', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('German', 'I'),
#   ('mark', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('Japanese', 'I'),
#   ('yen', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('British', 'I'),
#   ('pound', 'O'),
#   ('and', 'O'),
#   ('gold', 'O'),
#   ('bullion', 'O'),
#   ('(', 'O'),
#   ('previous', 'O'),
#   ('day', 'O'),
#   ("'s", 'O'),
#   ('closes', 'O'),
#   ('in', 'O'),
#   ('brackets', 'O'),
#   (')', 'O'),
#   (':', 'O')],
#  [('AUG', 'O'),
#   ('23', 'O'),
#   ('DAY', 'O'),
#   ("'S", 'O'),
#   ('CHANGE', 'O'),
#   ('1996', 'O'),
#   ('HIGH', 'O'),
#   ('1996', 'O'),
#   ('LOW', 'O')],
#  [('CLOSE', 'O'), ('IN', 'O'), ('POINTS', 'O')],
#  [('NEW', 'I'),
#   ('YORK', 'I'),
#   ('5,710.53', 'O'),
#   ('-', 'O'),
#   ('22.94', 'O'),
#   ('5,778.00', 'O'),
#   ('5,032.94', 'O')],
#  [('(', 'O'),
#   ('midday', 'O'),
#   (')', 'O'),
#   ('(', 'O'),
#   ('May', 'O'),
#   ('22', 'O'),
#   (')', 'O'),
#   ('(', 'O'),
#   ('Jan', 'O'),
#   ('10', 'O'),
#   (')', 'O')],
#  [('LONDON', 'I'),
#   ('3,907.5', 'O'),
#   ('+16.4', 'O'),
#   ('3,907.5', 'O'),
#   ('3,632.3', 'O')],
#  [('(', 'O'),
#   ('Aug', 'O'),
#   ('23', 'O'),
#   (')', 'O'),
#   ('(', 'O'),
#   ('Jul', 'O'),
#   ('16', 'O'),
#   (')', 'O')],
#  [('TOKYO', 'I'),
#   ('21,228.80', 'O'),
#   ('-', 'O'),
#   ('134.44', 'O'),
#   ('22,666.80', 'O'),
#   ('19,734.70', 'O')],
#  [('(', 'O'),
#   ('Jun', 'O'),
#   ('26', 'O'),
#   (')', 'O'),
#   ('(', 'O'),
#   ('Mar', 'O'),
#   ('13', 'O'),
#   (')', 'O')],
#  [('FRANKFURT', 'I'),
#   ('2,555.16', 'O'),
#   ('-', 'O'),
#   ('2.10', 'O'),
#   ('2,583.49', 'O'),
#   (')', 'O'),
#   ('2,284.86', 'O')],
#  [('(', 'O'),
#   ('Jul', 'O'),
#   ('5', 'O'),
#   (')', 'O'),
#   ('(', 'O'),
#   ('Jan', 'O'),
#   ('2', 'O'),
#   (')', 'O')],
#  [('PARIS', 'I'),
#   ('2,020.82', 'O'),
#   ('+3.06', 'O'),
#   ('2,146.79', 'O'),
#   ('1,897.85', 'O')],
#  [('(', 'O'),
#   ('Apr', 'O'),
#   ('30', 'O'),
#   (')', 'O'),
#   ('(', 'O'),
#   ('Jan', 'O'),
#   ('11', 'O'),
#   (')', 'O')],
#  [('SYDNEY', 'I'),
#   ('2,292.9', 'O'),
#   ('+18.3', 'O'),
#   ('2,326.00', 'O'),
#   ('2,096.10', 'O')],
#  [('(', 'O'),
#   ('Apr', 'O'),
#   ('26', 'O'),
#   (')', 'O'),
#   ('(', 'O'),
#   ('Jul', 'O'),
#   ('17', 'O'),
#   (')', 'O')],
#  [('HONG', 'I'),
#   ('KONG', 'I'),
#   ('11,424.64', 'O'),
#   ('-', 'O'),
#   ('54.13', 'O'),
#   ('11,594.99', 'O'),
#   ('10,204.87', 'O')],
#  [('(', 'O'),
#   ('Feb', 'O'),
#   ('16', 'O'),
#   (')', 'O'),
#   ('(', 'O'),
#   ('Jan', 'O'),
#   ('2', 'O'),
#   (')', 'O')],
#  [('-', 'O'), ('-', 'O'), ('-', 'O'), ('-', 'O')],
#  [('FOREIGN', 'O'),
#   ('EXCHANGE', 'O'),
#   ('/', 'O'),
#   ('GOLD', 'O'),
#   ('BULLION', 'O'),
#   ('CLOSE', 'O'),
#   ('IN', 'O'),
#   ('LONDON', 'I')],
#  [('Dollar', 'O'), ('/', 'O'), ('mark', 'O'), ('...', 'O')],
#  [('1.4871', 'O'), ('(', 'O'), ('1.4935', 'O'), (')', 'O')],
#  [('Dollar', 'O'), ('/', 'O'), ('yen', 'O'), ('....', 'O')],
#  [('108.50', 'O'), ('(', 'O'), ('108.43', 'O'), (')', 'O')],
#  [('Pound', 'O'), ('/', 'O'), ('dollar', 'O'), ('..', 'O')],
#  [('$', 'O'),
#   ('1.5520', 'O'),
#   ('(', 'O'),
#   ('$', 'O'),
#   ('1.5497', 'O'),
#   (')', 'O')],
#  [('Gold', 'O'), ('(', 'O'), ('ounce', 'O'), (')', 'O'), ('..', 'O')],
#  [('$', 'O'),
#   ('387.50', 'O'),
#   ('(', 'O'),
#   ('$', 'O'),
#   ('386.95', 'O'),
#   (')', 'O')],
#  [('-', 'O'), ('-', 'O'), ('-', 'O'), ('-', 'O')],
#  [('*INDICES', 'O'),
#   ('USED', 'O'),
#   ('AND', 'O'),
#   ('THEIR', 'O'),
#   ('ALL-TIME', 'O'),
#   ('CLOSING', 'O'),
#   ('HIGHS', 'O')],
#  [('New', 'I'),
#   ('York', 'I'),
#   ('Dow', 'I'),
#   ('Jones', 'I'),
#   ('industrial', 'O'),
#   ('average', 'O'),
#   ('--', 'O'),
#   ('5,778.00', 'O'),
#   ('(', 'O'),
#   ('May', 'O'),
#   ('22/96', 'O'),
#   (')', 'O')],
#  [('London', 'I'),
#   ('FTSE-100', 'I'),
#   ('index', 'O'),
#   ('--', 'O'),
#   ('3,907.5', 'O'),
#   ('(', 'O'),
#   ('Aug', 'O'),
#   ('23/96', 'O'),
#   (')', 'O')],
#  [('Tokyo', 'I'),
#   ('Nikkei', 'I'),
#   ('average', 'O'),
#   ('--', 'O'),
#   ('38,915.87', 'O'),
#   ('(', 'O'),
#   ('Dec', 'O'),
#   ('29/89', 'O'),
#   (')', 'O')],
#  [('Frankfurt', 'I'),
#   ('DAX-3O', 'I'),
#   ('index', 'O'),
#   ('--', 'O'),
#   ('2,583.49', 'O'),
#   ('(', 'O'),
#   ('Jul', 'O'),
#   ('5/96', 'O'),
#   (')', 'O')],
#  [('Paris', 'I'),
#   ('CAC-40', 'I'),
#   ('General', 'I'),
#   ('index', 'O'),
#   ('--', 'O'),
#   ('2,355.93', 'O'),
#   ('(', 'O'),
#   ('Feb', 'O'),
#   ('2/94', 'O'),
#   (')', 'O')],
#  [('Sydney', 'I'),
#   ('Australian', 'I'),
#   ('All-Ordinaries', 'I'),
#   ('index', 'O'),
#   ('--', 'O'),
#   ('2,340.6', 'O'),
#   ('(', 'O'),
#   ('Feb', 'O'),
#   ('3/94', 'O'),
#   (')', 'O')],
#  [('Hong', 'I'),
#   ('Kong', 'I'),
#   ('Hang', 'I'),
#   ('Seng', 'I'),
#   ('index', 'O'),
#   ('--', 'O'),
#   ('12,201.09', 'O'),
#   ('(', 'O'),
#   ('Jan', 'O'),
#   ('4/94', 'O'),
#   (')', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('U.S.', 'I'),
#   ('judge', 'O'),
#   ('orders', 'O'),
#   ('Biogen', 'I'),
#   (',', 'O'),
#   ('Berlex', 'I'),
#   ('officials', 'O'),
#   ('deposed', 'O'),
#   ('.', 'O')],
#  [('Leslie', 'I'), ('Gevirtz', 'I')],
#  [('BOSTON', 'I'), ('1996-08-28', 'O')],
#  [('In', 'O'),
#   ('order', 'O'),
#   ('to', 'O'),
#   ('help', 'O'),
#   ('him', 'O'),
#   ('decide', 'O'),
#   ('whether', 'O'),
#   ('he', 'O'),
#   ('should', 'O'),
#   ('hear', 'O'),
#   ('the', 'O'),
#   ('case', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('U.S.', 'I'),
#   ('District', 'I'),
#   ('Court', 'I'),
#   ('judge', 'O'),
#   ('Wednesday', 'O'),
#   ('ordered', 'O'),
#   ('the', 'O'),
#   ('legal', 'O'),
#   ('counsels', 'O'),
#   ('of', 'O'),
#   ('Biogen', 'I'),
#   ('Inc', 'I'),
#   ('and', 'O'),
#   ('Berlex', 'I'),
#   ('Laboratories', 'I'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('subsidiary', 'O'),
#   ('of', 'O'),
#   ('Schering', 'I'),
#   ('AG', 'I'),
#   (',', 'O'),
#   ('deposed', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('tempest', 'O'),
#   ('beyond', 'O'),
#   ('the', 'O'),
#   ('test', 'O'),
#   ('tube', 'O'),
#   ('involves', 'O'),
#   ('allegations', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('U.S.', 'I'),
#   ('Food', 'I'),
#   ('and', 'I'),
#   ('Drug', 'I'),
#   ('Administration', 'I'),
#   ('violated', 'O'),
#   ('the', 'O'),
#   ('Orphan', 'I'),
#   ('Drug', 'I'),
#   ('law', 'I'),
#   ('by', 'O'),
#   ('allowing', 'O'),
#   ('Biogen', 'I'),
#   ('the', 'O'),
#   ('right', 'O'),
#   ('to', 'O'),
#   ('sell', 'O'),
#   ('its', 'O'),
#   ('multiple', 'O'),
#   ('sclerosis', 'O'),
#   ('drug', 'O'),
#   ('Avonex', 'I'),
#   ('.', 'O')],
#  [('Berlex', 'I'),
#   ('also', 'O'),
#   ('charges', 'O'),
#   ('that', 'O'),
#   ('Avonex', 'I'),
#   ('is', 'O'),
#   ('so', 'O'),
#   ('similar', 'O'),
#   ('to', 'O'),
#   ('its', 'O'),
#   ('MS', 'O'),
#   ('drug', 'O'),
#   (',', 'O'),
#   ('Betaseron', 'I'),
#   (',', 'O'),
#   ('that', 'O'),
#   ('it', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('patent', 'O'),
#   ('infringement', 'O'),
#   ('.', 'O')],
#  [('Both', 'O'),
#   ('drugs', 'O'),
#   ('are', 'O'),
#   ('types', 'O'),
#   ('of', 'O'),
#   ('interferon', 'O'),
#   ('.', 'O')],
#  [('One', 'O'),
#   ('analyst', 'O'),
#   ('said', 'O'),
#   ('sales', 'O'),
#   ('of', 'O'),
#   ('Avonex', 'I'),
#   ('had', 'O'),
#   ('already', 'O'),
#   ('cut', 'O'),
#   ('into', 'O'),
#   ('Betaseron', 'I'),
#   ('market', 'O'),
#   ('share', 'O'),
#   ('.', 'O')],
#  [('BioVest', 'I'),
#   ('Research', 'I'),
#   (',', 'I'),
#   ('Inc', 'I'),
#   ("'s", 'O'),
#   ('analyst', 'O'),
#   ('Eddie', 'I'),
#   ('Hedaya', 'I'),
#   ('said', 'O'),
#   (',', 'O'),
#   ('"', 'O'),
#   ('Berlex', 'I'),
#   ('sales', 'O'),
#   ('are', 'O'),
#   ('losing', 'O'),
#   ('share', 'O'),
#   ('like', 'O'),
#   ('mad', 'O'),
#   ('...', 'O')],
#  [('my', 'O'),
#   ('understanding', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('marketplace', 'O'),
#   ('is', 'O'),
#   ('that', 'O'),
#   ('they', 'O'),
#   ("'re", 'O'),
#   ('below', 'O'),
#   ('expectations', 'O'),
#   ('.', 'O'),
#   ('"', 'O')],
#  [('He', 'O'),
#   ('added', 'O'),
#   ('Chiron', 'I'),
#   ('Corp', 'I'),
#   ('reported', 'O'),
#   ('its', 'O'),
#   ('sales', 'O'),
#   ('of', 'O'),
#   ('inventory', 'O'),
#   ('to', 'O'),
#   ('Berlex', 'I'),
#   ('was', 'O'),
#   ('down', 'O'),
#   ('.', 'O')],
#  [('Chiron', 'I'),
#   ('makes', 'O'),
#   ('Betaseron', 'I'),
#   (';', 'O'),
#   ('Berlex', 'I'),
#   ('markets', 'O'),
#   ('it', 'O'),
#   (',', 'O'),
#   ('he', 'O'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('Biogen', 'I'),
#   (',', 'O'),
#   ('in', 'O'),
#   ('its', 'O'),
#   ('Securities', 'I'),
#   ('and', 'I'),
#   ('Exchange', 'I'),
#   ('Commission', 'I'),
#   ('quarterly', 'O'),
#   ('report', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('period', 'O'),
#   ('ending', 'O'),
#   ('June', 'O'),
#   ('30', 'O'),
#   (',', 'O'),
#   ('said', 'O'),
#   ('it', 'O'),
#   ('had', 'O'),
#   ('earned', 'O'),
#   ('$', 'O'),
#   ('6.1', 'O'),
#   ('million', 'O'),
#   ('from', 'O'),
#   ('Avonex', 'I'),
#   ('sales', 'O'),
#   ('during', 'O'),
#   ('the', 'O'),
#   ('drugs', 'O'),
#   ('first', 'O'),
#   ('six', 'O'),
#   ('weeks', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('market', 'O'),
#   ('.', 'O')],
#  [('When', 'O'),
#   ('it', 'O'),
#   ('approved', 'O'),
#   ('Avonex', 'I'),
#   ('in', 'O'),
#   ('May', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('FDA', 'I'),
#   ('said', 'O'),
#   ('both', 'O'),
#   ('Biogen', 'I'),
#   ("'s", 'O'),
#   ('product', 'O'),
#   ('and', 'O'),
#   ('Betaseron', 'I'),
#   ('were', 'O'),
#   ('developed', 'O'),
#   ('under', 'O'),
#   ('the', 'O'),
#   ('incentives', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('Ophran', 'I'),
#   ('Drug', 'I'),
#   ('Act', 'I'),
#   ('which', 'O'),
#   ('provides', 'O'),
#   ('seven', 'O'),
#   ('years', 'O'),
#   ('of', 'O'),
#   ('marketing', 'O'),
#   ('exclusivity', 'O'),
#   ('for', 'O'),
#   ('products', 'O'),
#   ('that', 'O'),
#   ('treat', 'O'),
#   ('rare', 'O'),
#   ('diseases', 'O'),
#   ('.', 'O')],
#  [('Avonex', 'I'),
#   ('"', 'O'),
#   ('has', 'O'),
#   ('been', 'O'),
#   ('allowed', 'O'),
#   ('to', 'O'),
#   ('enter', 'O'),
#   ('the', 'O'),
#   ('market', 'O'),
#   ('because', 'O'),
#   ('it', 'O'),
#   ('differs', 'O'),
#   ('from', 'O'),
#   ('interferon', 'O'),
#   ('beta-1b', 'O'),
#   ('(', 'O'),
#   ('Betaseron', 'I'),
#   (')', 'O'),
#   ('..', 'O')],
#  [('.', 'O'), ('"', 'O')],
#  [('the', 'O'), ('FDA', 'I'), ('said', 'O'), ('.', 'O')],
#  [('Now', 'O'),
#   (',', 'O'),
#   ('U.S.', 'I'),
#   ('District', 'O'),
#   ('Judge', 'O'),
#   ('Mark', 'I'),
#   ('Wolf', 'I'),
#   ('has', 'O'),
#   ('ordered', 'O'),
#   ('the', 'O'),
#   ('chief', 'O'),
#   ('counsel', 'O'),
#   ('for', 'O'),
#   ('Biogen', 'I'),
#   (',', 'O'),
#   ('Michael', 'I'),
#   ('Astrue', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('Robert', 'I'),
#   ('Chabora', 'I'),
#   (',', 'O'),
#   ('his', 'O'),
#   ('counterpart', 'O'),
#   ('at', 'O'),
#   ('Berlex', 'I'),
#   ('be', 'O'),
#   ('deposed', 'O'),
#   ('about', 'O'),
#   ('a', 'O'),
#   ('May', 'O'),
#   ('21', 'O'),
#   ('meeting', 'O'),
#   ('the', 'O'),
#   ('two', 'O'),
#   ('men', 'O'),
#   ('attended', 'O'),
#   ('to', 'O'),
#   ('help', 'O'),
#   ('him', 'O'),
#   ('determine', 'O'),
#   ('whether', 'O'),
#   ('the', 'O'),
#   ('lawsuit', 'O'),
#   ('filed', 'O'),
#   ('by', 'O'),
#   ('Biogen', 'I'),
#   ('against', 'O'),
#   ('Berlex', 'I'),
#   ('should', 'O'),
#   ('be', 'O'),
#   ('heard', 'O'),
#   ('in', 'O'),
#   ('Massachusetts', 'I'),
#   ('.', 'O')],
#  [('Berlex', 'I'),
#   ('filed', 'O'),
#   ('a', 'O'),
#   ('lawsuit', 'O'),
#   ('against', 'O'),
#   ('Biogen', 'I'),
#   ('in', 'O'),
#   ('U.S.', 'I'),
#   ('District', 'I'),
#   ('Court', 'I'),
#   ('in', 'O'),
#   ('Newark', 'I'),
#   (',', 'O'),
#   ('N.J.', 'I'),
#   ('in', 'O'),
#   ('July', 'O'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('Biogen', 'I'),
#   ('had', 'O'),
#   ('already', 'O'),
#   ('filed', 'O'),
#   ('a', 'O'),
#   ('suit', 'O'),
#   ('against', 'O'),
#   ('Berlex', 'I'),
#   ('in', 'O'),
#   ('Massachusetts', 'I'),
#   ('in', 'O'),
#   ('May', 'O'),
#   ('.', 'O')],
#  [('Wolf', 'I'),
#   ('ordered', 'O'),
#   ('the', 'O'),
#   ('depositions', 'O'),
#   ('to', 'O'),
#   ('determine', 'O'),
#   ('if', 'O'),
#   ('he', 'O'),
#   ('or', 'O'),
#   ('U.S.', 'I'),
#   ('District', 'O'),
#   ('Judge', 'O'),
#   ('John', 'I'),
#   ('Bissell', 'I'),
#   ('of', 'O'),
#   ('Newark', 'I'),
#   ('should', 'O'),
#   ('preside', 'O'),
#   ('over', 'O'),
#   ('the', 'O'),
#   ('case', 'O'),
#   ('.', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('CYCLING', 'O'),
#   ('-', 'O'),
#   ('BOARDMAN', 'I'),
#   ('FULFILS', 'O'),
#   ('WORLD', 'O'),
#   ('RECORD', 'O'),
#   ('PREDICTION', 'O'),
#   ('.', 'O')],
#  [('Martin', 'I'), ('Ayres', 'I')],
#  [('MANCHESTER', 'I'), (',', 'O'), ('England', 'I'), ('1996-08-28', 'O')],
#  [('Britain', 'I'),
#   ("'s", 'O'),
#   ('Chris', 'I'),
#   ('Boardman', 'I'),
#   ('fulfilled', 'O'),
#   ('his', 'O'),
#   ('prediction', 'O'),
#   ('that', 'O'),
#   ('he', 'O'),
#   ('would', 'O'),
#   ('break', 'O'),
#   ('the', 'O'),
#   ('world', 'O'),
#   ('4,000', 'O'),
#   ('metres', 'O'),
#   ('world', 'O'),
#   ('record', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('world', 'O'),
#   ('track', 'O'),
#   ('cycling', 'O'),
#   ('championships', 'O'),
#   ('on', 'O'),
#   ('Wednesday', 'O'),
#   ('.', 'O')],
#  [('Boardman', 'I'),
#   ('clocked', 'O'),
#   ('four', 'O'),
#   ('minutes', 'O'),
#   ('13.353', 'O'),
#   ('seconds', 'O'),
#   ('to', 'O'),
#   ('slice', 'O'),
#   ('more', 'O'),
#   ('than', 'O'),
#   ('six', 'O'),
#   ('seconds', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('previous', 'O'),
#   ('world', 'O'),
#   ('mark', 'O'),
#   ('of', 'O'),
#   ('4:19.699', 'O'),
#   ('set', 'O'),
#   ('by', 'O'),
#   ('Olympic', 'I'),
#   ('champion', 'O'),
#   ('Andrea', 'I'),
#   ('Collinelli', 'I'),
#   ('of', 'O'),
#   ('Italy', 'I'),
#   ('in', 'O'),
#   ('Atlanta', 'I'),
#   ('in', 'O'),
#   ('July', 'O'),
#   ('.', 'O')],
#  [('Collinelli', 'I'),
#   ('qualified', 'O'),
#   ('in', 'O'),
#   ('second', 'O'),
#   ('place', 'O'),
#   (',', 'O'),
#   ('also', 'O'),
#   ('beating', 'O'),
#   ('his', 'O'),
#   ('old', 'O'),
#   ('record', 'O'),
#   ('in', 'O'),
#   ('4:17.696', 'O'),
#   ('.', 'O')],
#  [('"', 'O'),
#   ('I', 'O'),
#   ('was', 'O'),
#   ('very', 'O'),
#   ('nervous', 'O'),
#   ('before', 'O'),
#   ('the', 'O'),
#   ('start', 'O'),
#   ('but', 'O'),
#   ('then', 'O'),
#   ('I', 'O'),
#   ('was', 'O'),
#   ('amazed', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('speed', 'O'),
#   ('of', 'O'),
#   ('my', 'O'),
#   ('ride', 'O'),
#   (',', 'O'),
#   ('"', 'O'),
#   ('Boardman', 'I'),
#   ('said', 'O'),
#   ('.', 'O'),
#   ('"', 'O')],
#  [('I', 'O'),
#   ('do', 'O'),
#   ("n't", 'O'),
#   ('know', 'O'),
#   ('if', 'O'),
#   ('I', 'O'),
#   ('can', 'O'),
#   ('go', 'O'),
#   ('any', 'O'),
#   ('faster', 'O'),
#   ('.', 'O')],
#  [('Who', 'O'),
#   ('knows', 'O'),
#   ('what', 'O'),
#   ('will', 'O'),
#   ('happen', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('later', 'O'),
#   ('stages', 'O'),
#   ('?', 'O'),
#   ('"', 'O')],
#  [('Boardman', 'I'),
#   (',', 'O'),
#   ('28', 'O'),
#   (',', 'O'),
#   ('did', 'O'),
#   ('not', 'O'),
#   ('contest', 'O'),
#   ('the', 'O'),
#   ('Olympic', 'I'),
#   ('pursuit', 'O'),
#   ('because', 'O'),
#   ('of', 'O'),
#   ('its', 'O'),
#   ('proximity', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('Tour', 'I'),
#   ('de', 'I'),
#   ('France', 'I'),
#   ('in', 'O'),
#   ('which', 'O'),
#   ('he', 'O'),
#   ('led', 'O'),
#   ('the', 'O'),
#   ('French', 'I'),
#   ('GAN', 'I'),
#   ('team', 'O'),
#   ('.', 'O')],
#  [('However', 'O'),
#   (',', 'O'),
#   ('he', 'O'),
#   ('took', 'O'),
#   ('a', 'O'),
#   ('bronze', 'O'),
#   ('medal', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('Olympic', 'I'),
#   ('road', 'O'),
#   ('time-trial', 'O'),
#   ('and', 'O'),
#   ('then', 'O'),
#   ('returned', 'O'),
#   ('home', 'O'),
#   ('to', 'O'),
#   ('prepare', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('world', 'O'),
#   ('track', 'O'),
#   ('series', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('Manchester', 'I'),
#   ('indoor', 'O'),
#   ('velodrome', 'O'),
#   ('.', 'O')],
#  [('He', 'O'),
#   ('adopted', 'O'),
#   ('the', 'O'),
#   ('"', 'O'),
#   ('superman', 'O'),
#   ('"', 'O'),
#   ('riding', 'O'),
#   ('position', 'O'),
#   ('with', 'O'),
#   ('arms', 'O'),
#   ('at', 'O'),
#   ('full', 'O'),
#   ('stretch', 'O'),
#   ('perfected', 'O'),
#   ('by', 'O'),
#   ('fellow', 'O'),
#   ('Briton', 'I'),
#   ('Graeme', 'I'),
#   ('Obree', 'I'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('1995', 'O'),
#   ('world', 'O'),
#   ('champion', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('taken', 'O'),
#   ('up', 'O'),
#   ('in', 'O'),
#   ('Atlanta', 'I'),
#   ('by', 'O'),
#   ('Collinelli', 'I'),
#   ('.', 'O')],
#  [('Obree', 'I'),
#   ('was', 'O'),
#   ('forced', 'O'),
#   ('to', 'O'),
#   ('pull', 'O'),
#   ('out', 'O'),
#   ('of', 'O'),
#   ('his', 'O'),
#   ('title', 'O'),
#   ('defence', 'O'),
#   ('because', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('viral', 'O'),
#   ('infection', 'O'),
#   ('.', 'O')],
#  [('Qualifiers', 'O'),
#   ('for', 'O'),
#   ('Wednesday', 'O'),
#   ('evening', 'O'),
#   ("'s", 'O'),
#   ('quarter-finals', 'O'),
#   (':', 'O')],
#  [('1.', 'O'),
#   ('Chris', 'I'),
#   ('Boardman', 'I'),
#   ('(', 'O'),
#   ('Britain', 'I'),
#   (')', 'O'),
#   ('4:13.353', 'O')],
#  [('2.', 'O'),
#   ('Andrea', 'I'),
#   ('Collinelli', 'I'),
#   ('(', 'O'),
#   ('Italy', 'I'),
#   (')', 'O'),
#   ('4:17.696', 'O')],
#  [('3.', 'O'),
#   ('Mariano', 'I'),
#   ('Friedick', 'I'),
#   ('(', 'O'),
#   ('U.S.', 'I'),
#   (')', 'O'),
#   ('4:19.808', 'O')],
#  [('4.', 'O'),
#   ('Heiko', 'I'),
#   ('Szonn', 'I'),
#   ('(', 'O'),
#   ('Germany', 'I'),
#   (')', 'O'),
#   ('4:21.009', 'O')],
#  [('5.', 'O'),
#   ('Francis', 'I'),
#   ('Moreau', 'I'),
#   ('(', 'O'),
#   ('France', 'I'),
#   (')', 'O'),
#   ('4:21.454', 'O')],
#  [('6.', 'O'),
#   ('Alexei', 'I'),
#   ('Markov', 'I'),
#   ('(', 'O'),
#   ('Russia', 'I'),
#   (')', 'O'),
#   ('4:22.738', 'O')],
#  [('7.', 'O'),
#   ('Michael', 'I'),
#   ('Sandstod', 'I'),
#   ('(', 'O'),
#   ('Denmark', 'I'),
#   (')', 'O'),
#   ('4:24.427', 'O')],
#  [('8.', 'O'),
#   ('Edouard', 'I'),
#   ('Gritsoun', 'I'),
#   ('(', 'O'),
#   ('Russia', 'I'),
#   (')', 'O'),
#   ('4:26.467', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('S.', 'I'),
#   ('African', 'I'),
#   ('apartheid', 'O'),
#   ('killer', 'O'),
#   ('convicted', 'O'),
#   ('of', 'O'),
#   ('six', 'O'),
#   ('murders', 'O'),
#   ('.', 'O')],
#  [('PRETORIA', 'I'), ('1996-08-27', 'O')],
#  [('South', 'I'),
#   ('African', 'I'),
#   ('apartheid', 'O'),
#   ('killer', 'O'),
#   ('Eugene', 'I'),
#   ('de', 'I'),
#   ('Kock', 'I'),
#   ('was', 'O'),
#   ('found', 'O'),
#   ('guilty', 'O'),
#   ('of', 'O'),
#   ('murder', 'O'),
#   ('and', 'O'),
#   ('attempted', 'O'),
#   ('murder', 'O'),
#   ('on', 'O'),
#   ('Tuesday', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('day', 'O'),
#   ('after', 'O'),
#   ('he', 'O'),
#   ('was', 'O'),
#   ('convicted', 'O'),
#   ('of', 'O'),
#   ('five', 'O'),
#   ('other', 'O'),
#   ('murders', 'O'),
#   ('.', 'O')],
#  [('De', 'I'),
#   ('Kock', 'I'),
#   (',', 'O'),
#   ('48', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('former', 'O'),
#   ('police', 'O'),
#   ('colonel', 'O'),
#   ('who', 'O'),
#   ('commanded', 'O'),
#   ('a', 'O'),
#   ('hit-squad', 'O'),
#   ('that', 'O'),
#   ('wiped', 'O'),
#   ('out', 'O'),
#   ('opponents', 'O'),
#   ('of', 'O'),
#   ('apartheid', 'O'),
#   (',', 'O'),
#   ('is', 'O'),
#   ('the', 'O'),
#   ('most', 'O'),
#   ('senior', 'O'),
#   ('servant', 'O'),
#   ('of', 'O'),
#   ('white', 'O'),
#   ('rule', 'O'),
#   ('yet', 'O'),
#   ('to', 'O'),
#   ('face', 'O'),
#   ('justice', 'O'),
#   ('.', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('RUGBY', 'I'),
#   ('LEAGUE', 'I'),
#   ('-', 'O'),
#   ('EUROPEAN', 'I'),
#   ('SUPER', 'I'),
#   ('LEAGUE', 'I'),
#   ('RESULTS', 'O'),
#   ('/', 'O'),
#   ('STANDINGS', 'O'),
#   ('.', 'O')],
#  [('LONDON', 'I'), ('1996-08-24', 'O')],
#  [('Results', 'O'),
#   ('of', 'O'),
#   ('European', 'I'),
#   ('Super', 'I'),
#   ('League', 'I')],
#  [('rugby', 'O'),
#   ('league', 'O'),
#   ('matches', 'O'),
#   ('on', 'O'),
#   ('Saturday', 'O'),
#   (':', 'O')],
#  [('Paris', 'I'), ('14', 'O'), ('Bradford', 'I'), ('27', 'O')],
#  [('Wigan', 'I'), ('78', 'O'), ('Workington', 'I'), ('4', 'O')],
#  [('Standings', 'O'),
#   ('(', 'O'),
#   ('tabulated', 'O'),
#   ('under', 'O'),
#   ('played', 'O'),
#   (',', 'O'),
#   ('won', 'O'),
#   (',', 'O'),
#   ('drawn', 'O'),
#   (',', 'O'),
#   ('lost', 'O'),
#   (',', 'O'),
#   ('points', 'O')],
#  [('for', 'O'),
#   (',', 'O'),
#   ('against', 'O'),
#   (',', 'O'),
#   ('total', 'O'),
#   ('points', 'O'),
#   (')', 'O'),
#   (':', 'O')],
#  [('Wigan', 'I'),
#   ('22', 'O'),
#   ('19', 'O'),
#   ('1', 'O'),
#   ('2', 'O'),
#   ('902', 'O'),
#   ('326', 'O'),
#   ('39', 'O')],
#  [('St', 'I'),
#   ('Helens', 'I'),
#   ('21', 'O'),
#   ('19', 'O'),
#   ('0', 'O'),
#   ('2', 'O'),
#   ('884', 'O'),
#   ('441', 'O'),
#   ('38', 'O')],
#  [('Bradford', 'I'),
#   ('22', 'O'),
#   ('17', 'O'),
#   ('0', 'O'),
#   ('5', 'O'),
#   ('767', 'O'),
#   ('409', 'O'),
#   ('34', 'O')],
#  [('Warrington', 'I'),
#   ('21', 'O'),
#   ('12', 'O'),
#   ('0', 'O'),
#   ('9', 'O'),
#   ('555', 'O'),
#   ('499', 'O'),
#   ('24', 'O')],
#  [('London', 'I'),
#   ('21', 'O'),
#   ('11', 'O'),
#   ('1', 'O'),
#   ('9', 'O'),
#   ('555', 'O'),
#   ('462', 'O'),
#   ('23', 'O')],
#  [('Sheffield', 'I'),
#   ('21', 'O'),
#   ('10', 'O'),
#   ('0', 'O'),
#   ('11', 'O'),
#   ('574', 'O'),
#   ('696', 'O'),
#   ('20', 'O')],
#  [('Halifax', 'I'),
#   ('21', 'O'),
#   ('9', 'O'),
#   ('1', 'O'),
#   ('11', 'O'),
#   ('603', 'O'),
#   ('552', 'O'),
#   ('19', 'O')],
#  [('Castleford', 'I'),
#   ('21', 'O'),
#   ('9', 'O'),
#   ('0', 'O'),
#   ('12', 'O'),
#   ('548', 'O'),
#   ('543', 'O'),
#   ('18', 'O')],
#  [('Oldham', 'I'),
#   ('21', 'O'),
#   ('8', 'O'),
#   ('1', 'O'),
#   ('12', 'O'),
#   ('439', 'O'),
#   ('656', 'O'),
#   ('17', 'O')],
#  [('Leeds', 'I'),
#   ('21', 'O'),
# ...
#  [('Qualifier', 'O'),
#   ('vs.', 'O'),
#   ('Tomas', 'I'),
#   ('Carbonell', 'I'),
#   ('(', 'O'),
#   ('Spain', 'I'),
#   (')', 'O')],
#  [('Qualifier', 'O'),
#   ('vs.', 'O'),
#   ('2', 'O'),
#   ('-', 'O'),
#   ('Michael', 'I'),
#   ('Chang', 'I'),
#   ('(', 'O'),
#   ('U.S.', 'I'),
#   (')', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('BASEBALL', 'O'),
#   ('-', 'O'),
#   ('MAJOR', 'I'),
#   ('LEAGUE', 'I'),
#   ('STANDINGS', 'O'),
#   ('AFTER', 'O'),
#   ('SATURDAY', 'O'),
#   ("'S", 'O'),
#   ('GAMES', 'O'),
#   ('.', 'O')],
#  [('NEW', 'I'), ('YORK', 'I'), ('1996-08-25', 'O')],
#  [('Major', 'I'), ('League', 'I'), ('Baseball', 'I')],
#  [('standings', 'O'),
#   ('after', 'O'),
#   ('games', 'O'),
#   ('played', 'O'),
#   ('on', 'O'),
#   ('Saturday', 'O'),
#   ('(', 'O'),
#   ('tabulate', 'O'),
#   ('under', 'O'),
#   ('won', 'O'),
#   (',', 'O')],
#  [('lost', 'O'),
#   (',', 'O'),
#   ('winning', 'O'),
#   ('percentage', 'O'),
#   ('and', 'O'),
#   ('games', 'O'),
#   ('behind', 'O'),
#   (')', 'O'),
#   (':', 'O')],
#  [('AMERICAN', 'I'), ('LEAGUE', 'I')],
#  [('EASTERN', 'I'), ('DIVISION', 'I')],
#  [('W', 'O'), ('L', 'O'), ('PCT', 'O'), ('GB', 'O')],
#  [('NEW', 'I'),
#   ('YORK', 'I'),
#   ('74', 'O'),
#   ('54', 'O'),
#   ('.578', 'O'),
#   ('-', 'O')],
#  [('BALTIMORE', 'I'), ('68', 'O'), ('60', 'O'), ('.531', 'O'), ('6', 'O')],
#  [('BOSTON', 'I'), ('65', 'O'), ('65', 'O'), ('.500', 'O'), ('10', 'O')],
#  [('TORONTO', 'I'), ('61', 'O'), ('69', 'O'), ('.469', 'O'), ('14', 'O')],
#  [('DETROIT', 'I'),
#   ('46', 'O'),
#   ('83', 'O'),
#   ('.357', 'O'),
#   ('28', 'O'),
#   ('1/2', 'O')],
#  [('CENTRAL', 'I'), ('DIVISION', 'I')],
#  [('CLEVELAND', 'I'), ('76', 'O'), ('53', 'O'), ('.589', 'O'), ('-', 'O')],
#  [('CHICAGO', 'I'), ('69', 'O'), ('62', 'O'), ('.527', 'O'), ('8', 'O')],
#  [('MINNESOTA', 'I'), ('65', 'O'), ('64', 'O'), ('.504', 'O'), ('11', 'O')],
#  [('MILWAUKEE', 'I'),
#   ('62', 'O'),
#   ('68', 'O'),
#   ('.477', 'O'),
#   ('14', 'O'),
#   ('1/2', 'O')],
#  [('KANSAS', 'I'),
#   ('CITY', 'I'),
#   ('59', 'O'),
#   ('72', 'O'),
#   ('.450', 'O'),
#   ('18', 'O')],
#  [('WESTERN', 'I'), ('DIVISION', 'I')],
#  [('TEXAS', 'I'), ('74', 'O'), ('56', 'O'), ('.569', 'O'), ('-', 'O')],
#  [('SEATTLE', 'I'), ('66', 'O'), ('62', 'O'), ('.516', 'O'), ('7', 'O')],
#  [('OAKLAND', 'I'), ('62', 'O'), ('70', 'O'), ('.470', 'O'), ('13', 'O')],
#  [('CALIFORNIA', 'I'),
#   ('60', 'O'),
#   ('69', 'O'),
#   ('.465', 'O'),
#   ('13', 'O'),
#   ('1/2', 'O')],
#  [('SUNDAY', 'O'),
#   (',', 'O'),
#   ('AUGUST', 'O'),
#   ('25TH', 'O'),
#   ('SCHEDULE', 'O')],
#  [('SEATTLE', 'I'), ('AT', 'O'), ('BOSTON', 'I')],
#  [('MILWAUKEE', 'I'), ('AT', 'O'), ('CLEVELAND', 'I')],
#  [('CALIFORNIA', 'I'), ('AT', 'O'), ('BALTIMORE', 'I')],
#  [('OAKLAND', 'I'), ('AT', 'O'), ('NEW', 'I'), ('YORK', 'I')],
#  [('TORONTO', 'I'), ('AT', 'O'), ('CHICAGO', 'I')],
#  [('TEXAS', 'I'), ('AT', 'O'), ('MINNESOTA', 'I')],
#  [('DETROIT', 'I'), ('AT', 'O'), ('KANSAS', 'I'), ('CITY', 'I')],
#  [('NATIONAL', 'I'), ('LEAGUE', 'I')],
#  [('EASTERN', 'I'), ('DIVISION', 'I')],
#  [('W', 'O'), ('L', 'O'), ('PCT', 'O'), ('GB', 'O')],
#  [('ATLANTA', 'I'), ('81', 'O'), ('47', 'O'), ('.633', 'O'), ('-', 'O')],
#  [('MONTREAL', 'I'), ('70', 'O'), ('58', 'O'), ('.547', 'O'), ('11', 'O')],
#  [('FLORIDA', 'I'), ('60', 'O'), ('70', 'O'), ('.462', 'O'), ('22', 'O')],
#  [('NEW', 'I'),
#   ('YORK', 'I'),
#   ('59', 'O'),
#   ('71', 'O'),
#   ('.454', 'O'),
#   ('23', 'O')],
#  [('PHILADELPHIA', 'I'), ('53', 'O'), ('77', 'O'), ('.408', 'O'), ('29', 'O')],
#  [('CENTRAL', 'I'), ('DIVISION', 'I')],
#  [('HOUSTON', 'I'), ('69', 'O'), ('61', 'O'), ('.531', 'O'), ('-', 'O')],
#  [('ST', 'I'),
#   ('LOUIS', 'I'),
#   ('68', 'O'),
#   ('61', 'O'),
#   ('.527', 'O'),
#   ('1/2', 'O')],
#  [('CINCINNATI', 'I'), ('64', 'O'), ('64', 'O'), ('.500', 'O'), ('4', 'O')],
#  [('CHICAGO', 'I'),
#   ('63', 'O'),
#   ('64', 'O'),
#   ('.496', 'O'),
#   ('4', 'O'),
#   ('1/2', 'O')],
#  [('PITTSBURGH', 'I'),
#   ('55', 'O'),
#   ('74', 'O'),
#   ('.426', 'O'),
#   ('13', 'O'),
#   ('1/2', 'O')],
#  [('WESTERN', 'I'), ('DIVISION', 'I')],
#  [('SAN', 'I'),
#   ('DIEGO', 'I'),
#   ('71', 'O'),
#   ('60', 'O'),
#   ('.542', 'O'),
#   ('-', 'O')],
#  [('LOS', 'I'),
#   ('ANGELES', 'I'),
#   ('69', 'O'),
#   ('60', 'O'),
#   ('.535', 'O'),
#   ('1', 'O')],
#  [('COLORADO', 'I'),
#   ('67', 'O'),
#   ('63', 'O'),
#   ('.515', 'O'),
#   ('3', 'O'),
#   ('1/2', 'O')],
#  [('SAN', 'I'),
#   ('FRANCISCO', 'I'),
#   ('54', 'O'),
#   ('73', 'O'),
#   ('.425', 'O'),
#   ('15', 'O')],
#  [('SUNDAY', 'O'),
#   (',', 'O'),
#   ('AUGUST', 'O'),
#   ('25TH', 'O'),
#   ('SCHEDULE', 'O')],
#  [('CHICAGO', 'I'), ('AT', 'O'), ('ATLANTA', 'I')],
#  [('PITTSBURGH', 'I'), ('AT', 'O'), ('COLORADO', 'I')],
#  [('NEW', 'I'), ('YORK', 'I'), ('AT', 'O'), ('LOS', 'I'), ('ANGELES', 'I')],
#  [('PHILADELPHIA', 'I'), ('AT', 'O'), ('SAN', 'I'), ('DIEGO', 'I')],
#  [('MONTREAL', 'I'), ('AT', 'O'), ('SAN', 'I'), ('FRANCISCO', 'I')],
#  [('CINCINNATI', 'I'), ('AT', 'O'), ('FLORIDA', 'I')],
#  [('ST', 'I'), ('LOUIS', 'I'), ('AT', 'O'), ('HOUSTON', 'I')],
#  [('-DOCSTART-', 'O')],
#  [('SOCCER', 'O'),
#   ('-', 'O'),
#   ('SWISS', 'I'),
#   ('PREMIER', 'O'),
#   ('DIVISION', 'O'),
#   ('RESULTS', 'O'),
#   ('/', 'O'),
#   ('STANDINGS', 'O'),
#   ('.', 'O')],
#  [('GENEVA', 'I'), ('1996-08-25', 'O')],
#  [('Results', 'O'),
#   ('of', 'O'),
#   ('Swiss', 'I'),
#   ('premier', 'O'),
#   ('division', 'O')],
#  [('matches', 'O'),
#   ('played', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('weekend', 'O'),
#   (':', 'O')],
#  [('Aarau', 'I'), ('1', 'O'), ('Young', 'I'), ('Boys', 'I'), ('0', 'O')],
#  [('Grasshopper', 'I'), ('2', 'O'), ('Lucerne', 'I'), ('2', 'O')],
#  [('Lugano', 'I'), ('1', 'O'), ('Basle', 'I'), ('1', 'O')],
#  [('Neuchatel', 'I'), ('3', 'O'), ('St', 'I'), ('Gallen', 'I'), ('0', 'O')],
#  [('Sion', 'I'), ('3', 'O'), ('Servette', 'I'), ('1', 'O')],
#  [('Standings', 'O'),
#   ('(', 'O'),
#   ('tabulated', 'O'),
#   ('under', 'O'),
#   ('played', 'O'),
#   (',', 'O'),
#   ('won', 'O'),
#   (',', 'O'),
#   ('drawn', 'O'),
#   (',', 'O'),
#   ('lost', 'O'),
#   (',', 'O'),
#   ('goals', 'O')],
#  [('for', 'O'),
#   (',', 'O'),
#   ('against', 'O'),
#   (',', 'O'),
#   ('points', 'O'),
#   (')', 'O'),
#   (':', 'O')],
#  [('Neuchatel', 'I'),
#   ('8', 'O'),
#   ('6', 'O'),
#   ('1', 'O'),
#   ('1', 'O'),
#   ('12', 'O'),
#   ('7', 'O'),
#   ('19', 'O')],
#  [('Grasshopper', 'I'),
#   ('9', 'O'),
#   ('4', 'O'),
#   ('4', 'O'),
#   ('1', 'O'),
#   ('17', 'O'),
#   ('11', 'O'),
#   ('16', 'O')],
#  [('St.', 'I'),
#   ('Gallen', 'O'),
#   ('9', 'O'),
#   ('4', 'O'),
#   ('4', 'O'),
#   ('1', 'O'),
#   ('6', 'O'),
#   ('5', 'O'),
#   ('16', 'O')],
#  [('Lausanne', 'I'),
#   ('9', 'O'),
#   ('4', 'O'),
#   ('2', 'O'),
#   ('3', 'O'),
#   ('18', 'O'),
#   ('13', 'O'),
#   ('14', 'O')],
#  [('Aarau', 'I'),
#   ('8', 'O'),
#   ('4', 'O'),
#   ('1', 'O'),
#   ('3', 'O'),
#   ('9', 'O'),
#   ('4', 'O'),
#   ('13', 'O')],
#  [('Sion', 'I'),
#   ('9', 'O'),
#   ('3', 'O'),
#   ('4', 'O'),
#   ('2', 'O'),
#   ('13', 'O'),
#   ('11', 'O'),
#   ('13', 'O')],
#  [('Zurich', 'I'),
#   ('9', 'O'),
#   ('2', 'O'),
#   ('5', 'O'),
#   ('2', 'O'),
#   ('9', 'O'),
#   ('9', 'O'),
#   ('11', 'O')],
#  [('Basle', 'I'),
#   ('8', 'O'),
#   ('2', 'O'),
#   ('3', 'O'),
#   ('3', 'O'),
#   ('12', 'O'),
#   ('11', 'O'),
#   ('9', 'O')],
#  [('Servette', 'I'),
#   ('9', 'O'),
#   ('2', 'O'),
#   ('3', 'O'),
#   ('4', 'O'),
#   ('10', 'O'),
#   ('12', 'O'),
#   ('9', 'O')],
#  [('Lucerne', 'I'),
#   ('8', 'O'),
#   ('1', 'O'),
#   ('5', 'O'),
#   ('2', 'O'),
#   ('10', 'O'),
#   ('11', 'O'),
#   ('8', 'O')],
#  [('Lugano', 'I'),
#   ('9', 'O'),
#   ('1', 'O'),
#   ('4', 'O'),
#   ('4', 'O'),
#   ('6', 'O'),
#   ('15', 'O'),
#   ('7', 'O')],
#  [('Young', 'I'),
#   ('Boys', 'I'),
#   ('9', 'O'),
#   ('1', 'O'),
#   ('0', 'O'),
#   ('8', 'O'),
#   ('6', 'O'),
#   ('19', 'O'),
#   ('3', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('SOCCER', 'O'),
#   ('-', 'O'),
#   ('FRENCH', 'I'),
#   ('LEAGUE', 'O'),
#   ('SUMMARIES', 'O'),
#   ('.', 'O')],
#  [('PARIS', 'I'), ('1996-08-24', 'O')],
#  [('Summaries', 'O'),
#   ('of', 'O'),
#   ('French', 'I'),
#   ('first', 'O'),
#   ('division', 'O')],
#  [('matches', 'O'), ('on', 'O'), ('Saturday', 'O'), (':', 'O')],
#  [('Nantes', 'I'),
#   ('0', 'O'),
#   ('Lens', 'I'),
#   ('1', 'O'),
#   ('(', 'O'),
#   ('Smicer', 'I'),
#   ('52nd', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('Halftime', 'O'), ('0-0', 'O'), ('.', 'O')],
#  [('Attendance', 'O'), ('16,000', 'O'), ('.', 'O')],
#  [('Nice', 'I'),
#   ('1', 'O'),
#   ('(', 'O'),
#   ('Debbah', 'I'),
#   ('39th', 'O'),
#   (')', 'O'),
#   ('Bastia', 'I'),
#   ('1', 'O'),
#   ('(', 'O'),
#   ('Drobnjak', 'I'),
#   ('82nd', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('1-0', 'O'), ('.', 'O')],
#  [('6,000', 'O'), ('.', 'O')],
#  [('Lille', 'I'),
#   ('3', 'O'),
#   ('(', 'O'),
#   ('Boutoille', 'I'),
#   ('47th', 'O'),
#   (',', 'O'),
#   ('Becanovic', 'I'),
#   ('79th', 'O'),
#   ('pen', 'O'),
#   (',', 'O'),
#   ('82nd', 'O'),
#   (')', 'O'),
#   (')', 'O'),
#   ('Rennes', 'I'),
#   ('1', 'O')],
#  [('(', 'O'), ("Guivarc'h", 'I'), ('60th', 'O'), ('pen', 'O'), ('.', 'O')],
#  [(')', 'O'), ('0-0', 'O'), ('.', 'O')],
#  [('6,000', 'O'), ('.', 'O')],
#  [('Bordeaux', 'I'), ('0', 'O'), ('Auxerre', 'I'), ('0', 'O'), ('.', 'O')],
#  [('30,000', 'O'), ('.', 'O')],
#  [('Marseille', 'I'),
#   ('1', 'O'),
#   ('(', 'O'),
#   ('Gravelaine', 'I'),
#   ('24th', 'O'),
#   (')', 'O'),
#   ('Metz', 'I'),
#   ('2', 'O'),
#   ('(', 'O'),
#   ('Traore', 'I'),
#   ('65th', 'O'),
#   (',', 'O'),
#   ('Bombarda', 'I')],
#  [('69th', 'O'), (')', 'O'), ('.', 'O')],
#  [('1-0', 'O'), ('.', 'O')],
#  [('20,000', 'O'), ('.', 'O')],
#  [('Strasbourg', 'I'),
#   ('1', 'O'),
#   ('(', 'O'),
#   ('Zitelli', 'I'),
#   ('80th', 'O'),
#   (')', 'O'),
#   ('Le', 'I'),
#   ('Havre', 'I'),
#   ('0', 'O'),
#   ('.', 'O')],
#  [('0-0', 'O'), ('.', 'O')],
#  [('15,000', 'O')],
#  [('Caen', 'I'),
#   ('1', 'O'),
#   ('(', 'O'),
#   ('Bancarel', 'I'),
#   ('70th', 'O'),
#   (')', 'O'),
#   ('Lyon', 'I'),
#   ('1', 'O'),
#   ('(', 'O'),
#   ('Caveglia', 'I'),
#   ('89th', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('0-0', 'O'), ('.', 'O')],
#  [('9,000', 'O'), ('.', 'O')],
#  [('Guingamp', 'I'),
#   ('2', 'O'),
#   ('(', 'O'),
#   ('Wreh', 'I'),
#   ('15th', 'O'),
#   (',', 'O'),
#   ('42nd', 'O'),
#   (')', 'O'),
#   ('Monaco', 'I'),
#   ('1', 'O'),
#   ('(', 'O'),
#   ('Scifo', 'I'),
#   ('35th', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('2-1', 'O'), ('.', 'O')],
#  [('7,000', 'O'), ('.', 'O')],
#  [('Montpellier', 'I'),
#   ('0', 'O'),
#   ('Cannes', 'I'),
#   ('1', 'O'),
#   ('(', 'O'),
#   ('Charvet', 'I'),
#   ('8th', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('0-1', 'O'), ('.', 'O')],
#  [('10,000', 'O'), ('.', 'O')],
#  [('Played', 'O'), ('on', 'O'), ('Friday', 'O'), (':', 'O')],
#  [('Nancy', 'I'),
#   ('0', 'O'),
#   ('Paris', 'I'),
#   ('St', 'I'),
#   ('Germain', 'I'),
#   ('0', 'O'),
#   ('.', 'O')],
#  [('15,000', 'O'), ('.', 'O')],
#  [('-DOCSTART-', 'O')],
#  [('McGrath', 'I'),
#   ('left', 'O'),
#   ('out', 'O'),
#   ('of', 'O'),
#   ('Ireland', 'I'),
#   ('World', 'I'),
#   ('Cup', 'I'),
#   ('squad', 'O'),
#   ('.', 'O')],
#  [('DUBLIN', 'I'), ('1996-08-27', 'O')],
#  [('Ireland', 'I'),
#   ("'s", 'O'),
#   ('most', 'O'),
#   ('experienced', 'O'),
#   ('player', 'O'),
#   (',', 'O'),
#   ('defender', 'O'),
#   ('Paul', 'I'),
#   ('McGrath', 'I'),
#   (',', 'O'),
#   ('was', 'O'),
#   ('left', 'O'),
#   ('out', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('national', 'O'),
#   ('squad', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('first', 'O'),
#   ('time', 'O'),
#   ('in', 'O'),
#   ('11', 'O'),
#   ('years', 'O'),
#   ('on', 'O'),
#   ('Tuesday', 'O'),
#   ('when', 'O'),
#   ('new', 'O'),
#   ('manager', 'O'),
#   ('Mick', 'I'),
#   ('McCarthy', 'I'),
#   ('named', 'O'),
#   ('his', 'O'),
#   ('side', 'O'),
#   ('to', 'O'),
#   ('face', 'O'),
#   ('Liechtenstein', 'I'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('World', 'I'),
#   ('Cup', 'I'),
#   ('qualifier', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('36-year-old', 'O'),
#   ('Aston', 'I'),
#   ('Villa', 'I'),
#   ('player', 'O'),
#   ('won', 'O'),
#   ('the', 'O'),
#   ('last', 'O'),
#   ('of', 'O'),
#   ('his', 'O'),
#   ('Irish', 'I'),
#   ('record', 'O'),
#   ('of', 'O'),
#   ('82', 'O'),
#   ('international', 'O'),
#   ('caps', 'O'),
#   ('against', 'O'),
#   ('the', 'O'),
#   ('Czech', 'I'),
#   ('Republic', 'I'),
#   ('in', 'O'),
#   ('Prague', 'I'),
#   ('in', 'O'),
#   ('April', 'O'),
#   ('.', 'O')],
#  [('"', 'O'),
#   ('Paul', 'I'),
#   ('accepted', 'O'),
#   ('the', 'O'),
#   ('situation', 'O'),
#   ('.', 'O')],
#  [('He', 'O'),
#   ('has', 'O'),
#   ("n't", 'O'),
#   ('played', 'O'),
#   ('any', 'O'),
#   ('first-team', 'O'),
#   ('games', 'O'),
#   ('for', 'O'),
#   ('Villa', 'I'),
#   ('this', 'O'),
#   ('season', 'O'),
#   ('and', 'O'),
#   ('he', 'O'),
#   ("'s", 'O'),
#   ('not', 'O'),
#   ('the', 'O'),
#   ('type', 'O'),
#   ('of', 'O'),
#   ('player', 'O'),
#   ('I', 'O'),
#   ('would', 'O'),
#   ('have', 'O'),
#   ('brought', 'O'),
#   ('on', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('substitute', 'O'),
#   (',', 'O'),
#   ('"', 'O'),
#   ('McCarthy', 'I'),
#   ('said', 'O'),
#   ('.', 'O'),
#   ('"', 'O')],
#  [('But', 'O'),
#   ('he', 'O'),
#   ('surprised', 'O'),
#   ('me', 'O'),
#   ('in', 'O'),
#   ('training', 'O'),
#   ('over', 'O'),
#   ('the', 'O'),
#   ('last', 'O'),
#   ('two', 'O'),
#   ('days', 'O'),
#   ('because', 'O'),
#   ('of', 'O'),
#   ('his', 'O'),
#   ('involvement', 'O'),
#   ('.', 'O')],
#  [('He', 'O'),
#   ("'s", 'O'),
#   ('certainly', 'O'),
#   ('is', 'O'),
#   ('still', 'O'),
#   ('very', 'O'),
#   ('much', 'O'),
#   ('part', 'O'),
#   ('of', 'O'),
#   ('my', 'O'),
#   ('plans', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('future', 'O'),
#   ('.', 'O')],
#  [('"', 'O'),
#   ('At', 'O'),
#   ('24', 'O'),
#   (',', 'O'),
#   ('25', 'O'),
#   ('or', 'O'),
#   ('26', 'O'),
#   ('you', 'O'),
#   ('could', 'O'),
#   ('get', 'O'),
#   ('away', 'O'),
#   ('with', 'O'),
#   ('it', 'O'),
#   (',', 'O'),
#   ('not', 'O'),
#   ('having', 'O'),
#   ('played', 'O'),
#   ('first-team', 'O'),
#   ('games', 'O'),
#   ('.', 'O')],
#  [('But', 'O'),
#   ('at', 'O'),
#   ('36', 'O'),
#   ('it', 'O'),
#   ('would', 'O'),
#   ('be', 'O'),
#   ('asking', 'O'),
#   ('too', 'O'),
#   ('much', 'O'),
#   ('of', 'O'),
#   ('Paul', 'I'),
#   (',', 'O'),
#   ('"', 'O'),
#   ('he', 'O'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('Also', 'O'),
#   ('omitted', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('20-man', 'O'),
#   ('squad', 'O'),
#   ('which', 'O'),
#   ('will', 'O'),
#   ('travel', 'O'),
#   ('to', 'O'),
#   ('Vaduz', 'I'),
#   ('for', 'O'),
#   ('Saturday', 'O'),
#   ("'s", 'O'),
#   ('group', 'O'),
#   ('eight', 'O'),
#   ('match', 'O'),
#   ('are', 'O'),
#   ('central', 'O'),
#   ('defenders', 'O'),
#   ('Alan', 'I'),
#   ('Kernaghan', 'I'),
#   ('and', 'O'),
#   ('Liam', 'I'),
#   ('Daish', 'I'),
#   ('.', 'O')],
#  [('Leeds', 'I'),
#   ('United', 'I'),
#   ('defender', 'O'),
#   ('Gary', 'I'),
#   ('Kelly', 'I'),
#   ('is', 'O'),
#   ('unable', 'O'),
#   ('to', 'O'),
#   ('travel', 'O'),
#   ('because', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('knee', 'O'),
#   ('injury', 'O'),
#   ('picked', 'O'),
#   ('up', 'O'),
#   ('in', 'O'),
#   ('Monday', 'O'),
#   ("'s", 'O'),
#   ('1-0', 'O'),
#   ('victory', 'O'),
#   ('over', 'O'),
#   ('Wimbledon', 'I'),
#   ('at', 'O'),
#   ('Elland', 'I'),
#   ('Road', 'I'),
#   ('.', 'O')],
#  [('Since', 'O'),
#   ('taking', 'O'),
#   ('over', 'O'),
#   ('from', 'O'),
#   ('Jack', 'I'),
#   ('Charlton', 'I'),
#   ('in', 'O'),
#   ('February', 'O'),
#   (',', 'O'),
#   ('McCarthy', 'I'),
#   ('has', 'O'),
#   ('played', 'O'),
#   ('largely', 'O'),
#   ('experimental', 'O'),
#   ('sides', 'O'),
#   ('and', 'O'),
#   ('seen', 'O'),
#   ('them', 'O'),
#   ('lose', 'O'),
#   ('five', 'O'),
#   ('times', 'O'),
#   (',', 'O'),
#   ('draw', 'O'),
#   ('twice', 'O'),
#   ('and', 'O'),
#   ('win', 'O'),
#   ('just', 'O'),
#   ('once', 'O'),
#   ('.', 'O')],
#  [('Squad', 'O'),
#   (':', 'O'),
#   ('Alan', 'I'),
#   ('Kelly', 'I'),
#   (',', 'O'),
#   ('Shay', 'I'),
#   ('Given', 'I'),
#   (',', 'O'),
#   ('Denis', 'I'),
#   ('Irwin', 'I'),
#   (',', 'O'),
#   ('Phil', 'I'),
#   ('Babb', 'I'),
#   (',', 'O'),
#   ('Jeff', 'I'),
#   ('Kenna', 'I'),
#   (',', 'O'),
#   ('Curtis', 'I'),
#   ('Fleming', 'I'),
#   (',', 'O'),
#   ('Gary', 'I'),
#   ('Breen', 'I'),
#   (',', 'O'),
#   ('Ian', 'I'),
#   ('Harte', 'I'),
#   (',', 'O'),
#   ('Kenny', 'I'),
#   ('Cunningham', 'I'),
#   (',', 'O'),
#   ('Steve', 'I'),
#   ('Staunton', 'I'),
#   (',', 'O'),
#   ('Andy', 'I'),
#   ('Townsend', 'I'),
#   (',', 'O'),
#   ('Ray', 'I'),
#   ('Houghton', 'I'),
#   (',', 'O'),
#   ('Gareth', 'I'),
#   ('Farrelly', 'I'),
#   (',', 'O'),
#   ('Alan', 'I'),
#   ('McLoughlin', 'I'),
#   (',', 'O'),
#   ('Jason', 'I'),
#   ('McAteer', 'I'),
#   (',', 'O'),
#   ('Alan', 'I'),
#   ('Moore', 'I'),
#   (',', 'O'),
#   ('Keith', 'I'),
#   ("O'Neill", 'I'),
#   (',', 'O'),
#   ('Tony', 'I'),
#   ('Cascarino', 'I'),
#   (',', 'O'),
#   ('Niall', 'I'),
#   ('Quinn', 'I'),
#   (',', 'O'),
#   ('David', 'I'),
#   ('Kelly', 'I'),
#   ('.', 'O')],
#  [('--', 'O'), ('Dublin', 'I'), ('Newsroom', 'I'), ('+6613377', 'O')],
#  ...]

# %%
fe=extract_ner_features_train(ner_data_train)
fe[1]
# Out:
# [{'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=SSS&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=says': 1,
#   'w+2=hijackers': 1,
#   'w+3=were': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=says&w+2=hijackers': 1,
#   'w-1=SSS&w+1=says': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=Iraq': 1,
#   'w+1=hijackers': 1,
#   'w+2=were': 1,
#   'w+3=not': 1,
#   'w-1=Iraq&w-2=SSS': 1,
#   'w+1=hijackers&w+2=were': 1,
#   'w-1=Iraq&w+1=hijackers': 1},
#  {'w-3=SSS': 1,
#   'w-2=Iraq': 1,
#   'w-1=says': 1,
#   'w+1=were': 1,
#   'w+2=not': 1,
#   'w+3=diplomats': 1,
#   'w-1=says&w-2=Iraq': 1,
#   'w+1=were&w+2=not': 1,
#   'w-1=says&w+1=were': 1},
#  {'w-3=Iraq': 1,
#   'w-2=says': 1,
#   'w-1=hijackers': 1,
#   'w+1=not': 1,
#   'w+2=diplomats': 1,
#   'w+3=.': 1,
#   'w-1=hijackers&w-2=says': 1,
#   'w+1=not&w+2=diplomats': 1,
#   'w-1=hijackers&w+1=not': 1},
#  {'w-3=says': 1,
#   'w-2=hijackers': 1,
#   'w-1=were': 1,
#   'w+1=diplomats': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1=were&w-2=hijackers': 1,
#   'w+1=diplomats&w+2=.': 1,
#   'w-1=were&w+1=diplomats': 1},
#  {'w-3=hijackers': 1,
#   'w-2=were': 1,
#   'w-1=not': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=not&w-2=were': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=not&w+1=.': 1},
#  {'w-3=were': 1,
#   'w-2=not': 1,
#   'w-1=diplomats': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=diplomats&w-2=not': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=diplomats&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=1996-08-28': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=1996-08-28&w+2=EEE': 1,
#   'w-1=SSS&w+1=1996-08-28': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=BAGHDAD': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=BAGHDAD&w-2=SSS': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=BAGHDAD&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=on': 1,
#   'w+2=Wednesday': 1,
#   'w+3=said': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=on&w+2=Wednesday': 1,
#   'w-1=SSS&w+1=on': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=Iraq': 1,
#   'w+1=Wednesday': 1,
#   'w+2=said': 1,
#   'w+3=the': 1,
#   'w-1=Iraq&w-2=SSS': 1,
#   'w+1=Wednesday&w+2=said': 1,
#   'w-1=Iraq&w+1=Wednesday': 1},
#  {'w-3=SSS': 1,
#   'w-2=Iraq': 1,
#   'w-1=on': 1,
#   'w+1=said': 1,
#   'w+2=the': 1,
#   'w+3=hijackers': 1,
#   'w-1=on&w-2=Iraq': 1,
#   'w+1=said&w+2=the': 1,
#   'w-1=on&w+1=said': 1},
#  {'w-3=Iraq': 1,
#   'w-2=on': 1,
#   'w-1=Wednesday': 1,
#   'w+1=the': 1,
#   'w+2=hijackers': 1,
#   'w+3=of': 1,
#   'w-1=Wednesday&w-2=on': 1,
#   'w+1=the&w+2=hijackers': 1,
#   'w-1=Wednesday&w+1=the': 1},
#  {'w-3=on': 1,
#   'w-2=Wednesday': 1,
#   'w-1=said': 1,
#   'w+1=hijackers': 1,
#   'w+2=of': 1,
#   'w+3=a': 1,
#   'w-1=said&w-2=Wednesday': 1,
#   'w+1=hijackers&w+2=of': 1,
#   'w-1=said&w+1=hijackers': 1},
#  {'w-3=Wednesday': 1,
#   'w-2=said': 1,
#   'w-1=the': 1,
#   'w+1=of': 1,
#   'w+2=a': 1,
#   'w+3=Sudanese': 1,
#   'w-1=the&w-2=said': 1,
#   'w+1=of&w+2=a': 1,
#   'w-1=the&w+1=of': 1},
#  {'w-3=said': 1,
#   'w-2=the': 1,
#   'w-1=hijackers': 1,
#   'w+1=a': 1,
#   'w+2=Sudanese': 1,
#   'w+3=airliner': 1,
#   'w-1=hijackers&w-2=the': 1,
#   'w+1=a&w+2=Sudanese': 1,
#   'w-1=hijackers&w+1=a': 1},
#  {'w-3=the': 1,
#   'w-2=hijackers': 1,
#   'w-1=of': 1,
#   'w+1=Sudanese': 1,
#   'w+2=airliner': 1,
#   'w+3=were': 1,
#   'w-1=of&w-2=hijackers': 1,
#   'w+1=Sudanese&w+2=airliner': 1,
#   'w-1=of&w+1=Sudanese': 1},
#  {'w-3=hijackers': 1,
#   'w-2=of': 1,
#   'w-1=a': 1,
#   'w+1=airliner': 1,
#   'w+2=were': 1,
#   'w+3=not': 1,
#   'w-1=a&w-2=of': 1,
#   'w+1=airliner&w+2=were': 1,
#   'w-1=a&w+1=airliner': 1},
#  {'w-3=of': 1,
#   'w-2=a': 1,
#   'w-1=Sudanese': 1,
#   'w+1=were': 1,
#   'w+2=not': 1,
#   'w+3=Iraqi': 1,
#   'w-1=Sudanese&w-2=a': 1,
#   'w+1=were&w+2=not': 1,
#   'w-1=Sudanese&w+1=were': 1},
#  {'w-3=a': 1,
#   'w-2=Sudanese': 1,
#   'w-1=airliner': 1,
#   'w+1=not': 1,
#   'w+2=Iraqi': 1,
#   'w+3=diplomats': 1,
#   'w-1=airliner&w-2=Sudanese': 1,
#   'w+1=not&w+2=Iraqi': 1,
#   'w-1=airliner&w+1=not': 1},
#  {'w-3=Sudanese': 1,
#   'w-2=airliner': 1,
#   'w-1=were': 1,
#   'w+1=Iraqi': 1,
#   'w+2=diplomats': 1,
#   'w+3=and': 1,
#   'w-1=were&w-2=airliner': 1,
#   'w+1=Iraqi&w+2=diplomats': 1,
#   'w-1=were&w+1=Iraqi': 1},
#  {'w-3=airliner': 1,
#   'w-2=were': 1,
#   'w-1=not': 1,
#   'w+1=diplomats': 1,
#   'w+2=and': 1,
#   'w+3=added': 1,
#   'w-1=not&w-2=were': 1,
#   'w+1=diplomats&w+2=and': 1,
#   'w-1=not&w+1=diplomats': 1},
#  {'w-3=were': 1,
#   'w-2=not': 1,
#   'w-1=Iraqi': 1,
#   'w+1=and': 1,
#   'w+2=added': 1,
#   'w+3=that': 1,
#   'w-1=Iraqi&w-2=not': 1,
#   'w+1=and&w+2=added': 1,
#   'w-1=Iraqi&w+1=and': 1},
#  {'w-3=not': 1,
#   'w-2=Iraqi': 1,
#   'w-1=diplomats': 1,
#   'w+1=added': 1,
#   'w+2=that': 1,
#   'w+3="': 1,
#   'w-1=diplomats&w-2=Iraqi': 1,
#   'w+1=added&w+2=that': 1,
#   'w-1=diplomats&w+1=added': 1},
#  {'w-3=Iraqi': 1,
#   'w-2=diplomats': 1,
#   'w-1=and': 1,
#   'w+1=that': 1,
#   'w+2="': 1,
#   'w+3=noble': 1,
#   'w-1=and&w-2=diplomats': 1,
#   'w+1=that&w+2="': 1,
#   'w-1=and&w+1=that': 1},
#  {'w-3=diplomats': 1,
#   'w-2=and': 1,
#   'w-1=added': 1,
#   'w+1="': 1,
#   'w+2=noble': 1,
#   'w+3=Iraqis': 1,
#   'w-1=added&w-2=and': 1,
#   'w+1="&w+2=noble': 1,
#   'w-1=added&w+1="': 1},
#  {'w-3=and': 1,
#   'w-2=added': 1,
#   'w-1=that': 1,
#   'w+1=noble': 1,
#   'w+2=Iraqis': 1,
#   'w+3="': 1,
#   'w-1=that&w-2=added': 1,
#   'w+1=noble&w+2=Iraqis': 1,
#   'w-1=that&w+1=noble': 1},
#  {'w-3=added': 1,
#   'w-2=that': 1,
#   'w-1="': 1,
#   'w+1=Iraqis': 1,
#   'w+2="': 1,
#   'w+3=would': 1,
#   'w-1="&w-2=that': 1,
#   'w+1=Iraqis&w+2="': 1,
#   'w-1="&w+1=Iraqis': 1},
#  {'w-3=that': 1,
#   'w-2="': 1,
#   'w-1=noble': 1,
#   'w+1="': 1,
#   'w+2=would': 1,
#   'w+3=never': 1,
#   'w-1=noble&w-2="': 1,
#   'w+1="&w+2=would': 1,
#   'w-1=noble&w+1="': 1},
#  {'w-3="': 1,
#   'w-2=noble': 1,
#   'w-1=Iraqis': 1,
#   'w+1=would': 1,
#   'w+2=never': 1,
#   'w+3=contemplate': 1,
#   'w-1=Iraqis&w-2=noble': 1,
#   'w+1=would&w+2=never': 1,
#   'w-1=Iraqis&w+1=would': 1},
#  {'w-3=noble': 1,
#   'w-2=Iraqis': 1,
#   'w-1="': 1,
#   'w+1=never': 1,
#   'w+2=contemplate': 1,
#   'w+3=such': 1,
#   'w-1="&w-2=Iraqis': 1,
#   'w+1=never&w+2=contemplate': 1,
#   'w-1="&w+1=never': 1},
#  {'w-3=Iraqis': 1,
#   'w-2="': 1,
#   'w-1=would': 1,
#   'w+1=contemplate': 1,
#   'w+2=such': 1,
#   'w+3=an': 1,
#   'w-1=would&w-2="': 1,
#   'w+1=contemplate&w+2=such': 1,
#   'w-1=would&w+1=contemplate': 1},
#  {'w-3="': 1,
#   'w-2=would': 1,
#   'w-1=never': 1,
#   'w+1=such': 1,
#   'w+2=an': 1,
#   'w+3=action': 1,
#   'w-1=never&w-2=would': 1,
#   'w+1=such&w+2=an': 1,
#   'w-1=never&w+1=such': 1},
#  {'w-3=would': 1,
#   'w-2=never': 1,
#   'w-1=contemplate': 1,
#   'w+1=an': 1,
#   'w+2=action': 1,
#   'w+3=.': 1,
#   'w-1=contemplate&w-2=never': 1,
#   'w+1=an&w+2=action': 1,
#   'w-1=contemplate&w+1=an': 1},
#  {'w-3=never': 1,
#   'w-2=contemplate': 1,
#   'w-1=such': 1,
#   'w+1=action': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1=such&w-2=contemplate': 1,
#   'w+1=action&w+2=.': 1,
#   'w-1=such&w+1=action': 1},
#  {'w-3=contemplate': 1,
#   'w-2=such': 1,
#   'w-1=an': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=an&w-2=such': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=an&w+1=.': 1},
#  {'w-3=such': 1,
#   'w-2=an': 1,
#   'w-1=action': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=action&w-2=an': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=action&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=official': 1,
#   'w+2=Iraqi': 1,
#   'w+3=News': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=official&w+2=Iraqi': 1,
#   'w-1=SSS&w+1=official': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=The': 1,
#   'w+1=Iraqi': 1,
#   'w+2=News': 1,
#   'w+3=Agency': 1,
#   'w-1=The&w-2=SSS': 1,
#   'w+1=Iraqi&w+2=News': 1,
#   'w-1=The&w+1=Iraqi': 1},
#  {'w-3=SSS': 1,
#   'w-2=The': 1,
#   'w-1=official': 1,
#   'w+1=News': 1,
#   'w+2=Agency': 1,
#   'w+3=(': 1,
#   'w-1=official&w-2=The': 1,
#   'w+1=News&w+2=Agency': 1,
#   'w-1=official&w+1=News': 1},
#  {'w-3=The': 1,
#   'w-2=official': 1,
#   'w-1=Iraqi': 1,
#   'w+1=Agency': 1,
#   'w+2=(': 1,
#   'w+3=INA': 1,
#   'w-1=Iraqi&w-2=official': 1,
#   'w+1=Agency&w+2=(': 1,
#   'w-1=Iraqi&w+1=Agency': 1},
#  {'w-3=official': 1,
#   'w-2=Iraqi': 1,
#   'w-1=News': 1,
#   'w+1=(': 1,
#   'w+2=INA': 1,
#   'w+3=)': 1,
#   'w-1=News&w-2=Iraqi': 1,
#   'w+1=(&w+2=INA': 1,
#   'w-1=News&w+1=(': 1},
#  {'w-3=Iraqi': 1,
#   'w-2=News': 1,
#   'w-1=Agency': 1,
#   'w+1=INA': 1,
#   'w+2=)': 1,
#   'w+3=quoted': 1,
#   'w-1=Agency&w-2=News': 1,
#   'w+1=INA&w+2=)': 1,
#   'w-1=Agency&w+1=INA': 1},
#  {'w-3=News': 1,
#   'w-2=Agency': 1,
#   'w-1=(': 1,
#   'w+1=)': 1,
#   'w+2=quoted': 1,
#   'w+3=Iraq': 1,
#   'w-1=(&w-2=Agency': 1,
#   'w+1=)&w+2=quoted': 1,
#   'w-1=(&w+1=)': 1},
#  {'w-3=Agency': 1,
#   'w-2=(': 1,
#   'w-1=INA': 1,
#   'w+1=quoted': 1,
#   'w+2=Iraq': 1,
#   "w+3='s": 1,
#   'w-1=INA&w-2=(': 1,
#   'w+1=quoted&w+2=Iraq': 1,
#   'w-1=INA&w+1=quoted': 1},
#  {'w-3=(': 1,
#   'w-2=INA': 1,
#   'w-1=)': 1,
#   'w+1=Iraq': 1,
#   "w+2='s": 1,
#   'w+3=ambassador': 1,
#   'w-1=)&w-2=INA': 1,
#   "w+1=Iraq&w+2='s": 1,
#   'w-1=)&w+1=Iraq': 1},
#  {'w-3=INA': 1,
#   'w-2=)': 1,
#   'w-1=quoted': 1,
#   "w+1='s": 1,
#   'w+2=ambassador': 1,
#   'w+3=in': 1,
#   'w-1=quoted&w-2=)': 1,
#   "w+1='s&w+2=ambassador": 1,
#   "w-1=quoted&w+1='s": 1},
#  {'w-3=)': 1,
#   'w-2=quoted': 1,
#   'w-1=Iraq': 1,
#   'w+1=ambassador': 1,
#   'w+2=in': 1,
#   'w+3=Khartoum': 1,
#   'w-1=Iraq&w-2=quoted': 1,
#   'w+1=ambassador&w+2=in': 1,
#   'w-1=Iraq&w+1=ambassador': 1},
#  {'w-3=quoted': 1,
#   'w-2=Iraq': 1,
#   "w-1='s": 1,
#   'w+1=in': 1,
#   'w+2=Khartoum': 1,
#   'w+3=as': 1,
#   "w-1='s&w-2=Iraq": 1,
#   'w+1=in&w+2=Khartoum': 1,
#   "w-1='s&w+1=in": 1},
#  {'w-3=Iraq': 1,
#   "w-2='s": 1,
#   'w-1=ambassador': 1,
#   'w+1=Khartoum': 1,
#   'w+2=as': 1,
#   'w+3=saying': 1,
#   "w-1=ambassador&w-2='s": 1,
#   'w+1=Khartoum&w+2=as': 1,
#   'w-1=ambassador&w+1=Khartoum': 1},
#  {"w-3='s": 1,
#   'w-2=ambassador': 1,
#   'w-1=in': 1,
#   'w+1=as': 1,
#   'w+2=saying': 1,
#   'w+3=that': 1,
#   'w-1=in&w-2=ambassador': 1,
#   'w+1=as&w+2=saying': 1,
#   'w-1=in&w+1=as': 1},
#  {'w-3=ambassador': 1,
#   'w-2=in': 1,
#   'w-1=Khartoum': 1,
#   'w+1=saying': 1,
#   'w+2=that': 1,
#   'w+3=Iraq': 1,
#   'w-1=Khartoum&w-2=in': 1,
#   'w+1=saying&w+2=that': 1,
#   'w-1=Khartoum&w+1=saying': 1},
#  {'w-3=in': 1,
#   'w-2=Khartoum': 1,
#   'w-1=as': 1,
#   'w+1=that': 1,
#   'w+2=Iraq': 1,
#   "w+3='s": 1,
#   'w-1=as&w-2=Khartoum': 1,
#   'w+1=that&w+2=Iraq': 1,
#   'w-1=as&w+1=that': 1},
#  {'w-3=Khartoum': 1,
#   'w-2=as': 1,
#   'w-1=saying': 1,
#   'w+1=Iraq': 1,
#   "w+2='s": 1,
#   'w+3=embassy': 1,
#   'w-1=saying&w-2=as': 1,
#   "w+1=Iraq&w+2='s": 1,
#   'w-1=saying&w+1=Iraq': 1},
#  {'w-3=as': 1,
#   'w-2=saying': 1,
#   'w-1=that': 1,
#   "w+1='s": 1,
#   'w+2=embassy': 1,
#   'w+3=in': 1,
#   'w-1=that&w-2=saying': 1,
#   "w+1='s&w+2=embassy": 1,
#   "w-1=that&w+1='s": 1},
#  {'w-3=saying': 1,
#   'w-2=that': 1,
#   'w-1=Iraq': 1,
#   'w+1=embassy': 1,
#   'w+2=in': 1,
#   'w+3=the': 1,
#   'w-1=Iraq&w-2=that': 1,
#   'w+1=embassy&w+2=in': 1,
#   'w-1=Iraq&w+1=embassy': 1},
#  {'w-3=that': 1,
#   'w-2=Iraq': 1,
#   "w-1='s": 1,
#   'w+1=in': 1,
#   'w+2=the': 1,
#   'w+3=Sudanese': 1,
#   "w-1='s&w-2=Iraq": 1,
#   'w+1=in&w+2=the': 1,
#   "w-1='s&w+1=in": 1},
#  {'w-3=Iraq': 1,
#   "w-2='s": 1,
#   'w-1=embassy': 1,
#   'w+1=the': 1,
#   'w+2=Sudanese': 1,
#   'w+3=capital': 1,
#   "w-1=embassy&w-2='s": 1,
#   'w+1=the&w+2=Sudanese': 1,
#   'w-1=embassy&w+1=the': 1},
#  {"w-3='s": 1,
#   'w-2=embassy': 1,
#   'w-1=in': 1,
#   'w+1=Sudanese': 1,
#   'w+2=capital': 1,
#   'w+3=had': 1,
#   'w-1=in&w-2=embassy': 1,
#   'w+1=Sudanese&w+2=capital': 1,
#   'w-1=in&w+1=Sudanese': 1},
#  {'w-3=embassy': 1,
#   'w-2=in': 1,
#   'w-1=the': 1,
#   'w+1=capital': 1,
#   'w+2=had': 1,
#   'w+3=nothing': 1,
#   'w-1=the&w-2=in': 1,
#   'w+1=capital&w+2=had': 1,
#   'w-1=the&w+1=capital': 1},
#  {'w-3=in': 1,
#   'w-2=the': 1,
#   'w-1=Sudanese': 1,
#   'w+1=had': 1,
#   'w+2=nothing': 1,
#   'w+3=to': 1,
#   'w-1=Sudanese&w-2=the': 1,
#   'w+1=had&w+2=nothing': 1,
#   'w-1=Sudanese&w+1=had': 1},
#  {'w-3=the': 1,
#   'w-2=Sudanese': 1,
#   'w-1=capital': 1,
#   'w+1=nothing': 1,
#   'w+2=to': 1,
#   'w+3=do': 1,
#   'w-1=capital&w-2=Sudanese': 1,
#   'w+1=nothing&w+2=to': 1,
#   'w-1=capital&w+1=nothing': 1},
#  {'w-3=Sudanese': 1,
#   'w-2=capital': 1,
#   'w-1=had': 1,
#   'w+1=to': 1,
#   'w+2=do': 1,
#   'w+3=with': 1,
#   'w-1=had&w-2=capital': 1,
#   'w+1=to&w+2=do': 1,
#   'w-1=had&w+1=to': 1},
#  {'w-3=capital': 1,
#   'w-2=had': 1,
#   'w-1=nothing': 1,
#   'w+1=do': 1,
#   'w+2=with': 1,
#   'w+3=the': 1,
#   'w-1=nothing&w-2=had': 1,
#   'w+1=do&w+2=with': 1,
#   'w-1=nothing&w+1=do': 1},
#  {'w-3=had': 1,
#   'w-2=nothing': 1,
#   'w-1=to': 1,
#   'w+1=with': 1,
#   'w+2=the': 1,
#   'w+3=Monday': 1,
#   'w-1=to&w-2=nothing': 1,
#   'w+1=with&w+2=the': 1,
#   'w-1=to&w+1=with': 1},
#  {'w-3=nothing': 1,
#   'w-2=to': 1,
#   'w-1=do': 1,
#   'w+1=the': 1,
#   'w+2=Monday': 1,
#   'w+3=night': 1,
#   'w-1=do&w-2=to': 1,
#   'w+1=the&w+2=Monday': 1,
#   'w-1=do&w+1=the': 1},
#  {'w-3=to': 1,
#   'w-2=do': 1,
#   'w-1=with': 1,
#   'w+1=Monday': 1,
#   'w+2=night': 1,
#   'w+3=hijacking': 1,
#   'w-1=with&w-2=do': 1,
#   'w+1=Monday&w+2=night': 1,
#   'w-1=with&w+1=Monday': 1},
#  {'w-3=do': 1,
#   'w-2=with': 1,
#   'w-1=the': 1,
#   'w+1=night': 1,
#   'w+2=hijacking': 1,
#   'w+3=.': 1,
#   'w-1=the&w-2=with': 1,
#   'w+1=night&w+2=hijacking': 1,
#   'w-1=the&w+1=night': 1},
#  {'w-3=with': 1,
#   'w-2=the': 1,
#   'w-1=Monday': 1,
#   'w+1=hijacking': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1=Monday&w-2=the': 1,
#   'w+1=hijacking&w+2=.': 1,
#   'w-1=Monday&w+1=hijacking': 1},
#  {'w-3=the': 1,
#   'w-2=Monday': 1,
#   'w-1=night': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=night&w-2=Monday': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=night&w+1=.': 1},
#  {'w-3=Monday': 1,
#   'w-2=night': 1,
#   'w-1=hijacking': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=hijacking&w-2=night': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=hijacking&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   "w+1='s": 1,
#   'w+2=ambassador': 1,
#   'w+3=in': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   "w+1='s&w+2=ambassador": 1,
#   "w-1=SSS&w+1='s": 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=Iraq': 1,
#   'w+1=ambassador': 1,
#   'w+2=in': 1,
#   'w+3=Khartoum': 1,
#   'w-1=Iraq&w-2=SSS': 1,
#   'w+1=ambassador&w+2=in': 1,
#   'w-1=Iraq&w+1=ambassador': 1},
#  {'w-3=SSS': 1,
#   'w-2=Iraq': 1,
#   "w-1='s": 1,
#   'w+1=in': 1,
#   'w+2=Khartoum': 1,
#   'w+3=denounced': 1,
#   "w-1='s&w-2=Iraq": 1,
#   'w+1=in&w+2=Khartoum': 1,
#   "w-1='s&w+1=in": 1},
#  {'w-3=Iraq': 1,
#   "w-2='s": 1,
#   'w-1=ambassador': 1,
#   'w+1=Khartoum': 1,
#   'w+2=denounced': 1,
#   'w+3=the': 1,
#   "w-1=ambassador&w-2='s": 1,
#   'w+1=Khartoum&w+2=denounced': 1,
#   'w-1=ambassador&w+1=Khartoum': 1},
#  {"w-3='s": 1,
#   'w-2=ambassador': 1,
#   'w-1=in': 1,
#   'w+1=denounced': 1,
#   'w+2=the': 1,
#   'w+3=hijacking': 1,
#   'w-1=in&w-2=ambassador': 1,
#   'w+1=denounced&w+2=the': 1,
#   'w-1=in&w+1=denounced': 1},
#  {'w-3=ambassador': 1,
#   'w-2=in': 1,
#   'w-1=Khartoum': 1,
#   'w+1=the': 1,
#   'w+2=hijacking': 1,
#   'w+3=and': 1,
#   'w-1=Khartoum&w-2=in': 1,
#   'w+1=the&w+2=hijacking': 1,
#   'w-1=Khartoum&w+1=the': 1},
#  {'w-3=in': 1,
#   'w-2=Khartoum': 1,
#   'w-1=denounced': 1,
#   'w+1=hijacking': 1,
#   'w+2=and': 1,
#   'w+3=described': 1,
#   'w-1=denounced&w-2=Khartoum': 1,
#   'w+1=hijacking&w+2=and': 1,
#   'w-1=denounced&w+1=hijacking': 1},
#  {'w-3=Khartoum': 1,
#   'w-2=denounced': 1,
#   'w-1=the': 1,
#   'w+1=and': 1,
#   'w+2=described': 1,
#   'w+3=it': 1,
#   'w-1=the&w-2=denounced': 1,
#   'w+1=and&w+2=described': 1,
#   'w-1=the&w+1=and': 1},
#  {'w-3=denounced': 1,
#   'w-2=the': 1,
#   'w-1=hijacking': 1,
#   'w+1=described': 1,
#   'w+2=it': 1,
#   'w+3=as': 1,
#   'w-1=hijacking&w-2=the': 1,
#   'w+1=described&w+2=it': 1,
#   'w-1=hijacking&w+1=described': 1},
#  {'w-3=the': 1,
#   'w-2=hijacking': 1,
#   'w-1=and': 1,
#   'w+1=it': 1,
#   'w+2=as': 1,
#   'w+3=a': 1,
#   'w-1=and&w-2=hijacking': 1,
#   'w+1=it&w+2=as': 1,
#   'w-1=and&w+1=it': 1},
#  {'w-3=hijacking': 1,
#   'w-2=and': 1,
#   'w-1=described': 1,
#   'w+1=as': 1,
#   'w+2=a': 1,
#   'w+3=terrorist': 1,
#   'w-1=described&w-2=and': 1,
#   'w+1=as&w+2=a': 1,
#   'w-1=described&w+1=as': 1},
#  {'w-3=and': 1,
#   'w-2=described': 1,
#   'w-1=it': 1,
#   'w+1=a': 1,
#   'w+2=terrorist': 1,
#   'w+3=act': 1,
#   'w-1=it&w-2=described': 1,
#   'w+1=a&w+2=terrorist': 1,
#   'w-1=it&w+1=a': 1},
#  {'w-3=described': 1,
#   'w-2=it': 1,
#   'w-1=as': 1,
#   'w+1=terrorist': 1,
#   'w+2=act': 1,
#   'w+3=which': 1,
#   'w-1=as&w-2=it': 1,
#   'w+1=terrorist&w+2=act': 1,
#   'w-1=as&w+1=terrorist': 1},
#  {'w-3=it': 1,
#   'w-2=as': 1,
#   'w-1=a': 1,
#   'w+1=act': 1,
#   'w+2=which': 1,
#   'w+3=had': 1,
#   'w-1=a&w-2=as': 1,
#   'w+1=act&w+2=which': 1,
#   'w-1=a&w+1=act': 1},
#  {'w-3=as': 1,
#   'w-2=a': 1,
#   'w-1=terrorist': 1,
#   'w+1=which': 1,
#   'w+2=had': 1,
#   'w+3=nothing': 1,
#   'w-1=terrorist&w-2=a': 1,
#   'w+1=which&w+2=had': 1,
#   'w-1=terrorist&w+1=which': 1},
#  {'w-3=a': 1,
#   'w-2=terrorist': 1,
#   'w-1=act': 1,
#   'w+1=had': 1,
#   'w+2=nothing': 1,
#   'w+3=to': 1,
#   'w-1=act&w-2=terrorist': 1,
#   'w+1=had&w+2=nothing': 1,
#   'w-1=act&w+1=had': 1},
#  {'w-3=terrorist': 1,
#   'w-2=act': 1,
#   'w-1=which': 1,
#   'w+1=nothing': 1,
#   'w+2=to': 1,
#   'w+3=do': 1,
#   'w-1=which&w-2=act': 1,
#   'w+1=nothing&w+2=to': 1,
#   'w-1=which&w+1=nothing': 1},
#  {'w-3=act': 1,
#   'w-2=which': 1,
#   'w-1=had': 1,
#   'w+1=to': 1,
#   'w+2=do': 1,
#   'w+3="': 1,
#   'w-1=had&w-2=which': 1,
#   'w+1=to&w+2=do': 1,
#   'w-1=had&w+1=to': 1},
#  {'w-3=which': 1,
#   'w-2=had': 1,
#   'w-1=nothing': 1,
#   'w+1=do': 1,
#   'w+2="': 1,
#   'w+3=with': 1,
#   'w-1=nothing&w-2=had': 1,
#   'w+1=do&w+2="': 1,
#   'w-1=nothing&w+1=do': 1},
#  {'w-3=had': 1,
#   'w-2=nothing': 1,
#   'w-1=to': 1,
#   'w+1="': 1,
#   'w+2=with': 1,
#   'w+3=the': 1,
#   'w-1=to&w-2=nothing': 1,
#   'w+1="&w+2=with': 1,
#   'w-1=to&w+1="': 1},
#  {'w-3=nothing': 1,
#   'w-2=to': 1,
#   'w-1=do': 1,
#   'w+1=with': 1,
#   'w+2=the': 1,
#   'w+3=morals': 1,
#   'w-1=do&w-2=to': 1,
#   'w+1=with&w+2=the': 1,
#   'w-1=do&w+1=with': 1},
#  {'w-3=to': 1,
#   'w-2=do': 1,
#   'w-1="': 1,
#   'w+1=the': 1,
#   'w+2=morals': 1,
#   'w+3=and': 1,
#   'w-1="&w-2=do': 1,
#   'w+1=the&w+2=morals': 1,
#   'w-1="&w+1=the': 1},
#  {'w-3=do': 1,
#   'w-2="': 1,
#   'w-1=with': 1,
#   'w+1=morals': 1,
#   'w+2=and': 1,
#   'w+3=values': 1,
#   'w-1=with&w-2="': 1,
#   'w+1=morals&w+2=and': 1,
#   'w-1=with&w+1=morals': 1},
#  {'w-3="': 1,
#   'w-2=with': 1,
#   'w-1=the': 1,
#   'w+1=and': 1,
#   'w+2=values': 1,
#   'w+3=of': 1,
#   'w-1=the&w-2=with': 1,
#   'w+1=and&w+2=values': 1,
#   'w-1=the&w+1=and': 1},
#  {'w-3=with': 1,
#   'w-2=the': 1,
#   'w-1=morals': 1,
#   'w+1=values': 1,
#   'w+2=of': 1,
#   'w+3=noble': 1,
#   'w-1=morals&w-2=the': 1,
#   'w+1=values&w+2=of': 1,
#   'w-1=morals&w+1=values': 1},
#  {'w-3=the': 1,
#   'w-2=morals': 1,
#   'w-1=and': 1,
#   'w+1=of': 1,
#   'w+2=noble': 1,
#   'w+3=Iraqis': 1,
#   'w-1=and&w-2=morals': 1,
#   'w+1=of&w+2=noble': 1,
#   'w-1=and&w+1=of': 1},
#  {'w-3=morals': 1,
#   'w-2=and': 1,
#   'w-1=values': 1,
#   'w+1=noble': 1,
#   'w+2=Iraqis': 1,
#   'w+3=,': 1,
#   'w-1=values&w-2=and': 1,
#   'w+1=noble&w+2=Iraqis': 1,
#   'w-1=values&w+1=noble': 1},
#  {'w-3=and': 1,
#   'w-2=values': 1,
#   'w-1=of': 1,
#   'w+1=Iraqis': 1,
#   'w+2=,': 1,
#   'w+3="': 1,
#   'w-1=of&w-2=values': 1,
#   'w+1=Iraqis&w+2=,': 1,
#   'w-1=of&w+1=Iraqis': 1},
#  {'w-3=values': 1,
#   'w-2=of': 1,
#   'w-1=noble': 1,
#   'w+1=,': 1,
#   'w+2="': 1,
#   'w+3=INA': 1,
#   'w-1=noble&w-2=of': 1,
#   'w+1=,&w+2="': 1,
#   'w-1=noble&w+1=,': 1},
#  {'w-3=of': 1,
#   'w-2=noble': 1,
#   'w-1=Iraqis': 1,
#   'w+1="': 1,
#   'w+2=INA': 1,
#   'w+3=said': 1,
#   'w-1=Iraqis&w-2=noble': 1,
#   'w+1="&w+2=INA': 1,
#   'w-1=Iraqis&w+1="': 1},
#  {'w-3=noble': 1,
#   'w-2=Iraqis': 1,
#   'w-1=,': 1,
#   'w+1=INA': 1,
#   'w+2=said': 1,
#   'w+3=.': 1,
#   'w-1=,&w-2=Iraqis': 1,
#   'w+1=INA&w+2=said': 1,
#   'w-1=,&w+1=INA': 1},
#  {'w-3=Iraqis': 1,
#   'w-2=,': 1,
#   'w-1="': 1,
#   'w+1=said': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1="&w-2=,': 1,
#   'w+1=said&w+2=.': 1,
#   'w-1="&w+1=said': 1},
#  {'w-3=,': 1,
#   'w-2="': 1,
#   'w-1=INA': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=INA&w-2="': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=INA&w+1=.': 1},
#  {'w-3="': 1,
#   'w-2=INA': 1,
#   'w-1=said': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=said&w-2=INA': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=said&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Abdulsamad': 1,
#   'w+2=Hameed': 1,
#   'w+3=Ali': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Abdulsamad&w+2=Hameed': 1,
#   'w-1=SSS&w+1=Abdulsamad': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=Ambassador': 1,
#   'w+1=Hameed': 1,
#   'w+2=Ali': 1,
#   'w+3=told': 1,
#   'w-1=Ambassador&w-2=SSS': 1,
#   'w+1=Hameed&w+2=Ali': 1,
#   'w-1=Ambassador&w+1=Hameed': 1},
#  {'w-3=SSS': 1,
#   'w-2=Ambassador': 1,
#   'w-1=Abdulsamad': 1,
#   'w+1=Ali': 1,
#   'w+2=told': 1,
#   'w+3=INA': 1,
#   'w-1=Abdulsamad&w-2=Ambassador': 1,
#   'w+1=Ali&w+2=told': 1,
#   'w-1=Abdulsamad&w+1=Ali': 1},
#  {'w-3=Ambassador': 1,
#   'w-2=Abdulsamad': 1,
#   'w-1=Hameed': 1,
#   'w+1=told': 1,
#   'w+2=INA': 1,
#   'w+3=there': 1,
#   'w-1=Hameed&w-2=Abdulsamad': 1,
#   'w+1=told&w+2=INA': 1,
#   'w-1=Hameed&w+1=told': 1},
#  {'w-3=Abdulsamad': 1,
#   'w-2=Hameed': 1,
#   'w-1=Ali': 1,
#   'w+1=INA': 1,
#   'w+2=there': 1,
#   'w+3=was': 1,
#   'w-1=Ali&w-2=Hameed': 1,
#   'w+1=INA&w+2=there': 1,
#   'w-1=Ali&w+1=INA': 1},
#  {'w-3=Hameed': 1,
#   'w-2=Ali': 1,
#   'w-1=told': 1,
#   'w+1=there': 1,
#   'w+2=was': 1,
#   'w+3=only': 1,
#   'w-1=told&w-2=Ali': 1,
#   'w+1=there&w+2=was': 1,
#   'w-1=told&w+1=there': 1},
#  {'w-3=Ali': 1,
#   'w-2=told': 1,
#   'w-1=INA': 1,
#   'w+1=was': 1,
#   'w+2=only': 1,
#   'w+3=one': 1,
#   'w-1=INA&w-2=told': 1,
#   'w+1=was&w+2=only': 1,
#   'w-1=INA&w+1=was': 1},
#  {'w-3=told': 1,
#   'w-2=INA': 1,
#   'w-1=there': 1,
#   'w+1=only': 1,
#   'w+2=one': 1,
#   'w+3=diplomat': 1,
#   'w-1=there&w-2=INA': 1,
#   'w+1=only&w+2=one': 1,
#   'w-1=there&w+1=only': 1},
#  {'w-3=INA': 1,
#   'w-2=there': 1,
#   'w-1=was': 1,
#   'w+1=one': 1,
#   'w+2=diplomat': 1,
#   'w+3=among': 1,
#   'w-1=was&w-2=there': 1,
#   'w+1=one&w+2=diplomat': 1,
#   'w-1=was&w+1=one': 1},
#  {'w-3=there': 1,
#   'w-2=was': 1,
#   'w-1=only': 1,
#   'w+1=diplomat': 1,
#   'w+2=among': 1,
#   'w+3=the': 1,
#   'w-1=only&w-2=was': 1,
#   'w+1=diplomat&w+2=among': 1,
#   'w-1=only&w+1=diplomat': 1},
#  {'w-3=was': 1,
#   'w-2=only': 1,
#   'w-1=one': 1,
#   'w+1=among': 1,
#   'w+2=the': 1,
#   'w+3=199': 1,
#   'w-1=one&w-2=only': 1,
#   'w+1=among&w+2=the': 1,
#   'w-1=one&w+1=among': 1},
#  {'w-3=only': 1,
#   'w-2=one': 1,
#   'w-1=diplomat': 1,
#   'w+1=the': 1,
#   'w+2=199': 1,
#   'w+3=passengers': 1,
#   'w-1=diplomat&w-2=one': 1,
#   'w+1=the&w+2=199': 1,
#   'w-1=diplomat&w+1=the': 1},
#  {'w-3=one': 1,
#   'w-2=diplomat': 1,
#   'w-1=among': 1,
#   'w+1=199': 1,
#   'w+2=passengers': 1,
#   'w+3=and': 1,
#   'w-1=among&w-2=diplomat': 1,
#   'w+1=199&w+2=passengers': 1,
#   'w-1=among&w+1=199': 1},
#  {'w-3=diplomat': 1,
#   'w-2=among': 1,
#   'w-1=the': 1,
#   'w+1=passengers': 1,
#   'w+2=and': 1,
#   'w+3=crew': 1,
#   'w-1=the&w-2=among': 1,
#   'w+1=passengers&w+2=and': 1,
#   'w-1=the&w+1=passengers': 1},
#  {'w-3=among': 1,
#   'w-2=the': 1,
#   'w-1=199': 1,
#   'w+1=and': 1,
#   'w+2=crew': 1,
#   'w+3=on': 1,
#   'w-1=199&w-2=the': 1,
#   'w+1=and&w+2=crew': 1,
#   'w-1=199&w+1=and': 1},
#  {'w-3=the': 1,
#   'w-2=199': 1,
#   'w-1=passengers': 1,
#   'w+1=crew': 1,
#   'w+2=on': 1,
#   'w+3=the': 1,
#   'w-1=passengers&w-2=199': 1,
#   'w+1=crew&w+2=on': 1,
#   'w-1=passengers&w+1=crew': 1},
#  {'w-3=199': 1,
#   'w-2=passengers': 1,
#   'w-1=and': 1,
#   'w+1=on': 1,
#   'w+2=the': 1,
#   'w+3=Sudan': 1,
#   'w-1=and&w-2=passengers': 1,
#   'w+1=on&w+2=the': 1,
#   'w-1=and&w+1=on': 1},
#  {'w-3=passengers': 1,
#   'w-2=and': 1,
#   'w-1=crew': 1,
#   'w+1=the': 1,
#   'w+2=Sudan': 1,
#   'w+3=Airways': 1,
#   'w-1=crew&w-2=and': 1,
#   'w+1=the&w+2=Sudan': 1,
#   'w-1=crew&w+1=the': 1},
#  {'w-3=and': 1,
#   'w-2=crew': 1,
#   'w-1=on': 1,
#   'w+1=Sudan': 1,
#   'w+2=Airways': 1,
#   'w+3=Airbus': 1,
#   'w-1=on&w-2=crew': 1,
#   'w+1=Sudan&w+2=Airways': 1,
#   'w-1=on&w+1=Sudan': 1},
#  {'w-3=crew': 1,
#   'w-2=on': 1,
#   'w-1=the': 1,
#   'w+1=Airways': 1,
#   'w+2=Airbus': 1,
#   'w+3=.': 1,
#   'w-1=the&w-2=on': 1,
#   'w+1=Airways&w+2=Airbus': 1,
#   'w-1=the&w+1=Airways': 1},
#  {'w-3=on': 1,
#   'w-2=the': 1,
#   'w-1=Sudan': 1,
#   'w+1=Airbus': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1=Sudan&w-2=the': 1,
#   'w+1=Airbus&w+2=.': 1,
#   'w-1=Sudan&w+1=Airbus': 1},
#  {'w-3=the': 1,
#   'w-2=Sudan': 1,
#   'w-1=Airways': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Airways&w-2=Sudan': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=Airways&w+1=.': 1},
#  {'w-3=Sudan': 1,
#   'w-2=Airways': 1,
#   'w-1=Airbus': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Airbus&w-2=Airways': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=Airbus&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=He': 1,
#   'w+2=was': 1,
#   'w+3=not': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=He&w+2=was': 1,
#   'w-1=SSS&w+1=He': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1="': 1,
#   'w+1=was': 1,
#   'w+2=not': 1,
#   'w+3=involved': 1,
#   'w-1="&w-2=SSS': 1,
#   'w+1=was&w+2=not': 1,
#   'w-1="&w+1=was': 1},
#  {'w-3=SSS': 1,
#   'w-2="': 1,
#   'w-1=He': 1,
#   'w+1=not': 1,
#   'w+2=involved': 1,
#   'w+3=...': 1,
#   'w-1=He&w-2="': 1,
#   'w+1=not&w+2=involved': 1,
#   'w-1=He&w+1=not': 1},
#  {'w-3="': 1,
#   'w-2=He': 1,
#   'w-1=was': 1,
#   'w+1=involved': 1,
#   'w+2=...': 1,
#   'w+3=EEE': 1,
#   'w-1=was&w-2=He': 1,
#   'w+1=involved&w+2=...': 1,
#   'w-1=was&w+1=involved': 1},
#  {'w-3=He': 1,
#   'w-2=was': 1,
#   'w-1=not': 1,
#   'w+1=...': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=not&w-2=was': 1,
#   'w+1=...&w+2=EEE': 1,
#   'w-1=not&w+1=...': 1},
#  {'w-3=was': 1,
#   'w-2=not': 1,
#   'w-1=involved': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=involved&w-2=not': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=involved&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=the': 1,
#   'w+2=contrary': 1,
#   'w+3=he': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=the&w+2=contrary': 1,
#   'w-1=SSS&w+1=the': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=on': 1,
#   'w+1=contrary': 1,
#   'w+2=he': 1,
#   'w+3=was': 1,
#   'w-1=on&w-2=SSS': 1,
#   'w+1=contrary&w+2=he': 1,
#   'w-1=on&w+1=contrary': 1},
#  {'w-3=SSS': 1,
#   'w-2=on': 1,
#   'w-1=the': 1,
#   'w+1=he': 1,
#   'w+2=was': 1,
#   'w+3=harassed': 1,
#   'w-1=the&w-2=on': 1,
#   'w+1=he&w+2=was': 1,
#   'w-1=the&w+1=he': 1},
#  {'w-3=on': 1,
#   'w-2=the': 1,
#   'w-1=contrary': 1,
#   'w+1=was': 1,
#   'w+2=harassed': 1,
#   'w+3=by': 1,
#   'w-1=contrary&w-2=the': 1,
#   'w+1=was&w+2=harassed': 1,
#   'w-1=contrary&w+1=was': 1},
#  {'w-3=the': 1,
#   'w-2=contrary': 1,
#   'w-1=he': 1,
#   'w+1=harassed': 1,
#   'w+2=by': 1,
#   'w+3=the': 1,
#   'w-1=he&w-2=contrary': 1,
#   'w+1=harassed&w+2=by': 1,
#   'w-1=he&w+1=harassed': 1},
#  {'w-3=contrary': 1,
#   'w-2=he': 1,
#   'w-1=was': 1,
#   'w+1=by': 1,
#   'w+2=the': 1,
#   'w+3=elements': 1,
#   'w-1=was&w-2=he': 1,
#   'w+1=by&w+2=the': 1,
#   'w-1=was&w+1=by': 1},
#  {'w-3=he': 1,
#   'w-2=was': 1,
#   'w-1=harassed': 1,
#   'w+1=the': 1,
#   'w+2=elements': 1,
#   'w+3=which': 1,
#   'w-1=harassed&w-2=was': 1,
#   'w+1=the&w+2=elements': 1,
#   'w-1=harassed&w+1=the': 1},
#  {'w-3=was': 1,
#   'w-2=harassed': 1,
#   'w-1=by': 1,
#   'w+1=elements': 1,
#   'w+2=which': 1,
#   'w+3=carried': 1,
#   'w-1=by&w-2=harassed': 1,
#   'w+1=elements&w+2=which': 1,
#   'w-1=by&w+1=elements': 1},
#  {'w-3=harassed': 1,
#   'w-2=by': 1,
#   'w-1=the': 1,
#   'w+1=which': 1,
#   'w+2=carried': 1,
#   'w+3=out': 1,
#   'w-1=the&w-2=by': 1,
#   'w+1=which&w+2=carried': 1,
#   'w-1=the&w+1=which': 1},
#  {'w-3=by': 1,
#   'w-2=the': 1,
#   'w-1=elements': 1,
#   'w+1=carried': 1,
#   'w+2=out': 1,
#   'w+3=the': 1,
#   'w-1=elements&w-2=the': 1,
#   'w+1=carried&w+2=out': 1,
#   'w-1=elements&w+1=carried': 1},
#  {'w-3=the': 1,
#   'w-2=elements': 1,
#   'w-1=which': 1,
#   'w+1=out': 1,
#   'w+2=the': 1,
#   'w+3=hijacking': 1,
#   'w-1=which&w-2=elements': 1,
#   'w+1=out&w+2=the': 1,
#   'w-1=which&w+1=out': 1},
#  {'w-3=elements': 1,
#   'w-2=which': 1,
#   'w-1=carried': 1,
#   'w+1=the': 1,
#   'w+2=hijacking': 1,
#   'w+3=,': 1,
#   'w-1=carried&w-2=which': 1,
#   'w+1=the&w+2=hijacking': 1,
#   'w-1=carried&w+1=the': 1},
#  {'w-3=which': 1,
#   'w-2=carried': 1,
#   'w-1=out': 1,
#   'w+1=hijacking': 1,
#   'w+2=,': 1,
#   'w+3="': 1,
#   'w-1=out&w-2=carried': 1,
#   'w+1=hijacking&w+2=,': 1,
#   'w-1=out&w+1=hijacking': 1},
#  {'w-3=carried': 1,
#   'w-2=out': 1,
#   'w-1=the': 1,
#   'w+1=,': 1,
#   'w+2="': 1,
#   'w+3=he': 1,
#   'w-1=the&w-2=out': 1,
#   'w+1=,&w+2="': 1,
#   'w-1=the&w+1=,': 1},
#  {'w-3=out': 1,
#   'w-2=the': 1,
#   'w-1=hijacking': 1,
#   'w+1="': 1,
#   'w+2=he': 1,
#   'w+3=said': 1,
#   'w-1=hijacking&w-2=the': 1,
#   'w+1="&w+2=he': 1,
#   'w-1=hijacking&w+1="': 1},
#  {'w-3=the': 1,
#   'w-2=hijacking': 1,
#   'w-1=,': 1,
#   'w+1=he': 1,
#   'w+2=said': 1,
#   'w+3=.': 1,
#   'w-1=,&w-2=hijacking': 1,
#   'w+1=he&w+2=said': 1,
#   'w-1=,&w+1=he': 1},
#  {'w-3=hijacking': 1,
#   'w-2=,': 1,
#   'w-1="': 1,
#   'w+1=said': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1="&w-2=,': 1,
#   'w+1=said&w+2=.': 1,
#   'w-1="&w+1=said': 1},
#  {'w-3=,': 1,
#   'w-2="': 1,
#   'w-1=he': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=he&w-2="': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=he&w+1=.': 1},
#  {'w-3="': 1,
#   'w-2=he': 1,
#   'w-1=said': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=said&w-2=he': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=said&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=did': 1,
#   'w+2=not': 1,
#   'w+3=say': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=did&w+2=not': 1,
#   'w-1=SSS&w+1=did': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=INA': 1,
#   'w+1=not': 1,
#   'w+2=say': 1,
#   'w+3=the': 1,
#   'w-1=INA&w-2=SSS': 1,
#   'w+1=not&w+2=say': 1,
#   'w-1=INA&w+1=not': 1},
#  {'w-3=SSS': 1,
#   'w-2=INA': 1,
#   'w-1=did': 1,
#   'w+1=say': 1,
#   'w+2=the': 1,
#   'w+3=hijackers': 1,
#   'w-1=did&w-2=INA': 1,
#   'w+1=say&w+2=the': 1,
#   'w-1=did&w+1=say': 1},
#  {'w-3=INA': 1,
#   'w-2=did': 1,
#   'w-1=not': 1,
#   'w+1=the': 1,
#   'w+2=hijackers': 1,
#   'w+3=were': 1,
#   'w-1=not&w-2=did': 1,
#   'w+1=the&w+2=hijackers': 1,
#   'w-1=not&w+1=the': 1},
#  {'w-3=did': 1,
#   'w-2=not': 1,
#   'w-1=say': 1,
#   'w+1=hijackers': 1,
#   'w+2=were': 1,
#   'w+3=Iraqis': 1,
#   'w-1=say&w-2=not': 1,
#   'w+1=hijackers&w+2=were': 1,
#   'w-1=say&w+1=hijackers': 1},
#  {'w-3=not': 1,
#   'w-2=say': 1,
#   'w-1=the': 1,
#   'w+1=were': 1,
#   'w+2=Iraqis': 1,
#   'w+3=.': 1,
#   'w-1=the&w-2=say': 1,
#   'w+1=were&w+2=Iraqis': 1,
#   'w-1=the&w+1=were': 1},
#  {'w-3=say': 1,
#   'w-2=the': 1,
#   'w-1=hijackers': 1,
#   'w+1=Iraqis': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1=hijackers&w-2=the': 1,
#   'w+1=Iraqis&w+2=.': 1,
#   'w-1=hijackers&w+1=Iraqis': 1},
#  {'w-3=the': 1,
#   'w-2=hijackers': 1,
#   'w-1=were': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=were&w-2=hijackers': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=were&w+1=.': 1},
#  {'w-3=hijackers': 1,
#   'w-2=were': 1,
#   'w-1=Iraqis': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Iraqis&w-2=were': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=Iraqis&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=hijack': 1,
#   'w+2=started': 1,
#   'w+3=when': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=hijack&w+2=started': 1,
#   'w-1=SSS&w+1=hijack': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=The': 1,
#   'w+1=started': 1,
#   'w+2=when': 1,
#   'w+3=the': 1,
#   'w-1=The&w-2=SSS': 1,
#   'w+1=started&w+2=when': 1,
#   'w-1=The&w+1=started': 1},
#  {'w-3=SSS': 1,
#   'w-2=The': 1,
#   'w-1=hijack': 1,
#   'w+1=when': 1,
#   'w+2=the': 1,
#   'w+3=flight': 1,
#   'w-1=hijack&w-2=The': 1,
#   'w+1=when&w+2=the': 1,
#   'w-1=hijack&w+1=when': 1},
#  {'w-3=The': 1,
#   'w-2=hijack': 1,
#   'w-1=started': 1,
#   'w+1=the': 1,
#   'w+2=flight': 1,
#   'w+3=left': 1,
#   'w-1=started&w-2=hijack': 1,
#   'w+1=the&w+2=flight': 1,
#   'w-1=started&w+1=the': 1},
#  {'w-3=hijack': 1,
#   'w-2=started': 1,
#   'w-1=when': 1,
#   'w+1=flight': 1,
#   'w+2=left': 1,
#   'w+3=Khartoum': 1,
#   'w-1=when&w-2=started': 1,
#   'w+1=flight&w+2=left': 1,
#   'w-1=when&w+1=flight': 1},
#  {'w-3=started': 1,
#   'w-2=when': 1,
#   'w-1=the': 1,
#   'w+1=left': 1,
#   'w+2=Khartoum': 1,
#   'w+3=for': 1,
#   'w-1=the&w-2=when': 1,
#   'w+1=left&w+2=Khartoum': 1,
#   'w-1=the&w+1=left': 1},
#  {'w-3=when': 1,
#   'w-2=the': 1,
#   'w-1=flight': 1,
#   'w+1=Khartoum': 1,
#   'w+2=for': 1,
#   'w+3=Amman': 1,
#   'w-1=flight&w-2=the': 1,
#   'w+1=Khartoum&w+2=for': 1,
#   'w-1=flight&w+1=Khartoum': 1},
#  {'w-3=the': 1,
#   'w-2=flight': 1,
#   'w-1=left': 1,
#   'w+1=for': 1,
#   'w+2=Amman': 1,
#   'w+3=on': 1,
#   'w-1=left&w-2=flight': 1,
#   'w+1=for&w+2=Amman': 1,
#   'w-1=left&w+1=for': 1},
#  {'w-3=flight': 1,
#   'w-2=left': 1,
#   'w-1=Khartoum': 1,
#   'w+1=Amman': 1,
#   'w+2=on': 1,
#   'w+3=Monday': 1,
#   'w-1=Khartoum&w-2=left': 1,
#   'w+1=Amman&w+2=on': 1,
#   'w-1=Khartoum&w+1=Amman': 1},
#  {'w-3=left': 1,
#   'w-2=Khartoum': 1,
#   'w-1=for': 1,
#   'w+1=on': 1,
#   'w+2=Monday': 1,
#   'w+3=night': 1,
#   'w-1=for&w-2=Khartoum': 1,
#   'w+1=on&w+2=Monday': 1,
#   'w-1=for&w+1=on': 1},
#  {'w-3=Khartoum': 1,
#   'w-2=for': 1,
#   'w-1=Amman': 1,
#   'w+1=Monday': 1,
#   'w+2=night': 1,
#   'w+3=.': 1,
#   'w-1=Amman&w-2=for': 1,
#   'w+1=Monday&w+2=night': 1,
#   'w-1=Amman&w+1=Monday': 1},
#  {'w-3=for': 1,
#   'w-2=Amman': 1,
#   'w-1=on': 1,
#   'w+1=night': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1=on&w-2=Amman': 1,
#   'w+1=night&w+2=.': 1,
#   'w-1=on&w+1=night': 1},
#  {'w-3=Amman': 1,
#   'w-2=on': 1,
#   'w-1=Monday': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Monday&w-2=on': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=Monday&w+1=.': 1},
#  {'w-3=on': 1,
#   'w-2=Monday': 1,
#   'w-1=night': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=night&w-2=Monday': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=night&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=hijackers': 1,
#   'w+2=told': 1,
#   'w+3=the': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=hijackers&w+2=told': 1,
#   'w-1=SSS&w+1=hijackers': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=The': 1,
#   'w+1=told': 1,
#   'w+2=the': 1,
#   'w+3=crew': 1,
#   'w-1=The&w-2=SSS': 1,
#   'w+1=told&w+2=the': 1,
#   'w-1=The&w+1=told': 1},
#  {'w-3=SSS': 1,
#   'w-2=The': 1,
#   'w-1=hijackers': 1,
#   'w+1=the': 1,
#   'w+2=crew': 1,
#   'w+3=they': 1,
#   'w-1=hijackers&w-2=The': 1,
#   'w+1=the&w+2=crew': 1,
#   'w-1=hijackers&w+1=the': 1},
#  {'w-3=The': 1,
#   'w-2=hijackers': 1,
#   'w-1=told': 1,
#   'w+1=crew': 1,
#   'w+2=they': 1,
#   'w+3=had': 1,
#   'w-1=told&w-2=hijackers': 1,
#   'w+1=crew&w+2=they': 1,
#   'w-1=told&w+1=crew': 1},
#  {'w-3=hijackers': 1,
#   'w-2=told': 1,
#   'w-1=the': 1,
#   'w+1=they': 1,
#   'w+2=had': 1,
#   'w+3=grenades': 1,
#   'w-1=the&w-2=told': 1,
#   'w+1=they&w+2=had': 1,
#   'w-1=the&w+1=they': 1},
#  {'w-3=told': 1,
#   'w-2=the': 1,
#   'w-1=crew': 1,
#   'w+1=had': 1,
#   'w+2=grenades': 1,
#   'w+3=and': 1,
#   'w-1=crew&w-2=the': 1,
#   'w+1=had&w+2=grenades': 1,
#   'w-1=crew&w+1=had': 1},
#  {'w-3=the': 1,
#   'w-2=crew': 1,
#   'w-1=they': 1,
#   'w+1=grenades': 1,
#   'w+2=and': 1,
#   'w+3=other': 1,
#   'w-1=they&w-2=crew': 1,
#   'w+1=grenades&w+2=and': 1,
#   'w-1=they&w+1=grenades': 1},
#  {'w-3=crew': 1,
#   'w-2=they': 1,
#   'w-1=had': 1,
#   'w+1=and': 1,
#   'w+2=other': 1,
#   'w+3=explosives': 1,
#   'w-1=had&w-2=they': 1,
#   'w+1=and&w+2=other': 1,
#   'w-1=had&w+1=and': 1},
#  {'w-3=they': 1,
#   'w-2=had': 1,
#   'w-1=grenades': 1,
#   'w+1=other': 1,
#   'w+2=explosives': 1,
#   'w+3=and': 1,
#   'w-1=grenades&w-2=had': 1,
#   'w+1=other&w+2=explosives': 1,
#   'w-1=grenades&w+1=other': 1},
#  {'w-3=had': 1,
#   'w-2=grenades': 1,
#   'w-1=and': 1,
#   'w+1=explosives': 1,
#   'w+2=and': 1,
#   'w+3=threatened': 1,
#   'w-1=and&w-2=grenades': 1,
#   'w+1=explosives&w+2=and': 1,
#   'w-1=and&w+1=explosives': 1},
#  {'w-3=grenades': 1,
#   'w-2=and': 1,
#   'w-1=other': 1,
#   'w+1=and': 1,
#   'w+2=threatened': 1,
#   'w+3=to': 1,
#   'w-1=other&w-2=and': 1,
#   'w+1=and&w+2=threatened': 1,
#   'w-1=other&w+1=and': 1},
#  {'w-3=and': 1,
#   'w-2=other': 1,
#   'w-1=explosives': 1,
#   'w+1=threatened': 1,
#   'w+2=to': 1,
#   'w+3=blow': 1,
#   'w-1=explosives&w-2=other': 1,
#   'w+1=threatened&w+2=to': 1,
#   'w-1=explosives&w+1=threatened': 1},
#  {'w-3=other': 1,
#   'w-2=explosives': 1,
#   'w-1=and': 1,
#   'w+1=to': 1,
#   'w+2=blow': 1,
#   'w+3=up': 1,
#   'w-1=and&w-2=explosives': 1,
#   'w+1=to&w+2=blow': 1,
#   'w-1=and&w+1=to': 1},
#  {'w-3=explosives': 1,
#   'w-2=and': 1,
#   'w-1=threatened': 1,
#   'w+1=blow': 1,
#   'w+2=up': 1,
#   'w+3=the': 1,
#   'w-1=threatened&w-2=and': 1,
#   'w+1=blow&w+2=up': 1,
#   'w-1=threatened&w+1=blow': 1},
#  {'w-3=and': 1,
#   'w-2=threatened': 1,
#   'w-1=to': 1,
#   'w+1=up': 1,
#   'w+2=the': 1,
#   'w+3=plane': 1,
#   'w-1=to&w-2=threatened': 1,
#   'w+1=up&w+2=the': 1,
#   'w-1=to&w+1=up': 1},
#  {'w-3=threatened': 1,
#   'w-2=to': 1,
#   'w-1=blow': 1,
#   'w+1=the': 1,
#   'w+2=plane': 1,
#   'w+3=if': 1,
#   'w-1=blow&w-2=to': 1,
#   'w+1=the&w+2=plane': 1,
#   'w-1=blow&w+1=the': 1},
#  {'w-3=to': 1,
#   'w-2=blow': 1,
#   'w-1=up': 1,
#   'w+1=plane': 1,
#   'w+2=if': 1,
#   'w+3=they': 1,
#   'w-1=up&w-2=blow': 1,
#   'w+1=plane&w+2=if': 1,
#   'w-1=up&w+1=plane': 1},
#  {'w-3=blow': 1,
#   'w-2=up': 1,
#   'w-1=the': 1,
#   'w+1=if': 1,
#   'w+2=they': 1,
#   'w+3=were': 1,
#   'w-1=the&w-2=up': 1,
#   'w+1=if&w+2=they': 1,
#   'w-1=the&w+1=if': 1},
#  {'w-3=up': 1,
#   'w-2=the': 1,
#   'w-1=plane': 1,
#   'w+1=they': 1,
#   'w+2=were': 1,
#   'w+3=not': 1,
#   'w-1=plane&w-2=the': 1,
#   'w+1=they&w+2=were': 1,
#   'w-1=plane&w+1=they': 1},
#  {'w-3=the': 1,
#   'w-2=plane': 1,
#   'w-1=if': 1,
#   'w+1=were': 1,
#   'w+2=not': 1,
#   'w+3=taken': 1,
#   'w-1=if&w-2=plane': 1,
#   'w+1=were&w+2=not': 1,
#   'w-1=if&w+1=were': 1},
#  {'w-3=plane': 1,
#   'w-2=if': 1,
#   'w-1=they': 1,
#   'w+1=not': 1,
#   'w+2=taken': 1,
#   'w+3=to': 1,
#   'w-1=they&w-2=if': 1,
#   'w+1=not&w+2=taken': 1,
#   'w-1=they&w+1=not': 1},
#  {'w-3=if': 1,
#   'w-2=they': 1,
#   'w-1=were': 1,
#   'w+1=taken': 1,
#   'w+2=to': 1,
#   'w+3=London': 1,
#   'w-1=were&w-2=they': 1,
#   'w+1=taken&w+2=to': 1,
#   'w-1=were&w+1=taken': 1},
#  {'w-3=they': 1,
#   'w-2=were': 1,
#   'w-1=not': 1,
#   'w+1=to': 1,
#   'w+2=London': 1,
#   'w+3=.': 1,
#   'w-1=not&w-2=were': 1,
#   'w+1=to&w+2=London': 1,
#   'w-1=not&w+1=to': 1},
#  {'w-3=were': 1,
#   'w-2=not': 1,
#   'w-1=taken': 1,
#   'w+1=London': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1=taken&w-2=not': 1,
#   'w+1=London&w+2=.': 1,
#   'w-1=taken&w+1=London': 1},
#  {'w-3=not': 1,
#   'w-2=taken': 1,
#   'w-1=to': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=to&w-2=taken': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=to&w+1=.': 1},
#  {'w-3=taken': 1,
#   'w-2=to': 1,
#   'w-1=London': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=London&w-2=to': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=London&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=airliner': 1,
#   'w+2=refuelled': 1,
#   'w+3=at': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=airliner&w+2=refuelled': 1,
#   'w-1=SSS&w+1=airliner': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=The': 1,
#   'w+1=refuelled': 1,
#   'w+2=at': 1,
#   'w+3=Larnaca': 1,
#   'w-1=The&w-2=SSS': 1,
#   'w+1=refuelled&w+2=at': 1,
#   'w-1=The&w+1=refuelled': 1},
#  {'w-3=SSS': 1,
#   'w-2=The': 1,
#   'w-1=airliner': 1,
#   'w+1=at': 1,
#   'w+2=Larnaca': 1,
#   'w+3=,': 1,
#   'w-1=airliner&w-2=The': 1,
#   'w+1=at&w+2=Larnaca': 1,
#   'w-1=airliner&w+1=at': 1},
#  {'w-3=The': 1,
#   'w-2=airliner': 1,
#   'w-1=refuelled': 1,
#   'w+1=Larnaca': 1,
#   'w+2=,': 1,
#   'w+3=Cyprus': 1,
#   'w-1=refuelled&w-2=airliner': 1,
#   'w+1=Larnaca&w+2=,': 1,
#   'w-1=refuelled&w+1=Larnaca': 1},
#  {'w-3=airliner': 1,
#   'w-2=refuelled': 1,
#   'w-1=at': 1,
#   'w+1=,': 1,
#   'w+2=Cyprus': 1,
#   'w+3=and': 1,
#   'w-1=at&w-2=refuelled': 1,
#   'w+1=,&w+2=Cyprus': 1,
#   'w-1=at&w+1=,': 1},
#  {'w-3=refuelled': 1,
#   'w-2=at': 1,
#   'w-1=Larnaca': 1,
#   'w+1=Cyprus': 1,
#   'w+2=and': 1,
#   'w+3=landed': 1,
#   'w-1=Larnaca&w-2=at': 1,
#   'w+1=Cyprus&w+2=and': 1,
#   'w-1=Larnaca&w+1=Cyprus': 1},
#  {'w-3=at': 1,
#   'w-2=Larnaca': 1,
#   'w-1=,': 1,
#   'w+1=and': 1,
#   'w+2=landed': 1,
#   'w+3=at': 1,
#   'w-1=,&w-2=Larnaca': 1,
#   'w+1=and&w+2=landed': 1,
#   'w-1=,&w+1=and': 1},
#  {'w-3=Larnaca': 1,
#   'w-2=,': 1,
#   'w-1=Cyprus': 1,
#   'w+1=landed': 1,
#   'w+2=at': 1,
#   'w+3=London': 1,
#   'w-1=Cyprus&w-2=,': 1,
#   'w+1=landed&w+2=at': 1,
#   'w-1=Cyprus&w+1=landed': 1},
#  {'w-3=,': 1,
#   'w-2=Cyprus': 1,
#   'w-1=and': 1,
#   'w+1=at': 1,
#   'w+2=London': 1,
#   "w+3='s": 1,
#   'w-1=and&w-2=Cyprus': 1,
#   'w+1=at&w+2=London': 1,
#   'w-1=and&w+1=at': 1},
#  {'w-3=Cyprus': 1,
#   'w-2=and': 1,
#   'w-1=landed': 1,
#   'w+1=London': 1,
#   "w+2='s": 1,
#   'w+3=Stansted': 1,
#   'w-1=landed&w-2=and': 1,
#   "w+1=London&w+2='s": 1,
#   'w-1=landed&w+1=London': 1},
#  {'w-3=and': 1,
#   'w-2=landed': 1,
#   'w-1=at': 1,
#   "w+1='s": 1,
#   'w+2=Stansted': 1,
#   'w+3=airport': 1,
#   'w-1=at&w-2=landed': 1,
#   "w+1='s&w+2=Stansted": 1,
#   "w-1=at&w+1='s": 1},
#  {'w-3=landed': 1,
#   'w-2=at': 1,
#   'w-1=London': 1,
#   'w+1=Stansted': 1,
#   'w+2=airport': 1,
#   'w+3=in': 1,
#   'w-1=London&w-2=at': 1,
#   'w+1=Stansted&w+2=airport': 1,
#   'w-1=London&w+1=Stansted': 1},
#  {'w-3=at': 1,
#   'w-2=London': 1,
#   "w-1='s": 1,
#   'w+1=airport': 1,
#   'w+2=in': 1,
#   'w+3=the': 1,
#   "w-1='s&w-2=London": 1,
#   'w+1=airport&w+2=in': 1,
#   "w-1='s&w+1=airport": 1},
#  {'w-3=London': 1,
#   "w-2='s": 1,
#   'w-1=Stansted': 1,
#   'w+1=in': 1,
#   'w+2=the': 1,
#   'w+3=early': 1,
#   "w-1=Stansted&w-2='s": 1,
#   'w+1=in&w+2=the': 1,
#   'w-1=Stansted&w+1=in': 1},
#  {"w-3='s": 1,
#   'w-2=Stansted': 1,
#   'w-1=airport': 1,
#   'w+1=the': 1,
#   'w+2=early': 1,
#   'w+3=hours': 1,
#   'w-1=airport&w-2=Stansted': 1,
#   'w+1=the&w+2=early': 1,
#   'w-1=airport&w+1=the': 1},
#  {'w-3=Stansted': 1,
#   'w-2=airport': 1,
#   'w-1=in': 1,
#   'w+1=early': 1,
#   'w+2=hours': 1,
#   'w+3=of': 1,
#   'w-1=in&w-2=airport': 1,
#   'w+1=early&w+2=hours': 1,
#   'w-1=in&w+1=early': 1},
#  {'w-3=airport': 1,
#   'w-2=in': 1,
#   'w-1=the': 1,
#   'w+1=hours': 1,
#   'w+2=of': 1,
#   'w+3=Tuesday': 1,
#   'w-1=the&w-2=in': 1,
#   'w+1=hours&w+2=of': 1,
#   'w-1=the&w+1=hours': 1},
#  {'w-3=in': 1,
#   'w-2=the': 1,
#   'w-1=early': 1,
#   'w+1=of': 1,
#   'w+2=Tuesday': 1,
#   'w+3=.': 1,
#   'w-1=early&w-2=the': 1,
#   'w+1=of&w+2=Tuesday': 1,
#   'w-1=early&w+1=of': 1},
#  {'w-3=the': 1,
#   'w-2=early': 1,
#   'w-1=hours': 1,
#   'w+1=Tuesday': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1=hours&w-2=early': 1,
#   'w+1=Tuesday&w+2=.': 1,
#   'w-1=hours&w+1=Tuesday': 1},
#  {'w-3=early': 1,
#   'w-2=hours': 1,
#   'w-1=of': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=of&w-2=hours': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=of&w+1=.': 1},
#  {'w-3=hours': 1,
#   'w-2=of': 1,
#   'w-1=Tuesday': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Tuesday&w-2=of': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=Tuesday&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Iraqi': 1,
#   'w+2=suspected': 1,
#   'w+3=hijackers': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Iraqi&w+2=suspected': 1,
#   'w-1=SSS&w+1=Iraqi': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=Seven': 1,
#   'w+1=suspected': 1,
#   'w+2=hijackers': 1,
#   'w+3=surrendered': 1,
#   'w-1=Seven&w-2=SSS': 1,
#   'w+1=suspected&w+2=hijackers': 1,
#   'w-1=Seven&w+1=suspected': 1},
#  {'w-3=SSS': 1,
#   'w-2=Seven': 1,
#   'w-1=Iraqi': 1,
#   'w+1=hijackers': 1,
#   'w+2=surrendered': 1,
#   'w+3=and': 1,
#   'w-1=Iraqi&w-2=Seven': 1,
#   'w+1=hijackers&w+2=surrendered': 1,
#   'w-1=Iraqi&w+1=hijackers': 1},
#  {'w-3=Seven': 1,
#   'w-2=Iraqi': 1,
#   'w-1=suspected': 1,
#   'w+1=surrendered': 1,
#   'w+2=and': 1,
#   'w+3=British': 1,
#   'w-1=suspected&w-2=Iraqi': 1,
#   'w+1=surrendered&w+2=and': 1,
#   'w-1=suspected&w+1=surrendered': 1},
#  {'w-3=Iraqi': 1,
#   'w-2=suspected': 1,
#   'w-1=hijackers': 1,
#   'w+1=and': 1,
#   'w+2=British': 1,
#   'w+3=police': 1,
#   'w-1=hijackers&w-2=suspected': 1,
#   'w+1=and&w+2=British': 1,
#   'w-1=hijackers&w+1=and': 1},
#  {'w-3=suspected': 1,
#   'w-2=hijackers': 1,
#   'w-1=surrendered': 1,
#   'w+1=British': 1,
#   'w+2=police': 1,
#   'w+3=said': 1,
#   'w-1=surrendered&w-2=hijackers': 1,
#   'w+1=British&w+2=police': 1,
#   'w-1=surrendered&w+1=British': 1},
#  {'w-3=hijackers': 1,
#   'w-2=surrendered': 1,
#   'w-1=and': 1,
#   'w+1=police': 1,
#   'w+2=said': 1,
#   'w+3=they': 1,
#   'w-1=and&w-2=surrendered': 1,
#   'w+1=police&w+2=said': 1,
#   'w-1=and&w+1=police': 1},
#  {'w-3=surrendered': 1,
#   'w-2=and': 1,
#   'w-1=British': 1,
#   'w+1=said': 1,
#   'w+2=they': 1,
#   'w+3=had': 1,
#   'w-1=British&w-2=and': 1,
#   'w+1=said&w+2=they': 1,
#   'w-1=British&w+1=said': 1},
#  {'w-3=and': 1,
#   'w-2=British': 1,
#   'w-1=police': 1,
#   'w+1=they': 1,
#   'w+2=had': 1,
#   'w+3=apparently': 1,
#   'w-1=police&w-2=British': 1,
#   'w+1=they&w+2=had': 1,
#   'w-1=police&w+1=they': 1},
#  {'w-3=British': 1,
#   'w-2=police': 1,
#   'w-1=said': 1,
#   'w+1=had': 1,
#   'w+2=apparently': 1,
#   'w+3=asked': 1,
#   'w-1=said&w-2=police': 1,
#   'w+1=had&w+2=apparently': 1,
#   'w-1=said&w+1=had': 1},
#  {'w-3=police': 1,
#   'w-2=said': 1,
#   'w-1=they': 1,
#   'w+1=apparently': 1,
#   'w+2=asked': 1,
#   'w+3=for': 1,
#   'w-1=they&w-2=said': 1,
#   'w+1=apparently&w+2=asked': 1,
#   'w-1=they&w+1=apparently': 1},
#  {'w-3=said': 1,
#   'w-2=they': 1,
#   'w-1=had': 1,
#   'w+1=asked': 1,
#   'w+2=for': 1,
#   'w+3=political': 1,
#   'w-1=had&w-2=they': 1,
#   'w+1=asked&w+2=for': 1,
#   'w-1=had&w+1=asked': 1},
#  {'w-3=they': 1,
#   'w-2=had': 1,
#   'w-1=apparently': 1,
#   'w+1=for': 1,
#   'w+2=political': 1,
#   'w+3=asylum': 1,
#   'w-1=apparently&w-2=had': 1,
#   'w+1=for&w+2=political': 1,
#   'w-1=apparently&w+1=for': 1},
#  {'w-3=had': 1,
#   'w-2=apparently': 1,
#   'w-1=asked': 1,
#   'w+1=political': 1,
#   'w+2=asylum': 1,
#   'w+3=.': 1,
#   'w-1=asked&w-2=apparently': 1,
#   'w+1=political&w+2=asylum': 1,
#   'w-1=asked&w+1=political': 1},
#  {'w-3=apparently': 1,
#   'w-2=asked': 1,
#   'w-1=for': 1,
#   'w+1=asylum': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1=for&w-2=asked': 1,
#   'w+1=asylum&w+2=.': 1,
#   'w-1=for&w+1=asylum': 1},
#  {'w-3=asked': 1,
#   'w-2=for': 1,
#   'w-1=political': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=political&w-2=for': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=political&w+1=.': 1},
#  {'w-3=for': 1,
#   'w-2=political': 1,
#   'w-1=asylum': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=asylum&w-2=political': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=asylum&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=had': 1,
#   'w+2=brought': 1,
#   'w+3=their': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=had&w+2=brought': 1,
#   'w-1=SSS&w+1=had': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=Several': 1,
#   'w+1=brought': 1,
#   'w+2=their': 1,
#   'w+3=families': 1,
#   'w-1=Several&w-2=SSS': 1,
#   'w+1=brought&w+2=their': 1,
#   'w-1=Several&w+1=brought': 1},
#  {'w-3=SSS': 1,
#   'w-2=Several': 1,
#   'w-1=had': 1,
#   'w+1=their': 1,
#   'w+2=families': 1,
#   'w+3=along': 1,
#   'w-1=had&w-2=Several': 1,
#   'w+1=their&w+2=families': 1,
#   'w-1=had&w+1=their': 1},
#  {'w-3=Several': 1,
#   'w-2=had': 1,
#   'w-1=brought': 1,
#   'w+1=families': 1,
#   'w+2=along': 1,
#   'w+3=,': 1,
#   'w-1=brought&w-2=had': 1,
#   'w+1=families&w+2=along': 1,
#   'w-1=brought&w+1=families': 1},
#  {'w-3=had': 1,
#   'w-2=brought': 1,
#   'w-1=their': 1,
#   'w+1=along': 1,
#   'w+2=,': 1,
#   'w+3=including': 1,
#   'w-1=their&w-2=brought': 1,
#   'w+1=along&w+2=,': 1,
#   'w-1=their&w+1=along': 1},
#  {'w-3=brought': 1,
#   'w-2=their': 1,
#   'w-1=families': 1,
#   'w+1=,': 1,
#   'w+2=including': 1,
#   'w+3=children': 1,
#   'w-1=families&w-2=their': 1,
#   'w+1=,&w+2=including': 1,
#   'w-1=families&w+1=,': 1},
#  {'w-3=their': 1,
#   'w-2=families': 1,
#   'w-1=along': 1,
#   'w+1=including': 1,
#   'w+2=children': 1,
#   'w+3=.': 1,
#   'w-1=along&w-2=families': 1,
#   'w+1=including&w+2=children': 1,
#   'w-1=along&w+1=including': 1},
#  {'w-3=families': 1,
#   'w-2=along': 1,
#   'w-1=,': 1,
#   'w+1=children': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1=,&w-2=along': 1,
#   'w+1=children&w+2=.': 1,
#   'w-1=,&w+1=children': 1},
#  {'w-3=along': 1,
#   'w-2=,': 1,
#   'w-1=including': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=including&w-2=,': 1,
#   'w+1=.&w+2=EEE': 1,
#   'w-1=including&w+1=.': 1},
#  {'w-3=,': 1,
#   'w-2=including': 1,
#   'w-1=children': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=children&w-2=including': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=children&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=SSS&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=-': 1,
#   'w+2=ENGLISH': 1,
#   'w+3=COUNTY': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=-&w+2=ENGLISH': 1,
#   'w-1=SSS&w+1=-': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=CRICKET': 1,
#   'w+1=ENGLISH': 1,
#   'w+2=COUNTY': 1,
#   'w+3=CHAMPIONSHIP': 1,
#   'w-1=CRICKET&w-2=SSS': 1,
#   'w+1=ENGLISH&w+2=COUNTY': 1,
#   'w-1=CRICKET&w+1=ENGLISH': 1},
#  {'w-3=SSS': 1,
#   'w-2=CRICKET': 1,
#   'w-1=-': 1,
#   'w+1=COUNTY': 1,
#   'w+2=CHAMPIONSHIP': 1,
#   'w+3=SCORES': 1,
#   'w-1=-&w-2=CRICKET': 1,
#   'w+1=COUNTY&w+2=CHAMPIONSHIP': 1,
#   'w-1=-&w+1=COUNTY': 1},
#  {'w-3=CRICKET': 1,
#   'w-2=-': 1,
#   'w-1=ENGLISH': 1,
#   'w+1=CHAMPIONSHIP': 1,
#   'w+2=SCORES': 1,
#   'w+3=.': 1,
#   'w-1=ENGLISH&w-2=-': 1,
#   'w+1=CHAMPIONSHIP&w+2=SCORES': 1,
#   'w-1=ENGLISH&w+1=CHAMPIONSHIP': 1},
#  {'w-3=-': 1,
#   'w-2=ENGLISH': 1,
#   'w-1=COUNTY': 1,
#   'w+1=SCORES': 1,
#   'w+2=.': 1,
#   'w+3=EEE': 1,
#   'w-1=COUNTY&w-2=ENGLISH': 1,
#   'w+1=SCORES&w+2=.': 1,
#   'w-1=COUNTY&w+1=SCORES': 1},
#  {'w-3=ENGLISH': 1,
#   'w-2=COUNTY': 1,
#   'w-1=CHAMPIONSHIP': 1,
#   'w+1=.': 1,
#   'w+2=EEE': 1,
# ...
#   'w-1=Martens&w+1=Belgium': 1},
#  {'w-3=Jacky': 1,
#   'w-2=Martens': 1,
#   'w-1=(': 1,
#   'w+1=)': 1,
#   'w+2=Husqvarna': 1,
#   'w+3=EEE': 1,
#   'w-1=(&w-2=Martens': 1,
#   'w+1=)&w+2=Husqvarna': 1,
#   'w-1=(&w+1=)': 1},
#  {'w-3=Martens': 1,
#   'w-2=(': 1,
#   'w-1=Belgium': 1,
#   'w+1=Husqvarna': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Belgium&w-2=(': 1,
#   'w+1=Husqvarna&w+2=EEE': 1,
#   'w-1=Belgium&w+1=Husqvarna': 1},
#  {'w-3=(': 1,
#   'w-2=Belgium': 1,
#   'w-1=)': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=)&w-2=Belgium': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=)&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Peter': 1,
#   'w+2=Dirkx': 1,
#   'w+3=(': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Peter&w+2=Dirkx': 1,
#   'w-1=SSS&w+1=Peter': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=5.': 1,
#   'w+1=Dirkx': 1,
#   'w+2=(': 1,
#   'w+3=Belgium': 1,
#   'w-1=5.&w-2=SSS': 1,
#   'w+1=Dirkx&w+2=(': 1,
#   'w-1=5.&w+1=Dirkx': 1},
#  {'w-3=SSS': 1,
#   'w-2=5.': 1,
#   'w-1=Peter': 1,
#   'w+1=(': 1,
#   'w+2=Belgium': 1,
#   'w+3=)': 1,
#   'w-1=Peter&w-2=5.': 1,
#   'w+1=(&w+2=Belgium': 1,
#   'w-1=Peter&w+1=(': 1},
#  {'w-3=5.': 1,
#   'w-2=Peter': 1,
#   'w-1=Dirkx': 1,
#   'w+1=Belgium': 1,
#   'w+2=)': 1,
#   'w+3=KTM': 1,
#   'w-1=Dirkx&w-2=Peter': 1,
#   'w+1=Belgium&w+2=)': 1,
#   'w-1=Dirkx&w+1=Belgium': 1},
#  {'w-3=Peter': 1,
#   'w-2=Dirkx': 1,
#   'w-1=(': 1,
#   'w+1=)': 1,
#   'w+2=KTM': 1,
#   'w+3=EEE': 1,
#   'w-1=(&w-2=Dirkx': 1,
#   'w+1=)&w+2=KTM': 1,
#   'w-1=(&w+1=)': 1},
#  {'w-3=Dirkx': 1,
#   'w-2=(': 1,
#   'w-1=Belgium': 1,
#   'w+1=KTM': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Belgium&w-2=(': 1,
#   'w+1=KTM&w+2=EEE': 1,
#   'w-1=Belgium&w+1=KTM': 1},
#  {'w-3=(': 1,
#   'w-2=Belgium': 1,
#   'w-1=)': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=)&w-2=Belgium': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=)&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Danny': 1,
#   'w+2=Theybers': 1,
#   'w+3=(': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Danny&w+2=Theybers': 1,
#   'w-1=SSS&w+1=Danny': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=6.': 1,
#   'w+1=Theybers': 1,
#   'w+2=(': 1,
#   'w+3=Belgium': 1,
#   'w-1=6.&w-2=SSS': 1,
#   'w+1=Theybers&w+2=(': 1,
#   'w-1=6.&w+1=Theybers': 1},
#  {'w-3=SSS': 1,
#   'w-2=6.': 1,
#   'w-1=Danny': 1,
#   'w+1=(': 1,
#   'w+2=Belgium': 1,
#   'w+3=)': 1,
#   'w-1=Danny&w-2=6.': 1,
#   'w+1=(&w+2=Belgium': 1,
#   'w-1=Danny&w+1=(': 1},
#  {'w-3=6.': 1,
#   'w-2=Danny': 1,
#   'w-1=Theybers': 1,
#   'w+1=Belgium': 1,
#   'w+2=)': 1,
#   'w+3=Honda': 1,
#   'w-1=Theybers&w-2=Danny': 1,
#   'w+1=Belgium&w+2=)': 1,
#   'w-1=Theybers&w+1=Belgium': 1},
#  {'w-3=Danny': 1,
#   'w-2=Theybers': 1,
#   'w-1=(': 1,
#   'w+1=)': 1,
#   'w+2=Honda': 1,
#   'w+3=EEE': 1,
#   'w-1=(&w-2=Theybers': 1,
#   'w+1=)&w+2=Honda': 1,
#   'w-1=(&w+1=)': 1},
#  {'w-3=Theybers': 1,
#   'w-2=(': 1,
#   'w-1=Belgium': 1,
#   'w+1=Honda': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Belgium&w-2=(': 1,
#   'w+1=Honda&w+2=EEE': 1,
#   'w-1=Belgium&w+1=Honda': 1},
#  {'w-3=(': 1,
#   'w-2=Belgium': 1,
#   'w-1=)': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=)&w-2=Belgium': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=)&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=race': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=race&w+2=EEE': 1,
#   'w-1=SSS&w+1=race': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=Second': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Second&w-2=SSS': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=Second&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Shayne': 1,
#   'w+2=King': 1,
#   'w+3=(': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Shayne&w+2=King': 1,
#   'w-1=SSS&w+1=Shayne': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=1.': 1,
#   'w+1=King': 1,
#   'w+2=(': 1,
#   'w+3=New': 1,
#   'w-1=1.&w-2=SSS': 1,
#   'w+1=King&w+2=(': 1,
#   'w-1=1.&w+1=King': 1},
#  {'w-3=SSS': 1,
#   'w-2=1.': 1,
#   'w-1=Shayne': 1,
#   'w+1=(': 1,
#   'w+2=New': 1,
#   'w+3=Zealand': 1,
#   'w-1=Shayne&w-2=1.': 1,
#   'w+1=(&w+2=New': 1,
#   'w-1=Shayne&w+1=(': 1},
#  {'w-3=1.': 1,
#   'w-2=Shayne': 1,
#   'w-1=King': 1,
#   'w+1=New': 1,
#   'w+2=Zealand': 1,
#   'w+3=)': 1,
#   'w-1=King&w-2=Shayne': 1,
#   'w+1=New&w+2=Zealand': 1,
#   'w-1=King&w+1=New': 1},
#  {'w-3=Shayne': 1,
#   'w-2=King': 1,
#   'w-1=(': 1,
#   'w+1=Zealand': 1,
#   'w+2=)': 1,
#   'w+3=KTM': 1,
#   'w-1=(&w-2=King': 1,
#   'w+1=Zealand&w+2=)': 1,
#   'w-1=(&w+1=Zealand': 1},
#  {'w-3=King': 1,
#   'w-2=(': 1,
#   'w-1=New': 1,
#   'w+1=)': 1,
#   'w+2=KTM': 1,
#   'w+3=EEE': 1,
#   'w-1=New&w-2=(': 1,
#   'w+1=)&w+2=KTM': 1,
#   'w-1=New&w+1=)': 1},
#  {'w-3=(': 1,
#   'w-2=New': 1,
#   'w-1=Zealand': 1,
#   'w+1=KTM': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Zealand&w-2=New': 1,
#   'w+1=KTM&w+2=EEE': 1,
#   'w-1=Zealand&w+1=KTM': 1},
#  {'w-3=New': 1,
#   'w-2=Zealand': 1,
#   'w-1=)': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=)&w-2=Zealand': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=)&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Martens': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Martens&w+2=EEE': 1,
#   'w-1=SSS&w+1=Martens': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=2.': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=2.&w-2=SSS': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=2.&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Theybers': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Theybers&w+2=EEE': 1,
#   'w-1=SSS&w+1=Theybers': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=3.': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=3.&w-2=SSS': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=3.&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Johan': 1,
#   'w+2=Boonen': 1,
#   'w+3=(': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Johan&w+2=Boonen': 1,
#   'w-1=SSS&w+1=Johan': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=4.': 1,
#   'w+1=Boonen': 1,
#   'w+2=(': 1,
#   'w+3=Belgium': 1,
#   'w-1=4.&w-2=SSS': 1,
#   'w+1=Boonen&w+2=(': 1,
#   'w-1=4.&w+1=Boonen': 1},
#  {'w-3=SSS': 1,
#   'w-2=4.': 1,
#   'w-1=Johan': 1,
#   'w+1=(': 1,
#   'w+2=Belgium': 1,
#   'w+3=)': 1,
#   'w-1=Johan&w-2=4.': 1,
#   'w+1=(&w+2=Belgium': 1,
#   'w-1=Johan&w+1=(': 1},
#  {'w-3=4.': 1,
#   'w-2=Johan': 1,
#   'w-1=Boonen': 1,
#   'w+1=Belgium': 1,
#   'w+2=)': 1,
#   'w+3=Husqvarna': 1,
#   'w-1=Boonen&w-2=Johan': 1,
#   'w+1=Belgium&w+2=)': 1,
#   'w-1=Boonen&w+1=Belgium': 1},
#  {'w-3=Johan': 1,
#   'w-2=Boonen': 1,
#   'w-1=(': 1,
#   'w+1=)': 1,
#   'w+2=Husqvarna': 1,
#   'w+3=EEE': 1,
#   'w-1=(&w-2=Boonen': 1,
#   'w+1=)&w+2=Husqvarna': 1,
#   'w-1=(&w+1=)': 1},
#  {'w-3=Boonen': 1,
#   'w-2=(': 1,
#   'w-1=Belgium': 1,
#   'w+1=Husqvarna': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Belgium&w-2=(': 1,
#   'w+1=Husqvarna&w+2=EEE': 1,
#   'w-1=Belgium&w+1=Husqvarna': 1},
#  {'w-3=(': 1,
#   'w-2=Belgium': 1,
#   'w-1=)': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=)&w-2=Belgium': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=)&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Dietmar': 1,
#   'w+2=Lalcher': 1,
#   'w+3=(': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Dietmar&w+2=Lalcher': 1,
#   'w-1=SSS&w+1=Dietmar': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=5.': 1,
#   'w+1=Lalcher': 1,
#   'w+2=(': 1,
#   'w+3=Germany': 1,
#   'w-1=5.&w-2=SSS': 1,
#   'w+1=Lalcher&w+2=(': 1,
#   'w-1=5.&w+1=Lalcher': 1},
#  {'w-3=SSS': 1,
#   'w-2=5.': 1,
#   'w-1=Dietmar': 1,
#   'w+1=(': 1,
#   'w+2=Germany': 1,
#   'w+3=)': 1,
#   'w-1=Dietmar&w-2=5.': 1,
#   'w+1=(&w+2=Germany': 1,
#   'w-1=Dietmar&w+1=(': 1},
#  {'w-3=5.': 1,
#   'w-2=Dietmar': 1,
#   'w-1=Lalcher': 1,
#   'w+1=Germany': 1,
#   'w+2=)': 1,
#   'w+3=Honda': 1,
#   'w-1=Lalcher&w-2=Dietmar': 1,
#   'w+1=Germany&w+2=)': 1,
#   'w-1=Lalcher&w+1=Germany': 1},
#  {'w-3=Dietmar': 1,
#   'w-2=Lalcher': 1,
#   'w-1=(': 1,
#   'w+1=)': 1,
#   'w+2=Honda': 1,
#   'w+3=EEE': 1,
#   'w-1=(&w-2=Lalcher': 1,
#   'w+1=)&w+2=Honda': 1,
#   'w-1=(&w+1=)': 1},
#  {'w-3=Lalcher': 1,
#   'w-2=(': 1,
#   'w-1=Germany': 1,
#   'w+1=Honda': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Germany&w-2=(': 1,
#   'w+1=Honda&w+2=EEE': 1,
#   'w-1=Germany&w+1=Honda': 1},
#  {'w-3=(': 1,
#   'w-2=Germany': 1,
#   'w-1=)': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=)&w-2=Germany': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=)&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Claus': 1,
#   'w+2=Manne': 1,
#   'w+3=Nielsen': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Claus&w+2=Manne': 1,
#   'w-1=SSS&w+1=Claus': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=6.': 1,
#   'w+1=Manne': 1,
#   'w+2=Nielsen': 1,
#   'w+3=(': 1,
#   'w-1=6.&w-2=SSS': 1,
#   'w+1=Manne&w+2=Nielsen': 1,
#   'w-1=6.&w+1=Manne': 1},
#  {'w-3=SSS': 1,
#   'w-2=6.': 1,
#   'w-1=Claus': 1,
#   'w+1=Nielsen': 1,
#   'w+2=(': 1,
#   'w+3=Denmark': 1,
#   'w-1=Claus&w-2=6.': 1,
#   'w+1=Nielsen&w+2=(': 1,
#   'w-1=Claus&w+1=Nielsen': 1},
#  {'w-3=6.': 1,
#   'w-2=Claus': 1,
#   'w-1=Manne': 1,
#   'w+1=(': 1,
#   'w+2=Denmark': 1,
#   'w+3=)': 1,
#   'w-1=Manne&w-2=Claus': 1,
#   'w+1=(&w+2=Denmark': 1,
#   'w-1=Manne&w+1=(': 1},
#  {'w-3=Claus': 1,
#   'w-2=Manne': 1,
#   'w-1=Nielsen': 1,
#   'w+1=Denmark': 1,
#   'w+2=)': 1,
#   'w+3=KTM': 1,
#   'w-1=Nielsen&w-2=Manne': 1,
#   'w+1=Denmark&w+2=)': 1,
#   'w-1=Nielsen&w+1=Denmark': 1},
#  {'w-3=Manne': 1,
#   'w-2=Nielsen': 1,
#   'w-1=(': 1,
#   'w+1=)': 1,
#   'w+2=KTM': 1,
#   'w+3=EEE': 1,
#   'w-1=(&w-2=Nielsen': 1,
#   'w+1=)&w+2=KTM': 1,
#   'w-1=(&w+1=)': 1},
#  {'w-3=Nielsen': 1,
#   'w-2=(': 1,
#   'w-1=Denmark': 1,
#   'w+1=KTM': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Denmark&w-2=(': 1,
#   'w+1=KTM&w+2=EEE': 1,
#   'w-1=Denmark&w+1=KTM': 1},
#  {'w-3=(': 1,
#   'w-2=Denmark': 1,
#   'w-1=)': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=)&w-2=Denmark': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=)&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=on': 1,
#   'w+2=day': 1,
#   'w+3=:': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=on&w+2=day': 1,
#   'w-1=SSS&w+1=on': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=Overall': 1,
#   'w+1=day': 1,
#   'w+2=:': 1,
#   'w+3=EEE': 1,
#   'w-1=Overall&w-2=SSS': 1,
#   'w+1=day&w+2=:': 1,
#   'w-1=Overall&w+1=day': 1},
#  {'w-3=SSS': 1,
#   'w-2=Overall': 1,
#   'w-1=on': 1,
#   'w+1=:': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=on&w-2=Overall': 1,
#   'w+1=:&w+2=EEE': 1,
#   'w-1=on&w+1=:': 1},
#  {'w-3=Overall': 1,
#   'w-2=on': 1,
#   'w-1=day': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=day&w-2=on': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=day&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Martens': 1,
#   'w+2=30': 1,
#   'w+3=points': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Martens&w+2=30': 1,
#   'w-1=SSS&w+1=Martens': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=1.': 1,
#   'w+1=30': 1,
#   'w+2=points': 1,
#   'w+3=EEE': 1,
#   'w-1=1.&w-2=SSS': 1,
#   'w+1=30&w+2=points': 1,
#   'w-1=1.&w+1=30': 1},
#  {'w-3=SSS': 1,
#   'w-2=1.': 1,
#   'w-1=Martens': 1,
#   'w+1=points': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Martens&w-2=1.': 1,
#   'w+1=points&w+2=EEE': 1,
#   'w-1=Martens&w+1=points': 1},
#  {'w-3=1.': 1,
#   'w-2=Martens': 1,
#   'w-1=30': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=30&w-2=Martens': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=30&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Shayne': 1,
#   'w+2=King': 1,
#   'w+3=28': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Shayne&w+2=King': 1,
#   'w-1=SSS&w+1=Shayne': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=2.': 1,
#   'w+1=King': 1,
#   'w+2=28': 1,
#   'w+3=EEE': 1,
#   'w-1=2.&w-2=SSS': 1,
#   'w+1=King&w+2=28': 1,
#   'w-1=2.&w+1=King': 1},
#  {'w-3=SSS': 1,
#   'w-2=2.': 1,
#   'w-1=Shayne': 1,
#   'w+1=28': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Shayne&w-2=2.': 1,
#   'w+1=28&w+2=EEE': 1,
#   'w-1=Shayne&w+1=28': 1},
#  {'w-3=2.': 1,
#   'w-2=Shayne': 1,
#   'w-1=King': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=King&w-2=Shayne': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=King&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Smets': 1,
#   'w+2=27': 1,
#   'w+3=EEE': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Smets&w+2=27': 1,
#   'w-1=SSS&w+1=Smets': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=3.': 1,
#   'w+1=27': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=3.&w-2=SSS': 1,
#   'w+1=27&w+2=EEE': 1,
#   'w-1=3.&w+1=27': 1},
#  {'w-3=SSS': 1,
#   'w-2=3.': 1,
#   'w-1=Smets': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Smets&w-2=3.': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=Smets&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Theybers': 1,
#   'w+2=25': 1,
#   'w+3=EEE': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Theybers&w+2=25': 1,
#   'w-1=SSS&w+1=Theybers': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=4.': 1,
#   'w+1=25': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=4.&w-2=SSS': 1,
#   'w+1=25&w+2=EEE': 1,
#   'w-1=4.&w+1=25': 1},
#  {'w-3=SSS': 1,
#   'w-2=4.': 1,
#   'w-1=Theybers': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Theybers&w-2=4.': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=Theybers&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Van': 1,
#   'w+2=Doorn': 1,
#   'w+3=24': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Van&w+2=Doorn': 1,
#   'w-1=SSS&w+1=Van': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=5.': 1,
#   'w+1=Doorn': 1,
#   'w+2=24': 1,
#   'w+3=EEE': 1,
#   'w-1=5.&w-2=SSS': 1,
#   'w+1=Doorn&w+2=24': 1,
#   'w-1=5.&w+1=Doorn': 1},
#  {'w-3=SSS': 1,
#   'w-2=5.': 1,
#   'w-1=Van': 1,
#   'w+1=24': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Van&w-2=5.': 1,
#   'w+1=24&w+2=EEE': 1,
#   'w-1=Van&w+1=24': 1},
#  {'w-3=5.': 1,
#   'w-2=Van': 1,
#   'w-1=Doorn': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Doorn&w-2=Van': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=Doorn&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Johansson': 1,
#   'w+2=17': 1,
#   'w+3=EEE': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Johansson&w+2=17': 1,
#   'w-1=SSS&w+1=Johansson': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=6.': 1,
#   'w+1=17': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=6.&w-2=SSS': 1,
#   'w+1=17&w+2=EEE': 1,
#   'w-1=6.&w+1=17': 1},
#  {'w-3=SSS': 1,
#   'w-2=6.': 1,
#   'w-1=Johansson': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=Johansson&w-2=6.': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=Johansson&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=championship': 1,
#   'w+2=standings': 1,
#   'w+3=(': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=championship&w+2=standings': 1,
#   'w-1=SSS&w+1=championship': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=World': 1,
#   'w+1=standings': 1,
#   'w+2=(': 1,
#   'w+3=after': 1,
#   'w-1=World&w-2=SSS': 1,
#   'w+1=standings&w+2=(': 1,
#   'w-1=World&w+1=standings': 1},
#  {'w-3=SSS': 1,
#   'w-2=World': 1,
#   'w-1=championship': 1,
#   'w+1=(': 1,
#   'w+2=after': 1,
#   'w+3=11': 1,
#   'w-1=championship&w-2=World': 1,
#   'w+1=(&w+2=after': 1,
#   'w-1=championship&w+1=(': 1},
#  {'w-3=World': 1,
#   'w-2=championship': 1,
#   'w-1=standings': 1,
#   'w+1=after': 1,
#   'w+2=11': 1,
#   'w+3=of': 1,
#   'w-1=standings&w-2=championship': 1,
#   'w+1=after&w+2=11': 1,
#   'w-1=standings&w+1=after': 1},
#  {'w-3=championship': 1,
#   'w-2=standings': 1,
#   'w-1=(': 1,
#   'w+1=11': 1,
#   'w+2=of': 1,
#   'w+3=12': 1,
#   'w-1=(&w-2=standings': 1,
#   'w+1=11&w+2=of': 1,
#   'w-1=(&w+1=11': 1},
#  {'w-3=standings': 1,
#   'w-2=(': 1,
#   'w-1=after': 1,
#   'w+1=of': 1,
#   'w+2=12': 1,
#   'w+3=rounds': 1,
#   'w-1=after&w-2=(': 1,
#   'w+1=of&w+2=12': 1,
#   'w-1=after&w+1=of': 1},
#  {'w-3=(': 1,
#   'w-2=after': 1,
#   'w-1=11': 1,
#   'w+1=12': 1,
#   'w+2=rounds': 1,
#   'w+3=)': 1,
#   'w-1=11&w-2=after': 1,
#   'w+1=12&w+2=rounds': 1,
#   'w-1=11&w+1=12': 1},
#  {'w-3=after': 1,
#   'w-2=11': 1,
#   'w-1=of': 1,
#   'w+1=rounds': 1,
#   'w+2=)': 1,
#   'w+3=:': 1,
#   'w-1=of&w-2=11': 1,
#   'w+1=rounds&w+2=)': 1,
#   'w-1=of&w+1=rounds': 1},
#  {'w-3=11': 1,
#   'w-2=of': 1,
#   'w-1=12': 1,
#   'w+1=)': 1,
#   'w+2=:': 1,
#   'w+3=EEE': 1,
#   'w-1=12&w-2=of': 1,
#   'w+1=)&w+2=:': 1,
#   'w-1=12&w+1=)': 1},
#  {'w-3=of': 1,
#   'w-2=12': 1,
#   'w-1=rounds': 1,
#   'w+1=:': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=rounds&w-2=12': 1,
#   'w+1=:&w+2=EEE': 1,
#   'w-1=rounds&w+1=:': 1},
#  {'w-3=12': 1,
#   'w-2=rounds': 1,
#   'w-1=)': 1,
#   'w+1=EEE': 1,
#   'w+2=EEE': 1,
#   'w+3=EEE': 1,
#   'w-1=)&w-2=rounds': 1,
#   'w+1=EEE&w+2=EEE': 1,
#   'w-1=)&w+1=EEE': 1},
#  {'w-3=SSS': 1,
#   'w-2=SSS': 1,
#   'w-1=SSS': 1,
#   'w+1=Shayne': 1,
#   'w+2=King': 1,
#   'w+3=323': 1,
#   'w-1=SSS&w-2=SSS': 1,
#   'w+1=Shayne&w+2=King': 1,
#   'w-1=SSS&w+1=Shayne': 1},
#  ...]

# %% [markdown]
# Now, repeat the process of extracting features from the test data.
# What is the difference between the code above and below?

# %%
def extract_features_dev_or_test(data, features):
    """
    Extracts feature dictionaries and labels from "data". The only
    features which should be computed are those in "features". You
    should add your additional featurization code here.
    
    TODO: You should add your additional featurization code here.
    """
    y = []
    X = []
    for sentence in data:
        padded = [('SSS', None)] * 3 + sentence[:] + [('EEE', None)] * 3
        for i in range(3, len(padded) - 3):
            y.append(1 if padded[i][1] == 'I' else -1)
            feat1 = 'w-3=' + str(padded[i - 3][0])
            feat2 = 'w-2=' + str(padded[i - 2][0])
            feat3 = 'w-1=' + str(padded[i - 1][0])
            feat4 = 'w+1=' + str(padded[i + 1][0])
            feat5 = 'w+2=' + str(padded[i + 2][0])
            feat6 = 'w+3=' + str(padded[i + 3][0])
            feat7 = 'w-1=' + str(padded[i - 1][0]) + '&w-2=' + str(padded[i - 2][0])
            feat8 = 'w+1=' + str(padded[i + 1][0]) + '&w+2=' + str(padded[i + 2][0])
            feat9 = 'w-1=' + str(padded[i - 1][0]) + '&w+1=' + str(padded[i + 1][0])
            feats = [feat1, feat2, feat3, feat4, feat5, feat6, feat7, feat8, feat9]
            feats = {feature: 1 for feature in feats if feature in features}
            X.append(feats)
    return X, y

# %% [markdown]
# #### 3.2.2 Running the NER Experiment
#
# As stated previously, train both models on the CoNLL training data then compute the $F_1$  on the development and testing data of both CoNLL and Enron. Note that the model which is used to predict labels for Enron is trained on CoNLL data, not Enron data.

# %%
def run_ner_experiment(data_path):
    """
    Runs the NER experiment using the path to the ner data
    (e.g. "ner" from the released resources). We have implemented
    the standard Perceptron below. You should do the same for
    the averaged version and the SVM.
    
    The SVM requires transforming the features into a different
    format. See the end of this function for how to do that.
    """
    train = load_ner_data(dataset='conll', dataset_type='train')
    conll_test = load_ner_data(dataset='conll', dataset_type='test')
    enron_test = load_ner_data(dataset='enron', dataset_type='test')

    features, X_train, y_train = extract_ner_features_train(train)
    X_conll_test, y_conll_test = extract_features_dev_or_test(conll_test, features)
    X_enron_test, y_enron_test = extract_features_dev_or_test(enron_test, features)
                 
    # TODO: We show you how to do this for Perceptron.
    # You should do this for the Averaged Perceptron and SVM
    classifier = Perceptron(features)
    classifier.train(X_train, y_train)
    
    y_pred = classifier.predict(X_conll_test)
    conll_f1 = calculate_f1(y_conll_test, y_pred)

    y_pred = classifier.predict(X_enron_test)
    enron_f1 = calculate_f1(y_enron_test, y_pred)
    print('Perceptron')
    print('CoNLL Test Accuracy: ', conll_f1)
    print('Enron Test Accuracy: ', enron_f1)
    print()
    
    classifier = AveragedPerceptron(features)
    classifier.train(X_train, y_train)
    
    y_pred = classifier.predict(X_conll_test)
    conll_f1 = calculate_f1(y_conll_test, y_pred)

    y_pred = classifier.predict(X_enron_test)
    enron_f1 = calculate_f1(y_enron_test, y_pred)
    print('Averaged Perceptron')
    print('CoNLL Test Accuracy: ', conll_f1)
    print('Enron Test Accuracy: ', enron_f1)
    print()
    
    # This is how you convert from the way we represent features in the
    # Perceptron code to how you need to represent features for the SVM.
    # You can then train with (X_train_dict, y_train) and test with
    # (X_conll_test_dict, y_conll_test) and (X_enron_test_dict, y_enron_test)
    vectorizer = DictVectorizer()
    X_train_dict = vectorizer.fit_transform(X_train)
    X_conll_test_dict = vectorizer.transform(X_conll_test)
    X_enron_test_dict = vectorizer.transform(X_enron_test)
    
    svc = LinearSVC(loss='hinge')
    svc.fit(X_train_dict, y_train)
    y_pred = svc.predict(X_conll_test_dict)
    conll_f1 = calculate_f1(y_conll_test, y_pred)

    y_pred = classifier.predict(X_enron_test_dict)
    enron_f1 = calculate_f1(y_enron_test, y_pred)
    print('SVC')
    print('CoNLL Test Accuracy: ', conll_f1)
    print('Enron Test Accuracy: ', enron_f1)
    print()

# %%
# Run the NER experiment. "ner" is the path to where the data is located.
run_ner_experiment('ner')
# Out:
# Perceptron
# CoNLL Test Accuracy:  0.7523076923076922
# Enron Test Accuracy:  0.14016172506738545
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-131-bdbdfc112e59> in <module>
#       1 # Run the NER experiment. "ner" is the path to where the data is located.
# ----> 2 run_ner_experiment('ner')
#
# <ipython-input-130-b929c193960b> in run_ner_experiment(data_path)
#      33
#      34     classifier = AveragedPerceptron(features)
# ---> 35     classifier.train(X_train, y_train)
#      36
#      37     y_pred = classifier.predict(X_conll_test)
#
# <ipython-input-12-4c1190588f46> in train(self, X, y)
#      17         for iteration in range(self.ITERATIONS):
#      18             for x_i, y_i in zip(X, y):
# ---> 19                 self.process_example(x_i, y_i)
#      20         self.finalize()
#      21
#
# <ipython-input-16-97f096b259e9> in process_example(self, x, y)
#      18         else:
#      19             for feature in self.w:
# ---> 20                 self.cumul_w[feature] += self.w[feature] * self.classified
#      21                 if feature in x:
#      22                     self.w[feature] += self.eta * y * x[feature]
#
# KeyboardInterrupt:

# %% [markdown]
# ##### F1 Scores Table
# TODO: report your values:
#
# | Model               | CoNLL Test F1 | Enron Test F1 |
# |---------------------|---------------|---------------|
# | Averaged Perceptron |               |               |
# | SVM                 |               |               |

# %% [markdown]
# ##### Questions (5 points)
#
# Comment on the results:
# 1. Are the F$_1$ scores on CoNLL and Enron similar?
#
#     *TODO: My answer to question 1 here*
#
#
# 2. If they are dissimilar, explain why you think the F$_1$ score increased/decreased on the Enron data.
#
#     *TODO: My answer to question 2 here*

# %% [markdown]
# ## Submission Instructions
#
# We will be using Gradescope to turn in both the Python code.
# You should have been automatically added to Gradescope.
# If you do not have access, please ask the TA staff on Piazza.
#
# There are three parts to the submission on Gradescope:
# * ipynb file: Submit this notebook (.ipynb). If you are using Google Colab, you will have to download it as an ipynb file.
# * PDF: This notebook saved as a PDF. We will use this to see the overall structure of your homework and code, and to check manual questions like the tables, plots, and your discussions. How should I convert this notebook to PDF, you may ask? There are a few ways, but for simplicity print the Jupyter notebook and _Save as PDF_.
# * Code: A `hw2.py` file. We will use this to unit test and automate grading some parts of the homework. We only need a few functions/classes from the whole notebook. In particular, to unit test we only need:
#     - `calculate_f1`
#     - `highest_and_lowest_f1_score`
#     - `Perceptron`, `Winnow`, and `AdaGrad` classes.
#
# There are two ways to submit these pieces of code. You can either manually copy and paste these to a Python file,
# or you can use Jupyter's _Download as .py_, and delete all unnecessary code.
